# %%
from torchvision import datasets,transforms
import torch
import random
import torch.nn.functional as f
import torch.nn as nn
import torch.optim as optim
from torchsummary import summary

# %%
def get_cifar10_dataset(batch_size=64):
    transformers = transforms.Compose([
                           transforms.RandomHorizontalFlip(),
                           transforms.RandomCrop(32, 4),
                           transforms.ToTensor(),
                           transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
                       ])
    train_dataset = datasets.CIFAR10('./data', train=True, download=True,
                       transform=transformers)

    test_dataset = datasets.CIFAR10('./data', train=False, transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
                       ]))

    train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=batch_size, shuffle=True)
    test_loader = torch.utils.data.DataLoader(test_dataset,batch_size=batch_size, shuffle=False)
    return train_loader,test_loader

# %%
def train_single_model(model,optimiser,device,train_loader,epoch):
    model.train()
    criterion = nn.CrossEntropyLoss()
    correct = 0
    for batch_idx, (data, target) in enumerate(train_loader):        
        data, target = data.to(device), target.to(device)
        optimiser.zero_grad()
        output = model(data)
        loss = criterion(output,target)
        loss.backward()
        optimiser.step()

        pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()
        ### printing logs
        if batch_idx % 300 == 0:
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
    
    print('\nTrain set for client: Accuracy: {}/{} ({:.0f}%)\n'.format(
        correct, len(train_loader.dataset),
        100. * correct / len(train_loader.dataset)))

# %%
def test_single_model(model,device,test_loader):
    model.eval()
    criterion = nn.CrossEntropyLoss()
    with torch.no_grad():
        test_loss = 0
        correct = 0
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += criterion(output, target).item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
        
        test_loss /= len(test_loader.dataset)
        print('\nTest set for client: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, correct, len(test_loader.dataset),
            100. * correct / len(test_loader.dataset)))

def adjust_learning_rate(optimizer, init_lr, epoch):
    lr = init_lr * (0.5 ** (epoch // 40))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
import torch.nn as nn

class Flatten(nn.Module):
    def forward(self, x):
        batch_size = x.shape[0]
        return x.view(batch_size, -1)

cfg = {
    'VGG11': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
    'VGG16_client' : [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M'],
    'VGG16_server' : [512, 512, 512, 'M', 512, 512, 512, 'M'],
    'VGG11_client' : [64, 'M'],
    'VGG11_server' : [128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M']
}

def make_layers(cfg, in_channels):
    layers = []
    for x in cfg:
        if x == 'M':
            layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
        else:
            layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                        nn.BatchNorm2d(x),
                        nn.ReLU()]
            in_channels = x
    return nn.Sequential(*layers)

vgg = lambda input_channels,output_channels : nn.Sequential(
            make_layers(cfg['VGG16'],input_channels),
            Flatten(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(128,output_channels),
            nn.Softmax(dim=1))

vgg_client = lambda input_channels,output_channels : make_layers(cfg['VGG16_client'],input_channels)

vgg_server = lambda input_channels,output_channels : nn.Sequential(
            make_layers(cfg['VGG16_server'],input_channels),
            Flatten(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(p=0.25),
            nn.Linear(128,output_channels),
            nn.Softmax(dim=1))

# %%
if __name__ == "__main__":
    random.seed(7)
    torch.manual_seed(7)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    if torch.cuda.is_available():  
        dev = "cuda:0" 
    else:  
        dev = "cpu"
    device = torch.device(dev)

    train_loader,test_loader = get_cifar10_dataset(batch_size=128)

    model = vgg(input_channels=3,output_channels=10).to(device)
    optimiser = optim.SGD(model.parameters(),lr=1e-3,weight_decay=5e-4)

    print("Model Summary")
    summary(model,(3,32,32))

    init_lr = 0.1
    for i in range(1,200):
        adjust_learning_rate(optimiser,init_lr,i)
        train_single_model(model,optimiser,device,train_loader,i)
        history = test_single_model(model,device,test_loader)
    
    torch.save(model.state_dict(),"single-model.pt")
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Model Summary
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#             Conv2d-4           [-1, 64, 32, 32]          36,928
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#               ReLU-6           [-1, 64, 32, 32]               0
#          MaxPool2d-7           [-1, 64, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]          73,856
#        BatchNorm2d-9          [-1, 128, 16, 16]             256
#              ReLU-10          [-1, 128, 16, 16]               0
#            Conv2d-11          [-1, 128, 16, 16]         147,584
#       BatchNorm2d-12          [-1, 128, 16, 16]             256
#              ReLU-13          [-1, 128, 16, 16]               0
#         MaxPool2d-14            [-1, 128, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         295,168
#       BatchNorm2d-16            [-1, 256, 8, 8]             512
#              ReLU-17            [-1, 256, 8, 8]               0
#            Conv2d-18            [-1, 256, 8, 8]         590,080
#       BatchNorm2d-19            [-1, 256, 8, 8]             512
#              ReLU-20            [-1, 256, 8, 8]               0
#            Conv2d-21            [-1, 256, 8, 8]         590,080
#       BatchNorm2d-22            [-1, 256, 8, 8]             512
#              ReLU-23            [-1, 256, 8, 8]               0
#         MaxPool2d-24            [-1, 256, 4, 4]               0
#            Conv2d-25            [-1, 512, 4, 4]       1,180,160
#       BatchNorm2d-26            [-1, 512, 4, 4]           1,024
#              ReLU-27            [-1, 512, 4, 4]               0
#            Conv2d-28            [-1, 512, 4, 4]       2,359,808
#       BatchNorm2d-29            [-1, 512, 4, 4]           1,024
#              ReLU-30            [-1, 512, 4, 4]               0
#            Conv2d-31            [-1, 512, 4, 4]       2,359,808
#       BatchNorm2d-32            [-1, 512, 4, 4]           1,024
#              ReLU-33            [-1, 512, 4, 4]               0
#         MaxPool2d-34            [-1, 512, 2, 2]               0
#            Conv2d-35            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-36            [-1, 512, 2, 2]           1,024
#              ReLU-37            [-1, 512, 2, 2]               0
#            Conv2d-38            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-39            [-1, 512, 2, 2]           1,024
#              ReLU-40            [-1, 512, 2, 2]               0
#            Conv2d-41            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-42            [-1, 512, 2, 2]           1,024
#              ReLU-43            [-1, 512, 2, 2]               0
#         MaxPool2d-44            [-1, 512, 1, 1]               0
#           Flatten-45                  [-1, 512]               0
#            Linear-46                  [-1, 256]         131,328
#              ReLU-47                  [-1, 256]               0
#           Dropout-48                  [-1, 256]               0
#            Linear-49                  [-1, 128]          32,896
#              ReLU-50                  [-1, 128]               0
#           Dropout-51                  [-1, 128]               0
#            Linear-52                   [-1, 10]           1,290
#           Softmax-53                   [-1, 10]               0
# ================================================================
# Total params: 14,888,650
# Trainable params: 14,888,650
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 6.58
# Params size (MB): 56.80
# Estimated Total Size (MB): 63.39
# ----------------------------------------------------------------
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.303118
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 2.006468
#
# Train set for client: Accuracy: 15564/50000 (31%)
#
#
# Test set for client: Average loss: 0.0169, Accuracy: 3236/10000 (32%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 2.141691
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 1.979951
#
# Train set for client: Accuracy: 23557/50000 (47%)
#
#
# Test set for client: Average loss: 0.0154, Accuracy: 5035/10000 (50%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.919632
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 1.893278
#
# Train set for client: Accuracy: 27211/50000 (54%)
#
#
# Test set for client: Average loss: 0.0153, Accuracy: 5256/10000 (53%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.922056
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 1.847861
#
# Train set for client: Accuracy: 29560/50000 (59%)
#
#
# Test set for client: Average loss: 0.0152, Accuracy: 5330/10000 (53%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.808162
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 1.787919
#
# Train set for client: Accuracy: 31846/50000 (64%)
#
#
# Test set for client: Average loss: 0.0146, Accuracy: 6156/10000 (62%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.816439
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 1.818545
#
# Train set for client: Accuracy: 33156/50000 (66%)
#
#
# Test set for client: Average loss: 0.0140, Accuracy: 6860/10000 (69%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.801149
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 1.824968
#
# Train set for client: Accuracy: 34565/50000 (69%)
#
#
# Test set for client: Average loss: 0.0142, Accuracy: 6625/10000 (66%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.772521
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 1.674104
#
# Train set for client: Accuracy: 35333/50000 (71%)
#
#
# Test set for client: Average loss: 0.0146, Accuracy: 6146/10000 (61%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.753499
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 1.752663
#
# Train set for client: Accuracy: 35847/50000 (72%)
#
#
# Test set for client: Average loss: 0.0142, Accuracy: 6643/10000 (66%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 1.697511
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 1.729419
#
# Train set for client: Accuracy: 36434/50000 (73%)
#
#
# Test set for client: Average loss: 0.0138, Accuracy: 7058/10000 (71%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 1.740444
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 1.696941
#
# Train set for client: Accuracy: 36878/50000 (74%)
#
#
# Test set for client: Average loss: 0.0136, Accuracy: 7395/10000 (74%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 1.713050
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 1.739536
#
# Train set for client: Accuracy: 37410/50000 (75%)
#
#
# Test set for client: Average loss: 0.0140, Accuracy: 6912/10000 (69%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 1.655033
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 1.693573
#
# Train set for client: Accuracy: 37899/50000 (76%)
#
#
# Test set for client: Average loss: 0.0137, Accuracy: 7265/10000 (73%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 1.713593
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 1.724976
#
# Train set for client: Accuracy: 38076/50000 (76%)
#
#
# Test set for client: Average loss: 0.0135, Accuracy: 7481/10000 (75%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 1.648702
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 1.672263
#
# Train set for client: Accuracy: 38531/50000 (77%)
#
#
# Test set for client: Average loss: 0.0142, Accuracy: 6629/10000 (66%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 1.713464
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 1.687440
#
# Train set for client: Accuracy: 38823/50000 (78%)
#
#
# Test set for client: Average loss: 0.0133, Accuracy: 7706/10000 (77%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 1.625558
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 1.708074
#
# Train set for client: Accuracy: 38991/50000 (78%)
#
#
# Test set for client: Average loss: 0.0135, Accuracy: 7500/10000 (75%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 1.711092
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 1.674090
#
# Train set for client: Accuracy: 39297/50000 (79%)
#
#
# Test set for client: Average loss: 0.0136, Accuracy: 7426/10000 (74%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 1.659788
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 1.753007
#
# Train set for client: Accuracy: 39570/50000 (79%)
#
#
# Test set for client: Average loss: 0.0134, Accuracy: 7676/10000 (77%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 1.703304
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 1.667635
#
# Train set for client: Accuracy: 39725/50000 (79%)
#
#
# Test set for client: Average loss: 0.0136, Accuracy: 7339/10000 (73%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 1.619988
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 1.726810
#
# Train set for client: Accuracy: 39861/50000 (80%)
#
#
# Test set for client: Average loss: 0.0132, Accuracy: 7917/10000 (79%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 1.685290
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 1.593690
#
# Train set for client: Accuracy: 40265/50000 (81%)
#
#
# Test set for client: Average loss: 0.0135, Accuracy: 7568/10000 (76%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 1.582187
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 1.607553
#
# Train set for client: Accuracy: 40398/50000 (81%)
#
#
# Test set for client: Average loss: 0.0132, Accuracy: 7931/10000 (79%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 1.661373
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 1.649400
#
# Train set for client: Accuracy: 40618/50000 (81%)
#
#
# Test set for client: Average loss: 0.0134, Accuracy: 7640/10000 (76%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 1.722527
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 1.657831
#
# Train set for client: Accuracy: 40769/50000 (82%)
#
#
# Test set for client: Average loss: 0.0134, Accuracy: 7652/10000 (77%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 1.638012
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 1.632857
#
# Train set for client: Accuracy: 40907/50000 (82%)
#
#
# Test set for client: Average loss: 0.0130, Accuracy: 8153/10000 (82%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 1.637281
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 1.656593
#
# Train set for client: Accuracy: 41128/50000 (82%)
#
#
# Test set for client: Average loss: 0.0129, Accuracy: 8262/10000 (83%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 1.620784
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 1.623676
#
# Train set for client: Accuracy: 41175/50000 (82%)
#
#
# Test set for client: Average loss: 0.0130, Accuracy: 8094/10000 (81%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 1.662374
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 1.663584
#
# Train set for client: Accuracy: 41155/50000 (82%)
#
#
# Test set for client: Average loss: 0.0131, Accuracy: 7998/10000 (80%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 1.581045
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 1.632186
#
# Train set for client: Accuracy: 41557/50000 (83%)
#
#
# Test set for client: Average loss: 0.0130, Accuracy: 8180/10000 (82%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 1.607279
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 1.637683
#
# Train set for client: Accuracy: 41644/50000 (83%)
#
#
# Test set for client: Average loss: 0.0130, Accuracy: 8145/10000 (81%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 1.583193
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 1.659781
#
# Train set for client: Accuracy: 41613/50000 (83%)
#
#
# Test set for client: Average loss: 0.0130, Accuracy: 8122/10000 (81%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 1.564449
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 1.628687
#
# Train set for client: Accuracy: 41669/50000 (83%)
#
#
# Test set for client: Average loss: 0.0129, Accuracy: 8247/10000 (82%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 1.670906
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 1.670710
#
# Train set for client: Accuracy: 41772/50000 (84%)
#
#
# Test set for client: Average loss: 0.0129, Accuracy: 8245/10000 (82%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 1.611362
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 1.611452
#
# Train set for client: Accuracy: 42070/50000 (84%)
#
#
# Test set for client: Average loss: 0.0132, Accuracy: 7842/10000 (78%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 1.602813
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 1.602685
#
# Train set for client: Accuracy: 42144/50000 (84%)
#
#
# Test set for client: Average loss: 0.0132, Accuracy: 7900/10000 (79%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 1.611079
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 1.607768
#
# Train set for client: Accuracy: 42191/50000 (84%)
#
#
# Test set for client: Average loss: 0.0130, Accuracy: 8101/10000 (81%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 1.670424
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 1.631815
#
# Train set for client: Accuracy: 42113/50000 (84%)
#
#
# Test set for client: Average loss: 0.0135, Accuracy: 7537/10000 (75%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 1.618541
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 1.654880
#
# Train set for client: Accuracy: 42237/50000 (84%)
#
#
# Test set for client: Average loss: 0.0131, Accuracy: 8077/10000 (81%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 1.612985
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 1.617125
#
# Train set for client: Accuracy: 43545/50000 (87%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8554/10000 (86%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 1.549364
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 1.547277
#
# Train set for client: Accuracy: 43832/50000 (88%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8479/10000 (85%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 1.617693
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 1.628509
#
# Train set for client: Accuracy: 44038/50000 (88%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8558/10000 (86%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 1.549617
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 1.570144
#
# Train set for client: Accuracy: 44271/50000 (89%)
#
#
# Test set for client: Average loss: 0.0128, Accuracy: 8467/10000 (85%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 1.571171
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 1.614116
#
# Train set for client: Accuracy: 44223/50000 (88%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8566/10000 (86%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 1.554677
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 1.531395
#
# Train set for client: Accuracy: 44336/50000 (89%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8675/10000 (87%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 1.566305
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 1.599257
#
# Train set for client: Accuracy: 44396/50000 (89%)
#
#
# Test set for client: Average loss: 0.0129, Accuracy: 8333/10000 (83%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 1.578891
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 1.556550
#
# Train set for client: Accuracy: 44470/50000 (89%)
#
#
# Test set for client: Average loss: 0.0128, Accuracy: 8396/10000 (84%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 1.559379
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 1.606531
#
# Train set for client: Accuracy: 44439/50000 (89%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8611/10000 (86%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 1.582060
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 1.578749
#
# Train set for client: Accuracy: 44530/50000 (89%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8487/10000 (85%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 1.606805
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 1.582597
#
# Train set for client: Accuracy: 44572/50000 (89%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8600/10000 (86%)
#
# Train Epoch: 51 [0/50000 (0%)]	Loss: 1.567075
# Train Epoch: 51 [38400/50000 (77%)]	Loss: 1.606769
#
# Train set for client: Accuracy: 44617/50000 (89%)
#
#
# Test set for client: Average loss: 0.0128, Accuracy: 8413/10000 (84%)
#
# Train Epoch: 52 [0/50000 (0%)]	Loss: 1.566251
# Train Epoch: 52 [38400/50000 (77%)]	Loss: 1.587390
#
# Train set for client: Accuracy: 44672/50000 (89%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8641/10000 (86%)
#
# Train Epoch: 53 [0/50000 (0%)]	Loss: 1.548936
# Train Epoch: 53 [38400/50000 (77%)]	Loss: 1.613913
#
# Train set for client: Accuracy: 44705/50000 (89%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8626/10000 (86%)
#
# Train Epoch: 54 [0/50000 (0%)]	Loss: 1.515148
# Train Epoch: 54 [38400/50000 (77%)]	Loss: 1.556455
#
# Train set for client: Accuracy: 44787/50000 (90%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8564/10000 (86%)
#
# Train Epoch: 55 [0/50000 (0%)]	Loss: 1.647527
# Train Epoch: 55 [38400/50000 (77%)]	Loss: 1.573149
#
# Train set for client: Accuracy: 44762/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8615/10000 (86%)
#
# Train Epoch: 56 [0/50000 (0%)]	Loss: 1.568088
# Train Epoch: 56 [38400/50000 (77%)]	Loss: 1.553383
#
# Train set for client: Accuracy: 44931/50000 (90%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8487/10000 (85%)
#
# Train Epoch: 57 [0/50000 (0%)]	Loss: 1.564483
# Train Epoch: 57 [38400/50000 (77%)]	Loss: 1.582620
#
# Train set for client: Accuracy: 44825/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8624/10000 (86%)
#
# Train Epoch: 58 [0/50000 (0%)]	Loss: 1.543778
# Train Epoch: 58 [38400/50000 (77%)]	Loss: 1.566692
#
# Train set for client: Accuracy: 44927/50000 (90%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8576/10000 (86%)
#
# Train Epoch: 59 [0/50000 (0%)]	Loss: 1.556967
# Train Epoch: 59 [38400/50000 (77%)]	Loss: 1.552987
#
# Train set for client: Accuracy: 44943/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8719/10000 (87%)
#
# Train Epoch: 60 [0/50000 (0%)]	Loss: 1.552646
# Train Epoch: 60 [38400/50000 (77%)]	Loss: 1.596925
#
# Train set for client: Accuracy: 45070/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8657/10000 (87%)
#
# Train Epoch: 61 [0/50000 (0%)]	Loss: 1.518233
# Train Epoch: 61 [38400/50000 (77%)]	Loss: 1.540402
#
# Train set for client: Accuracy: 45136/50000 (90%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8597/10000 (86%)
#
# Train Epoch: 62 [0/50000 (0%)]	Loss: 1.573492
# Train Epoch: 62 [38400/50000 (77%)]	Loss: 1.562104
#
# Train set for client: Accuracy: 44972/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8709/10000 (87%)
#
# Train Epoch: 63 [0/50000 (0%)]	Loss: 1.542261
# Train Epoch: 63 [38400/50000 (77%)]	Loss: 1.601517
#
# Train set for client: Accuracy: 44975/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8687/10000 (87%)
#
# Train Epoch: 64 [0/50000 (0%)]	Loss: 1.589948
# Train Epoch: 64 [38400/50000 (77%)]	Loss: 1.573774
#
# Train set for client: Accuracy: 45165/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8622/10000 (86%)
#
# Train Epoch: 65 [0/50000 (0%)]	Loss: 1.563046
# Train Epoch: 65 [38400/50000 (77%)]	Loss: 1.595187
#
# Train set for client: Accuracy: 45087/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8598/10000 (86%)
#
# Train Epoch: 66 [0/50000 (0%)]	Loss: 1.571314
# Train Epoch: 66 [38400/50000 (77%)]	Loss: 1.581392
#
# Train set for client: Accuracy: 45178/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8629/10000 (86%)
#
# Train Epoch: 67 [0/50000 (0%)]	Loss: 1.578486
# Train Epoch: 67 [38400/50000 (77%)]	Loss: 1.528839
#
# Train set for client: Accuracy: 45129/50000 (90%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8538/10000 (85%)
#
# Train Epoch: 68 [0/50000 (0%)]	Loss: 1.545447
# Train Epoch: 68 [38400/50000 (77%)]	Loss: 1.599867
#
# Train set for client: Accuracy: 45277/50000 (91%)
#
#
# Test set for client: Average loss: 0.0129, Accuracy: 8297/10000 (83%)
#
# Train Epoch: 69 [0/50000 (0%)]	Loss: 1.576230
# Train Epoch: 69 [38400/50000 (77%)]	Loss: 1.583127
#
# Train set for client: Accuracy: 45201/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8691/10000 (87%)
#
# Train Epoch: 70 [0/50000 (0%)]	Loss: 1.576995
# Train Epoch: 70 [38400/50000 (77%)]	Loss: 1.547071
#
# Train set for client: Accuracy: 45133/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8711/10000 (87%)
#
# Train Epoch: 71 [0/50000 (0%)]	Loss: 1.557040
# Train Epoch: 71 [38400/50000 (77%)]	Loss: 1.569922
#
# Train set for client: Accuracy: 45299/50000 (91%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8642/10000 (86%)
#
# Train Epoch: 72 [0/50000 (0%)]	Loss: 1.554737
# Train Epoch: 72 [38400/50000 (77%)]	Loss: 1.526896
#
# Train set for client: Accuracy: 45293/50000 (91%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8707/10000 (87%)
#
# Train Epoch: 73 [0/50000 (0%)]	Loss: 1.574883
# Train Epoch: 73 [38400/50000 (77%)]	Loss: 1.544982
#
# Train set for client: Accuracy: 45224/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8649/10000 (86%)
#
# Train Epoch: 74 [0/50000 (0%)]	Loss: 1.518077
# Train Epoch: 74 [38400/50000 (77%)]	Loss: 1.521945
#
# Train set for client: Accuracy: 45402/50000 (91%)
#
#
# Test set for client: Average loss: 0.0125, Accuracy: 8759/10000 (88%)
#
# Train Epoch: 75 [0/50000 (0%)]	Loss: 1.526894
# Train Epoch: 75 [38400/50000 (77%)]	Loss: 1.528736
#
# Train set for client: Accuracy: 45386/50000 (91%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8556/10000 (86%)
#
# Train Epoch: 76 [0/50000 (0%)]	Loss: 1.601270
# Train Epoch: 76 [38400/50000 (77%)]	Loss: 1.544657
#
# Train set for client: Accuracy: 45317/50000 (91%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8665/10000 (87%)
#
# Train Epoch: 77 [0/50000 (0%)]	Loss: 1.612021
# Train Epoch: 77 [38400/50000 (77%)]	Loss: 1.582608
#
# Train set for client: Accuracy: 45359/50000 (91%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8506/10000 (85%)
#
# Train Epoch: 78 [0/50000 (0%)]	Loss: 1.568853
# Train Epoch: 78 [38400/50000 (77%)]	Loss: 1.560415
#
# Train set for client: Accuracy: 45327/50000 (91%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8684/10000 (87%)
#
# Train Epoch: 79 [0/50000 (0%)]	Loss: 1.574966
# Train Epoch: 79 [38400/50000 (77%)]	Loss: 1.536343
#
# Train set for client: Accuracy: 45517/50000 (91%)
#
#
# Test set for client: Average loss: 0.0129, Accuracy: 8287/10000 (83%)
#
# Train Epoch: 80 [0/50000 (0%)]	Loss: 1.609185
# Train Epoch: 80 [38400/50000 (77%)]	Loss: 1.552468
#
# Train set for client: Accuracy: 46286/50000 (93%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8891/10000 (89%)
#
# Train Epoch: 81 [0/50000 (0%)]	Loss: 1.556700
# Train Epoch: 81 [38400/50000 (77%)]	Loss: 1.513499
#
# Train set for client: Accuracy: 46497/50000 (93%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8927/10000 (89%)
#
# Train Epoch: 82 [0/50000 (0%)]	Loss: 1.532769
# Train Epoch: 82 [38400/50000 (77%)]	Loss: 1.535275
#
# Train set for client: Accuracy: 46729/50000 (93%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8953/10000 (90%)
#
# Train Epoch: 83 [0/50000 (0%)]	Loss: 1.536569
# Train Epoch: 83 [38400/50000 (77%)]	Loss: 1.550296
#
# Train set for client: Accuracy: 46771/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8965/10000 (90%)
#
# Train Epoch: 84 [0/50000 (0%)]	Loss: 1.530874
# Train Epoch: 84 [38400/50000 (77%)]	Loss: 1.537121
#
# Train set for client: Accuracy: 46777/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8969/10000 (90%)
#
# Train Epoch: 85 [0/50000 (0%)]	Loss: 1.505009
# Train Epoch: 85 [38400/50000 (77%)]	Loss: 1.534708
#
# Train set for client: Accuracy: 46983/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8924/10000 (89%)
#
# Train Epoch: 86 [0/50000 (0%)]	Loss: 1.548206
# Train Epoch: 86 [38400/50000 (77%)]	Loss: 1.502222
#
# Train set for client: Accuracy: 47024/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8967/10000 (90%)
#
# Train Epoch: 87 [0/50000 (0%)]	Loss: 1.503300
# Train Epoch: 87 [38400/50000 (77%)]	Loss: 1.529466
#
# Train set for client: Accuracy: 46921/50000 (94%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 8969/10000 (90%)
#
# Train Epoch: 88 [0/50000 (0%)]	Loss: 1.522510
# Train Epoch: 88 [38400/50000 (77%)]	Loss: 1.477410
#
# Train set for client: Accuracy: 47002/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8880/10000 (89%)
#
# Train Epoch: 89 [0/50000 (0%)]	Loss: 1.494695
# Train Epoch: 89 [38400/50000 (77%)]	Loss: 1.537071
#
# Train set for client: Accuracy: 47067/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8911/10000 (89%)
#
# Train Epoch: 90 [0/50000 (0%)]	Loss: 1.519483
# Train Epoch: 90 [38400/50000 (77%)]	Loss: 1.510892
#
# Train set for client: Accuracy: 47086/50000 (94%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9012/10000 (90%)
#
# Train Epoch: 91 [0/50000 (0%)]	Loss: 1.529192
# Train Epoch: 91 [38400/50000 (77%)]	Loss: 1.525293
#
# Train set for client: Accuracy: 47047/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8932/10000 (89%)
#
# Train Epoch: 92 [0/50000 (0%)]	Loss: 1.507535
# Train Epoch: 92 [38400/50000 (77%)]	Loss: 1.531137
#
# Train set for client: Accuracy: 47213/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8914/10000 (89%)
#
# Train Epoch: 93 [0/50000 (0%)]	Loss: 1.516846
# Train Epoch: 93 [38400/50000 (77%)]	Loss: 1.530626
#
# Train set for client: Accuracy: 47186/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8869/10000 (89%)
#
# Train Epoch: 94 [0/50000 (0%)]	Loss: 1.524143
# Train Epoch: 94 [38400/50000 (77%)]	Loss: 1.492141
#
# Train set for client: Accuracy: 47186/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8907/10000 (89%)
#
# Train Epoch: 95 [0/50000 (0%)]	Loss: 1.566810
# Train Epoch: 95 [38400/50000 (77%)]	Loss: 1.518208
#
# Train set for client: Accuracy: 47194/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8978/10000 (90%)
#
# Train Epoch: 96 [0/50000 (0%)]	Loss: 1.524504
# Train Epoch: 96 [38400/50000 (77%)]	Loss: 1.485139
#
# Train set for client: Accuracy: 47249/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8942/10000 (89%)
#
# Train Epoch: 97 [0/50000 (0%)]	Loss: 1.505804
# Train Epoch: 97 [38400/50000 (77%)]	Loss: 1.544846
#
# Train set for client: Accuracy: 47345/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8965/10000 (90%)
#
# Train Epoch: 98 [0/50000 (0%)]	Loss: 1.519975
# Train Epoch: 98 [38400/50000 (77%)]	Loss: 1.494922
#
# Train set for client: Accuracy: 47333/50000 (95%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 8990/10000 (90%)
#
# Train Epoch: 99 [0/50000 (0%)]	Loss: 1.488647
# Train Epoch: 99 [38400/50000 (77%)]	Loss: 1.543715
#
# Train set for client: Accuracy: 47317/50000 (95%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 8980/10000 (90%)
#
# Train Epoch: 100 [0/50000 (0%)]	Loss: 1.514740
# Train Epoch: 100 [38400/50000 (77%)]	Loss: 1.516323
#
# Train set for client: Accuracy: 47253/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8892/10000 (89%)
#
# Train Epoch: 101 [0/50000 (0%)]	Loss: 1.510801
# Train Epoch: 101 [38400/50000 (77%)]	Loss: 1.530547
#
# Train set for client: Accuracy: 47272/50000 (95%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9005/10000 (90%)
#
# Train Epoch: 102 [0/50000 (0%)]	Loss: 1.512551
# Train Epoch: 102 [38400/50000 (77%)]	Loss: 1.493376
#
# Train set for client: Accuracy: 47364/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8958/10000 (90%)
#
# Train Epoch: 103 [0/50000 (0%)]	Loss: 1.516938
# Train Epoch: 103 [38400/50000 (77%)]	Loss: 1.514898
#
# Train set for client: Accuracy: 47338/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8949/10000 (89%)
#
# Train Epoch: 104 [0/50000 (0%)]	Loss: 1.499146
# Train Epoch: 104 [38400/50000 (77%)]	Loss: 1.503989
#
# Train set for client: Accuracy: 47356/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8968/10000 (90%)
#
# Train Epoch: 105 [0/50000 (0%)]	Loss: 1.500808
# Train Epoch: 105 [38400/50000 (77%)]	Loss: 1.527294
#
# Train set for client: Accuracy: 47343/50000 (95%)
#
#
# Test set for client: Average loss: 0.0125, Accuracy: 8839/10000 (88%)
#
# Train Epoch: 106 [0/50000 (0%)]	Loss: 1.547797
# Train Epoch: 106 [38400/50000 (77%)]	Loss: 1.496752
#
# Train set for client: Accuracy: 47346/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8931/10000 (89%)
#
# Train Epoch: 107 [0/50000 (0%)]	Loss: 1.511024
# Train Epoch: 107 [38400/50000 (77%)]	Loss: 1.530251
#
# Train set for client: Accuracy: 47349/50000 (95%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 8976/10000 (90%)
#
# Train Epoch: 108 [0/50000 (0%)]	Loss: 1.543559
# Train Epoch: 108 [38400/50000 (77%)]	Loss: 1.518395
#
# Train set for client: Accuracy: 47358/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8959/10000 (90%)
#
# Train Epoch: 109 [0/50000 (0%)]	Loss: 1.560831
# Train Epoch: 109 [38400/50000 (77%)]	Loss: 1.493335
#
# Train set for client: Accuracy: 47446/50000 (95%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 8983/10000 (90%)
#
# Train Epoch: 110 [0/50000 (0%)]	Loss: 1.546021
# Train Epoch: 110 [38400/50000 (77%)]	Loss: 1.520399
#
# Train set for client: Accuracy: 47407/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8956/10000 (90%)
#
# Train Epoch: 111 [0/50000 (0%)]	Loss: 1.498176
# Train Epoch: 111 [38400/50000 (77%)]	Loss: 1.515239
#
# Train set for client: Accuracy: 47393/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8859/10000 (89%)
#
# Train Epoch: 112 [0/50000 (0%)]	Loss: 1.525113
# Train Epoch: 112 [38400/50000 (77%)]	Loss: 1.494395
#
# Train set for client: Accuracy: 47392/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8845/10000 (88%)
#
# Train Epoch: 113 [0/50000 (0%)]	Loss: 1.523284
# Train Epoch: 113 [38400/50000 (77%)]	Loss: 1.520202
#
# Train set for client: Accuracy: 47363/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8963/10000 (90%)
#
# Train Epoch: 114 [0/50000 (0%)]	Loss: 1.513994
# Train Epoch: 114 [38400/50000 (77%)]	Loss: 1.501928
#
# Train set for client: Accuracy: 47460/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8886/10000 (89%)
#
# Train Epoch: 115 [0/50000 (0%)]	Loss: 1.524394
# Train Epoch: 115 [38400/50000 (77%)]	Loss: 1.492122
#
# Train set for client: Accuracy: 47371/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8963/10000 (90%)
#
# Train Epoch: 116 [0/50000 (0%)]	Loss: 1.511962
# Train Epoch: 116 [38400/50000 (77%)]	Loss: 1.477212
#
# Train set for client: Accuracy: 47384/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8879/10000 (89%)
#
# Train Epoch: 117 [0/50000 (0%)]	Loss: 1.530192
# Train Epoch: 117 [38400/50000 (77%)]	Loss: 1.491037
#
# Train set for client: Accuracy: 47356/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8945/10000 (89%)
#
# Train Epoch: 118 [0/50000 (0%)]	Loss: 1.501011
# Train Epoch: 118 [38400/50000 (77%)]	Loss: 1.514911
#
# Train set for client: Accuracy: 47382/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8917/10000 (89%)
#
# Train Epoch: 119 [0/50000 (0%)]	Loss: 1.500466
# Train Epoch: 119 [38400/50000 (77%)]	Loss: 1.522986
#
# Train set for client: Accuracy: 47478/50000 (95%)
#
#
# Test set for client: Average loss: 0.0125, Accuracy: 8827/10000 (88%)
#
# Train Epoch: 120 [0/50000 (0%)]	Loss: 1.509485
# Train Epoch: 120 [38400/50000 (77%)]	Loss: 1.483460
#
# Train set for client: Accuracy: 47872/50000 (96%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9056/10000 (91%)
#
# Train Epoch: 121 [0/50000 (0%)]	Loss: 1.517878
# Train Epoch: 121 [38400/50000 (77%)]	Loss: 1.477446
#
# Train set for client: Accuracy: 48122/50000 (96%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9064/10000 (91%)
#
# Train Epoch: 122 [0/50000 (0%)]	Loss: 1.519766
# Train Epoch: 122 [38400/50000 (77%)]	Loss: 1.480257
#
# Train set for client: Accuracy: 48081/50000 (96%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9118/10000 (91%)
#
# Train Epoch: 123 [0/50000 (0%)]	Loss: 1.492121
# Train Epoch: 123 [38400/50000 (77%)]	Loss: 1.493652
#
# Train set for client: Accuracy: 48187/50000 (96%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9071/10000 (91%)
#
# Train Epoch: 124 [0/50000 (0%)]	Loss: 1.500424
# Train Epoch: 124 [38400/50000 (77%)]	Loss: 1.486312
#
# Train set for client: Accuracy: 48255/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9042/10000 (90%)
#
# Train Epoch: 125 [0/50000 (0%)]	Loss: 1.486499
# Train Epoch: 125 [38400/50000 (77%)]	Loss: 1.485276
#
# Train set for client: Accuracy: 48210/50000 (96%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9109/10000 (91%)
#
# Train Epoch: 126 [0/50000 (0%)]	Loss: 1.513969
# Train Epoch: 126 [38400/50000 (77%)]	Loss: 1.504533
#
# Train set for client: Accuracy: 48385/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9077/10000 (91%)
#
# Train Epoch: 127 [0/50000 (0%)]	Loss: 1.493048
# Train Epoch: 127 [38400/50000 (77%)]	Loss: 1.494511
#
# Train set for client: Accuracy: 48375/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9117/10000 (91%)
#
# Train Epoch: 128 [0/50000 (0%)]	Loss: 1.478918
# Train Epoch: 128 [38400/50000 (77%)]	Loss: 1.475320
#
# Train set for client: Accuracy: 48367/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9092/10000 (91%)
#
# Train Epoch: 129 [0/50000 (0%)]	Loss: 1.482552
# Train Epoch: 129 [38400/50000 (77%)]	Loss: 1.480342
#
# Train set for client: Accuracy: 48377/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9076/10000 (91%)
#
# Train Epoch: 130 [0/50000 (0%)]	Loss: 1.512797
# Train Epoch: 130 [38400/50000 (77%)]	Loss: 1.541615
#
# Train set for client: Accuracy: 48451/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9121/10000 (91%)
#
# Train Epoch: 131 [0/50000 (0%)]	Loss: 1.479704
# Train Epoch: 131 [38400/50000 (77%)]	Loss: 1.486267
#
# Train set for client: Accuracy: 48477/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9126/10000 (91%)
#
# Train Epoch: 132 [0/50000 (0%)]	Loss: 1.511257
# Train Epoch: 132 [38400/50000 (77%)]	Loss: 1.478016
#
# Train set for client: Accuracy: 48504/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9108/10000 (91%)
#
# Train Epoch: 133 [0/50000 (0%)]	Loss: 1.469763
# Train Epoch: 133 [38400/50000 (77%)]	Loss: 1.482990
#
# Train set for client: Accuracy: 48444/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9116/10000 (91%)
#
# Train Epoch: 134 [0/50000 (0%)]	Loss: 1.486629
# Train Epoch: 134 [38400/50000 (77%)]	Loss: 1.481918
#
# Train set for client: Accuracy: 48420/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9075/10000 (91%)
#
# Train Epoch: 135 [0/50000 (0%)]	Loss: 1.476201
# Train Epoch: 135 [38400/50000 (77%)]	Loss: 1.488362
#
# Train set for client: Accuracy: 48506/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9082/10000 (91%)
#
# Train Epoch: 136 [0/50000 (0%)]	Loss: 1.509698
# Train Epoch: 136 [38400/50000 (77%)]	Loss: 1.485643
#
# Train set for client: Accuracy: 48537/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9099/10000 (91%)
#
# Train Epoch: 137 [0/50000 (0%)]	Loss: 1.507964
# Train Epoch: 137 [38400/50000 (77%)]	Loss: 1.521067
#
# Train set for client: Accuracy: 48547/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9080/10000 (91%)
#
# Train Epoch: 138 [0/50000 (0%)]	Loss: 1.489443
# Train Epoch: 138 [38400/50000 (77%)]	Loss: 1.485643
#
# Train set for client: Accuracy: 48596/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9081/10000 (91%)
#
# Train Epoch: 139 [0/50000 (0%)]	Loss: 1.501060
# Train Epoch: 139 [38400/50000 (77%)]	Loss: 1.493386
#
# Train set for client: Accuracy: 48511/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9101/10000 (91%)
#
# Train Epoch: 140 [0/50000 (0%)]	Loss: 1.497141
# Train Epoch: 140 [38400/50000 (77%)]	Loss: 1.496938
#
# Train set for client: Accuracy: 48546/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9097/10000 (91%)
#
# Train Epoch: 141 [0/50000 (0%)]	Loss: 1.490469
# Train Epoch: 141 [38400/50000 (77%)]	Loss: 1.495842
#
# Train set for client: Accuracy: 48551/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9078/10000 (91%)
#
# Train Epoch: 142 [0/50000 (0%)]	Loss: 1.484824
# Train Epoch: 142 [38400/50000 (77%)]	Loss: 1.488032
#
# Train set for client: Accuracy: 48589/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9081/10000 (91%)
#
# Train Epoch: 143 [0/50000 (0%)]	Loss: 1.484749
# Train Epoch: 143 [38400/50000 (77%)]	Loss: 1.490948
#
# Train set for client: Accuracy: 48577/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9050/10000 (90%)
#
# Train Epoch: 144 [0/50000 (0%)]	Loss: 1.469561
# Train Epoch: 144 [38400/50000 (77%)]	Loss: 1.484492
#
# Train set for client: Accuracy: 48588/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9077/10000 (91%)
#
# Train Epoch: 145 [0/50000 (0%)]	Loss: 1.516831
# Train Epoch: 145 [38400/50000 (77%)]	Loss: 1.494624
#
# Train set for client: Accuracy: 48581/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9028/10000 (90%)
#
# Train Epoch: 146 [0/50000 (0%)]	Loss: 1.493516
# Train Epoch: 146 [38400/50000 (77%)]	Loss: 1.477770
#
# Train set for client: Accuracy: 48653/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9091/10000 (91%)
#
# Train Epoch: 147 [0/50000 (0%)]	Loss: 1.480540
# Train Epoch: 147 [38400/50000 (77%)]	Loss: 1.483672
#
# Train set for client: Accuracy: 48656/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9088/10000 (91%)
#
# Train Epoch: 148 [0/50000 (0%)]	Loss: 1.507693
# Train Epoch: 148 [38400/50000 (77%)]	Loss: 1.474738
#
# Train set for client: Accuracy: 48670/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9109/10000 (91%)
#
# Train Epoch: 149 [0/50000 (0%)]	Loss: 1.500544
# Train Epoch: 149 [38400/50000 (77%)]	Loss: 1.492743
#
# Train set for client: Accuracy: 48735/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9109/10000 (91%)
#
# Train Epoch: 150 [0/50000 (0%)]	Loss: 1.477003
# Train Epoch: 150 [38400/50000 (77%)]	Loss: 1.477968
#
# Train set for client: Accuracy: 48708/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9135/10000 (91%)
#
# Train Epoch: 151 [0/50000 (0%)]	Loss: 1.478440
# Train Epoch: 151 [38400/50000 (77%)]	Loss: 1.494987
#
# Train set for client: Accuracy: 48745/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9121/10000 (91%)
#
# Train Epoch: 152 [0/50000 (0%)]	Loss: 1.497465
# Train Epoch: 152 [38400/50000 (77%)]	Loss: 1.476666
#
# Train set for client: Accuracy: 48663/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9093/10000 (91%)
#
# Train Epoch: 153 [0/50000 (0%)]	Loss: 1.501790
# Train Epoch: 153 [38400/50000 (77%)]	Loss: 1.487696
#
# Train set for client: Accuracy: 48652/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9115/10000 (91%)
#
# Train Epoch: 154 [0/50000 (0%)]	Loss: 1.489000
# Train Epoch: 154 [38400/50000 (77%)]	Loss: 1.462017
#
# Train set for client: Accuracy: 48728/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9115/10000 (91%)
#
# Train Epoch: 155 [0/50000 (0%)]	Loss: 1.477715
# Train Epoch: 155 [38400/50000 (77%)]	Loss: 1.495926
#
# Train set for client: Accuracy: 48758/50000 (98%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9095/10000 (91%)
#
# Train Epoch: 156 [0/50000 (0%)]	Loss: 1.486639
# Train Epoch: 156 [38400/50000 (77%)]	Loss: 1.483167
#
# Train set for client: Accuracy: 48674/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9117/10000 (91%)
#
# Train Epoch: 157 [0/50000 (0%)]	Loss: 1.486378
# Train Epoch: 157 [38400/50000 (77%)]	Loss: 1.497884
#
# Train set for client: Accuracy: 48713/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9114/10000 (91%)
#
# Train Epoch: 158 [0/50000 (0%)]	Loss: 1.480694
# Train Epoch: 158 [38400/50000 (77%)]	Loss: 1.470353
#
# Train set for client: Accuracy: 48770/50000 (98%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9079/10000 (91%)
#
# Train Epoch: 159 [0/50000 (0%)]	Loss: 1.497532
# Train Epoch: 159 [38400/50000 (77%)]	Loss: 1.477265
#
# Train set for client: Accuracy: 48791/50000 (98%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9079/10000 (91%)
#
# Train Epoch: 160 [0/50000 (0%)]	Loss: 1.478992
# Train Epoch: 160 [38400/50000 (77%)]	Loss: 1.487242
#
# Train set for client: Accuracy: 48907/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9149/10000 (91%)
#
# Train Epoch: 161 [0/50000 (0%)]	Loss: 1.477248
# Train Epoch: 161 [38400/50000 (77%)]	Loss: 1.469572
#
# Train set for client: Accuracy: 48975/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9125/10000 (91%)
#
# Train Epoch: 162 [0/50000 (0%)]	Loss: 1.485265
# Train Epoch: 162 [38400/50000 (77%)]	Loss: 1.514164
#
# Train set for client: Accuracy: 48960/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9151/10000 (92%)
#
# Train Epoch: 163 [0/50000 (0%)]	Loss: 1.470544
# Train Epoch: 163 [38400/50000 (77%)]	Loss: 1.484295
#
# Train set for client: Accuracy: 49050/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9150/10000 (92%)
#
# Train Epoch: 164 [0/50000 (0%)]	Loss: 1.479568
# Train Epoch: 164 [38400/50000 (77%)]	Loss: 1.477339
#
# Train set for client: Accuracy: 49047/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9146/10000 (91%)
#
# Train Epoch: 165 [0/50000 (0%)]	Loss: 1.471770
# Train Epoch: 165 [38400/50000 (77%)]	Loss: 1.466904
#
# Train set for client: Accuracy: 49045/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9139/10000 (91%)
#
# Train Epoch: 166 [0/50000 (0%)]	Loss: 1.516208
# Train Epoch: 166 [38400/50000 (77%)]	Loss: 1.485317
#
# Train set for client: Accuracy: 49052/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9146/10000 (91%)
#
# Train Epoch: 167 [0/50000 (0%)]	Loss: 1.485990
# Train Epoch: 167 [38400/50000 (77%)]	Loss: 1.501000
#
# Train set for client: Accuracy: 49075/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9155/10000 (92%)
#
# Train Epoch: 168 [0/50000 (0%)]	Loss: 1.517183
# Train Epoch: 168 [38400/50000 (77%)]	Loss: 1.470476
#
# Train set for client: Accuracy: 49086/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9153/10000 (92%)
#
# Train Epoch: 169 [0/50000 (0%)]	Loss: 1.481413
# Train Epoch: 169 [38400/50000 (77%)]	Loss: 1.463166
#
# Train set for client: Accuracy: 49084/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9160/10000 (92%)
#
# Train Epoch: 170 [0/50000 (0%)]	Loss: 1.508774
# Train Epoch: 170 [38400/50000 (77%)]	Loss: 1.467686
#
# Train set for client: Accuracy: 49088/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9164/10000 (92%)
#
# Train Epoch: 171 [0/50000 (0%)]	Loss: 1.493120
# Train Epoch: 171 [38400/50000 (77%)]	Loss: 1.486164
#
# Train set for client: Accuracy: 49136/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9141/10000 (91%)
#
# Train Epoch: 172 [0/50000 (0%)]	Loss: 1.469596
# Train Epoch: 172 [38400/50000 (77%)]	Loss: 1.461726
#
# Train set for client: Accuracy: 49104/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9161/10000 (92%)
#
# Train Epoch: 173 [0/50000 (0%)]	Loss: 1.479849
# Train Epoch: 173 [38400/50000 (77%)]	Loss: 1.462518
#
# Train set for client: Accuracy: 49128/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9170/10000 (92%)
#
# Train Epoch: 174 [0/50000 (0%)]	Loss: 1.481990
# Train Epoch: 174 [38400/50000 (77%)]	Loss: 1.462121
#
# Train set for client: Accuracy: 49136/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9157/10000 (92%)
#
# Train Epoch: 175 [0/50000 (0%)]	Loss: 1.461806
# Train Epoch: 175 [38400/50000 (77%)]	Loss: 1.477813
#
# Train set for client: Accuracy: 49174/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9148/10000 (91%)
#
# Train Epoch: 176 [0/50000 (0%)]	Loss: 1.470621
# Train Epoch: 176 [38400/50000 (77%)]	Loss: 1.469748
#
# Train set for client: Accuracy: 49138/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9160/10000 (92%)
#
# Train Epoch: 177 [0/50000 (0%)]	Loss: 1.469872
# Train Epoch: 177 [38400/50000 (77%)]	Loss: 1.477429
#
# Train set for client: Accuracy: 49165/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9145/10000 (91%)
#
# Train Epoch: 178 [0/50000 (0%)]	Loss: 1.482711
# Train Epoch: 178 [38400/50000 (77%)]	Loss: 1.477897
#
# Train set for client: Accuracy: 49163/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9152/10000 (92%)
#
# Train Epoch: 179 [0/50000 (0%)]	Loss: 1.470203
# Train Epoch: 179 [38400/50000 (77%)]	Loss: 1.485201
#
# Train set for client: Accuracy: 49175/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9162/10000 (92%)
#
# Train Epoch: 180 [0/50000 (0%)]	Loss: 1.477758
# Train Epoch: 180 [38400/50000 (77%)]	Loss: 1.493030
#
# Train set for client: Accuracy: 49192/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9128/10000 (91%)
#
# Train Epoch: 181 [0/50000 (0%)]	Loss: 1.491728
# Train Epoch: 181 [38400/50000 (77%)]	Loss: 1.470082
#
# Train set for client: Accuracy: 49208/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9139/10000 (91%)
#
# Train Epoch: 182 [0/50000 (0%)]	Loss: 1.481771
# Train Epoch: 182 [38400/50000 (77%)]	Loss: 1.465966
#
# Train set for client: Accuracy: 49224/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9165/10000 (92%)
#
# Train Epoch: 183 [0/50000 (0%)]	Loss: 1.472614
# Train Epoch: 183 [38400/50000 (77%)]	Loss: 1.470562
#
# Train set for client: Accuracy: 49220/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9160/10000 (92%)
#
# Train Epoch: 184 [0/50000 (0%)]	Loss: 1.477311
# Train Epoch: 184 [38400/50000 (77%)]	Loss: 1.469518
#
# Train set for client: Accuracy: 49201/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9156/10000 (92%)
#
# Train Epoch: 185 [0/50000 (0%)]	Loss: 1.478513
# Train Epoch: 185 [38400/50000 (77%)]	Loss: 1.477568
#
# Train set for client: Accuracy: 49206/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9156/10000 (92%)
#
# Train Epoch: 186 [0/50000 (0%)]	Loss: 1.494806
# Train Epoch: 186 [38400/50000 (77%)]	Loss: 1.462144
#
# Train set for client: Accuracy: 49215/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9142/10000 (91%)
#
# Train Epoch: 187 [0/50000 (0%)]	Loss: 1.483624
# Train Epoch: 187 [38400/50000 (77%)]	Loss: 1.470914
#
# Train set for client: Accuracy: 49245/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9146/10000 (91%)
#
# Train Epoch: 188 [0/50000 (0%)]	Loss: 1.477434
# Train Epoch: 188 [38400/50000 (77%)]	Loss: 1.485336
#
# Train set for client: Accuracy: 49238/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9165/10000 (92%)
#
# Train Epoch: 189 [0/50000 (0%)]	Loss: 1.473819
# Train Epoch: 189 [38400/50000 (77%)]	Loss: 1.474309
#
# Train set for client: Accuracy: 49251/50000 (99%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9175/10000 (92%)
#
# Train Epoch: 190 [0/50000 (0%)]	Loss: 1.477041
# Train Epoch: 190 [38400/50000 (77%)]	Loss: 1.475155
#
# Train set for client: Accuracy: 49214/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9159/10000 (92%)
#
# Train Epoch: 191 [0/50000 (0%)]	Loss: 1.469882
# Train Epoch: 191 [38400/50000 (77%)]	Loss: 1.461899
#
# Train set for client: Accuracy: 49230/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9172/10000 (92%)
#
# Train Epoch: 192 [0/50000 (0%)]	Loss: 1.480402
# Train Epoch: 192 [38400/50000 (77%)]	Loss: 1.485078
#
# Train set for client: Accuracy: 49253/50000 (99%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9172/10000 (92%)
#
# Train Epoch: 193 [0/50000 (0%)]	Loss: 1.476803
# Train Epoch: 193 [38400/50000 (77%)]	Loss: 1.490641
#
# Train set for client: Accuracy: 49236/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9140/10000 (91%)
#
# Train Epoch: 194 [0/50000 (0%)]	Loss: 1.470525
# Train Epoch: 194 [38400/50000 (77%)]	Loss: 1.477477
#
# Train set for client: Accuracy: 49255/50000 (99%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9166/10000 (92%)
#
# Train Epoch: 195 [0/50000 (0%)]	Loss: 1.483694
# Train Epoch: 195 [38400/50000 (77%)]	Loss: 1.480623
#
# Train set for client: Accuracy: 49246/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9167/10000 (92%)
#
# Train Epoch: 196 [0/50000 (0%)]	Loss: 1.469897
# Train Epoch: 196 [38400/50000 (77%)]	Loss: 1.492434
#
# Train set for client: Accuracy: 49282/50000 (99%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9150/10000 (92%)
#
# Train Epoch: 197 [0/50000 (0%)]	Loss: 1.477660
# Train Epoch: 197 [38400/50000 (77%)]	Loss: 1.467079
#
# Train set for client: Accuracy: 49267/50000 (99%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9148/10000 (91%)
#
# Train Epoch: 198 [0/50000 (0%)]	Loss: 1.477184
# Train Epoch: 198 [38400/50000 (77%)]	Loss: 1.483050
#
# Train set for client: Accuracy: 49273/50000 (99%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9143/10000 (91%)
#
# Train Epoch: 199 [0/50000 (0%)]	Loss: 1.483801
# Train Epoch: 199 [38400/50000 (77%)]	Loss: 1.477473
#
# Train set for client: Accuracy: 49242/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9168/10000 (92%)

# %%
def train_model(clients,client_optimisers,server,server_optimiser,device,train_loader,epoch):
    for client in clients:
        client.train()
    server.train()
    criterion = nn.CrossEntropyLoss()
    correct = 0
    client = clients[0]
    client_optimiser = client_optimisers[0]
    for batch_idx, (data, target) in enumerate(train_loader):        
        data, target = data.to(device), target.to(device)
        server_optimiser.zero_grad()
        client_optimiser.zero_grad()

        ### execute client - feed forward network
        intermediate = client(data)
        remote = intermediate.detach().requires_grad_()
        ### execute server - feed forward network
        output = server(remote)
        loss = criterion(output,target)
        loss.backward()
        ### execute client back propagation
        grad = remote.grad.clone()
        intermediate.backward(grad)
        ### optimiser step
        server_optimiser.step()
        client_optimiser.step()

        pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()
        ### printing logs
        if batch_idx % 300 == 0:
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
    
    print('\nTrain set for client: Accuracy: {}/{} ({:.0f}%)\n'.format(
        correct, len(train_loader.dataset),
        100. * correct / len(train_loader.dataset)))

def adjust_learning_rate(optimizer, init_lr, epoch):
    lr = init_lr * (0.5 ** (epoch // 40))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

def test_model(clients,server,device,test_loader):
    for client in clients:
        client.eval()
    server.eval()
    criterion = nn.CrossEntropyLoss()
    for client in clients:
        with torch.no_grad():
            test_loss = 0
            correct = 0
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                intermediate = client(data)
                output = server(intermediate)
                test_loss += criterion(output, target).item()  # sum up batch loss
                pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
                correct += pred.eq(target.view_as(pred)).sum().item()
            
            test_loss /= len(test_loader.dataset)
            print('\nTest set for client: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
                test_loss, correct, len(test_loader.dataset),
                100. * correct / len(test_loader.dataset)))

if __name__ == "__main__":
    random.seed(7)
    torch.manual_seed(7)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    if torch.cuda.is_available():  
        dev = "cuda:0" 
    else:  
        dev = "cpu"
    device = torch.device(dev)

    train_loader,test_loader = get_cifar10_dataset(batch_size=128)

    clients=[]
    client_optimisers = []
    for i in range(1):
        client = vgg_client(input_channels=3,output_channels=10).to(device)
        client_optim = optim.SGD(client.parameters(),lr=1e-3,weight_decay=5e-4)
        clients.append(client)
        client_optimisers.append(client_optim)

    server = vgg_server(input_channels=256,output_channels=10).to(device)
    server_optim = optim.SGD(server.parameters(),lr=1e-3,weight_decay=5e-4)

    print("\n\nModel Summary")
    print("\nClient:")
    summary(clients[0],(3,32,32))
    print("\n\nServer:")
    summary(server,(256,4,4))

    init_lr = 0.1
    for i in range(1,200):
        for optimiser in client_optimisers:
            adjust_learning_rate(optimiser,init_lr,i)
        adjust_learning_rate(server_optim,init_lr,i)
        train_model(clients,client_optimisers,server,server_optim,device,train_loader,i)
        history1 = test_model(clients,server,device,test_loader)
    
    torch.save({'server':server.state_dict(),
            'client':clients[0].state_dict()},"split-model-single-agent.pt")
# Out:
# Files already downloaded and verified
#
#
# Model Summary
#
# Client:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#             Conv2d-4           [-1, 64, 32, 32]          36,928
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#               ReLU-6           [-1, 64, 32, 32]               0
#          MaxPool2d-7           [-1, 64, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]          73,856
#        BatchNorm2d-9          [-1, 128, 16, 16]             256
#              ReLU-10          [-1, 128, 16, 16]               0
#            Conv2d-11          [-1, 128, 16, 16]         147,584
#       BatchNorm2d-12          [-1, 128, 16, 16]             256
#              ReLU-13          [-1, 128, 16, 16]               0
#         MaxPool2d-14            [-1, 128, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         295,168
#       BatchNorm2d-16            [-1, 256, 8, 8]             512
#              ReLU-17            [-1, 256, 8, 8]               0
#            Conv2d-18            [-1, 256, 8, 8]         590,080
#       BatchNorm2d-19            [-1, 256, 8, 8]             512
#              ReLU-20            [-1, 256, 8, 8]               0
#            Conv2d-21            [-1, 256, 8, 8]         590,080
#       BatchNorm2d-22            [-1, 256, 8, 8]             512
#              ReLU-23            [-1, 256, 8, 8]               0
#         MaxPool2d-24            [-1, 256, 4, 4]               0
# ================================================================
# Total params: 1,737,792
# Trainable params: 1,737,792
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.84
# Params size (MB): 6.63
# Estimated Total Size (MB): 12.48
# ----------------------------------------------------------------
#
#
# Server:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 512, 4, 4]       1,180,160
#        BatchNorm2d-2            [-1, 512, 4, 4]           1,024
#               ReLU-3            [-1, 512, 4, 4]               0
#             Conv2d-4            [-1, 512, 4, 4]       2,359,808
#        BatchNorm2d-5            [-1, 512, 4, 4]           1,024
#               ReLU-6            [-1, 512, 4, 4]               0
#             Conv2d-7            [-1, 512, 4, 4]       2,359,808
#        BatchNorm2d-8            [-1, 512, 4, 4]           1,024
#               ReLU-9            [-1, 512, 4, 4]               0
#         MaxPool2d-10            [-1, 512, 2, 2]               0
#            Conv2d-11            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-12            [-1, 512, 2, 2]           1,024
#              ReLU-13            [-1, 512, 2, 2]               0
#            Conv2d-14            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-15            [-1, 512, 2, 2]           1,024
#              ReLU-16            [-1, 512, 2, 2]               0
#            Conv2d-17            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-18            [-1, 512, 2, 2]           1,024
#              ReLU-19            [-1, 512, 2, 2]               0
#         MaxPool2d-20            [-1, 512, 1, 1]               0
#           Flatten-21                  [-1, 512]               0
#            Linear-22                  [-1, 256]         131,328
#              ReLU-23                  [-1, 256]               0
#           Dropout-24                  [-1, 256]               0
#            Linear-25                  [-1, 128]          32,896
#              ReLU-26                  [-1, 128]               0
#           Dropout-27                  [-1, 128]               0
#            Linear-28                   [-1, 10]           1,290
#           Softmax-29                   [-1, 10]               0
# ================================================================
# Total params: 13,150,858
# Trainable params: 13,150,858
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 0.74
# Params size (MB): 50.17
# Estimated Total Size (MB): 50.92
# ----------------------------------------------------------------
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.304022
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 2.010779
#
# Train set for client: Accuracy: 15877/50000 (32%)
#
#
# Test set for client: Average loss: 0.0163, Accuracy: 3895/10000 (39%)
# Train Epoch: 2 [0/50000 (0%)]	Loss: 2.055211
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 1.853929
#
# Train set for client: Accuracy: 24499/50000 (49%)
#
#
# Test set for client: Average loss: 0.0159, Accuracy: 4415/10000 (44%)
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.939476
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 1.930621
#
# Train set for client: Accuracy: 27793/50000 (56%)
#
#
# Test set for client: Average loss: 0.0152, Accuracy: 5271/10000 (53%)
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.944682
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 1.815469
#
# Train set for client: Accuracy: 30589/50000 (61%)
#
#
# Test set for client: Average loss: 0.0160, Accuracy: 4337/10000 (43%)
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.838686
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 1.831273
#
# Train set for client: Accuracy: 32349/50000 (65%)
#
#
# Test set for client: Average loss: 0.0147, Accuracy: 6012/10000 (60%)
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.745779
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 1.857710
#
# Train set for client: Accuracy: 33588/50000 (67%)
#
#
# Test set for client: Average loss: 0.0142, Accuracy: 6628/10000 (66%)
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.801122
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 1.763734
#
# Train set for client: Accuracy: 34526/50000 (69%)
#
#
# Test set for client: Average loss: 0.0142, Accuracy: 6621/10000 (66%)
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.742188
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 1.751338
#
# Train set for client: Accuracy: 35522/50000 (71%)
#
#
# Test set for client: Average loss: 0.0140, Accuracy: 6832/10000 (68%)
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.752414
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 1.736377
#
# Train set for client: Accuracy: 36002/50000 (72%)
#
#
# Test set for client: Average loss: 0.0141, Accuracy: 6757/10000 (68%)
# Train Epoch: 10 [0/50000 (0%)]	Loss: 1.773374
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 1.726156
#
# Train set for client: Accuracy: 36540/50000 (73%)
#
#
# Test set for client: Average loss: 0.0138, Accuracy: 7076/10000 (71%)
# Train Epoch: 11 [0/50000 (0%)]	Loss: 1.695644
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 1.663441
#
# Train set for client: Accuracy: 37206/50000 (74%)
#
#
# Test set for client: Average loss: 0.0136, Accuracy: 7313/10000 (73%)
# Train Epoch: 12 [0/50000 (0%)]	Loss: 1.723926
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 1.722732
#
# Train set for client: Accuracy: 37651/50000 (75%)
#
#
# Test set for client: Average loss: 0.0141, Accuracy: 6689/10000 (67%)
# Train Epoch: 13 [0/50000 (0%)]	Loss: 1.647881
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 1.657169
#
# Train set for client: Accuracy: 37887/50000 (76%)
#
#
# Test set for client: Average loss: 0.0137, Accuracy: 7208/10000 (72%)
# Train Epoch: 14 [0/50000 (0%)]	Loss: 1.687511
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 1.666072
#
# Train set for client: Accuracy: 38273/50000 (77%)
#
#
# Test set for client: Average loss: 0.0136, Accuracy: 7413/10000 (74%)
# Train Epoch: 15 [0/50000 (0%)]	Loss: 1.778143
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 1.665162
#
# Train set for client: Accuracy: 38587/50000 (77%)
#
#
# Test set for client: Average loss: 0.0139, Accuracy: 7016/10000 (70%)
# Train Epoch: 16 [0/50000 (0%)]	Loss: 1.689267
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 1.721416
#
# Train set for client: Accuracy: 38779/50000 (78%)
#
#
# Test set for client: Average loss: 0.0136, Accuracy: 7418/10000 (74%)
# Train Epoch: 17 [0/50000 (0%)]	Loss: 1.673587
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 1.705708
#
# Train set for client: Accuracy: 39054/50000 (78%)
#
#
# Test set for client: Average loss: 0.0135, Accuracy: 7506/10000 (75%)
# Train Epoch: 18 [0/50000 (0%)]	Loss: 1.729865
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 1.624358
#
# Train set for client: Accuracy: 39230/50000 (78%)
#
#
# Test set for client: Average loss: 0.0133, Accuracy: 7818/10000 (78%)
# Train Epoch: 19 [0/50000 (0%)]	Loss: 1.675851
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 1.645385
#
# Train set for client: Accuracy: 39490/50000 (79%)
#
#
# Test set for client: Average loss: 0.0133, Accuracy: 7794/10000 (78%)
# Train Epoch: 20 [0/50000 (0%)]	Loss: 1.630627
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 1.680701
#
# Train set for client: Accuracy: 39714/50000 (79%)
#
#
# Test set for client: Average loss: 0.0133, Accuracy: 7717/10000 (77%)
# Train Epoch: 21 [0/50000 (0%)]	Loss: 1.675680
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 1.669196
#
# Train set for client: Accuracy: 39994/50000 (80%)
#
#
# Test set for client: Average loss: 0.0131, Accuracy: 8007/10000 (80%)
# Train Epoch: 22 [0/50000 (0%)]	Loss: 1.604291
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 1.627037
#
# Train set for client: Accuracy: 40163/50000 (80%)
#
#
# Test set for client: Average loss: 0.0134, Accuracy: 7632/10000 (76%)
# Train Epoch: 23 [0/50000 (0%)]	Loss: 1.603608
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 1.723111
#
# Train set for client: Accuracy: 40378/50000 (81%)
#
#
# Test set for client: Average loss: 0.0131, Accuracy: 7979/10000 (80%)
# Train Epoch: 24 [0/50000 (0%)]	Loss: 1.654268
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 1.640630
#
# Train set for client: Accuracy: 40572/50000 (81%)
#
#
# Test set for client: Average loss: 0.0131, Accuracy: 7977/10000 (80%)
# Train Epoch: 25 [0/50000 (0%)]	Loss: 1.622279
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 1.651299
#
# Train set for client: Accuracy: 40880/50000 (82%)
#
#
# Test set for client: Average loss: 0.0131, Accuracy: 7948/10000 (79%)
# Train Epoch: 26 [0/50000 (0%)]	Loss: 1.655696
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 1.652628
#
# Train set for client: Accuracy: 40938/50000 (82%)
#
#
# Test set for client: Average loss: 0.0131, Accuracy: 7994/10000 (80%)
# Train Epoch: 27 [0/50000 (0%)]	Loss: 1.679015
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 1.603528
#
# Train set for client: Accuracy: 41158/50000 (82%)
#
#
# Test set for client: Average loss: 0.0136, Accuracy: 7356/10000 (74%)
# Train Epoch: 28 [0/50000 (0%)]	Loss: 1.623163
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 1.677903
#
# Train set for client: Accuracy: 41208/50000 (82%)
#
#
# Test set for client: Average loss: 0.0131, Accuracy: 7978/10000 (80%)
# Train Epoch: 29 [0/50000 (0%)]	Loss: 1.610500
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 1.628702
#
# Train set for client: Accuracy: 41295/50000 (83%)
#
#
# Test set for client: Average loss: 0.0130, Accuracy: 8184/10000 (82%)
# Train Epoch: 30 [0/50000 (0%)]	Loss: 1.592082
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 1.612533
#
# Train set for client: Accuracy: 41496/50000 (83%)
#
#
# Test set for client: Average loss: 0.0134, Accuracy: 7640/10000 (76%)
# Train Epoch: 31 [0/50000 (0%)]	Loss: 1.648345
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 1.693939
#
# Train set for client: Accuracy: 41579/50000 (83%)
#
#
# Test set for client: Average loss: 0.0130, Accuracy: 8109/10000 (81%)
# Train Epoch: 32 [0/50000 (0%)]	Loss: 1.614414
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 1.645752
#
# Train set for client: Accuracy: 41737/50000 (83%)
#
#
# Test set for client: Average loss: 0.0132, Accuracy: 7844/10000 (78%)
# Train Epoch: 33 [0/50000 (0%)]	Loss: 1.664126
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 1.613804
#
# Train set for client: Accuracy: 41803/50000 (84%)
#
#
# Test set for client: Average loss: 0.0130, Accuracy: 8121/10000 (81%)
# Train Epoch: 34 [0/50000 (0%)]	Loss: 1.597741
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 1.588822
#
# Train set for client: Accuracy: 41803/50000 (84%)
#
#
# Test set for client: Average loss: 0.0135, Accuracy: 7483/10000 (75%)
# Train Epoch: 35 [0/50000 (0%)]	Loss: 1.600342
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 1.601417
#
# Train set for client: Accuracy: 42095/50000 (84%)
#
#
# Test set for client: Average loss: 0.0130, Accuracy: 8201/10000 (82%)
# Train Epoch: 36 [0/50000 (0%)]	Loss: 1.680919
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 1.634501
#
# Train set for client: Accuracy: 42175/50000 (84%)
#
#
# Test set for client: Average loss: 0.0132, Accuracy: 7858/10000 (79%)
# Train Epoch: 37 [0/50000 (0%)]	Loss: 1.595189
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 1.630811
#
# Train set for client: Accuracy: 42240/50000 (84%)
#
#
# Test set for client: Average loss: 0.0130, Accuracy: 8131/10000 (81%)
# Train Epoch: 38 [0/50000 (0%)]	Loss: 1.603591
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 1.621357
#
# Train set for client: Accuracy: 42468/50000 (85%)
#
#
# Test set for client: Average loss: 0.0132, Accuracy: 7931/10000 (79%)
# Train Epoch: 39 [0/50000 (0%)]	Loss: 1.630030
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 1.651063
#
# Train set for client: Accuracy: 42361/50000 (85%)
#
#
# Test set for client: Average loss: 0.0130, Accuracy: 8204/10000 (82%)
# Train Epoch: 40 [0/50000 (0%)]	Loss: 1.588025
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 1.595284
#
# Train set for client: Accuracy: 43598/50000 (87%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8581/10000 (86%)
# Train Epoch: 41 [0/50000 (0%)]	Loss: 1.563615
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 1.597380
#
# Train set for client: Accuracy: 43951/50000 (88%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8691/10000 (87%)
# Train Epoch: 42 [0/50000 (0%)]	Loss: 1.560452
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 1.582013
#
# Train set for client: Accuracy: 44185/50000 (88%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8477/10000 (85%)
# Train Epoch: 43 [0/50000 (0%)]	Loss: 1.579476
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 1.584691
#
# Train set for client: Accuracy: 44176/50000 (88%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8593/10000 (86%)
# Train Epoch: 44 [0/50000 (0%)]	Loss: 1.569423
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 1.519294
#
# Train set for client: Accuracy: 44286/50000 (89%)
#
#
# Test set for client: Average loss: 0.0129, Accuracy: 8253/10000 (83%)
# Train Epoch: 45 [0/50000 (0%)]	Loss: 1.542121
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 1.590961
#
# Train set for client: Accuracy: 44441/50000 (89%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8626/10000 (86%)
# Train Epoch: 46 [0/50000 (0%)]	Loss: 1.555962
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 1.546631
#
# Train set for client: Accuracy: 44390/50000 (89%)
#
#
# Test set for client: Average loss: 0.0128, Accuracy: 8347/10000 (83%)
# Train Epoch: 47 [0/50000 (0%)]	Loss: 1.573188
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 1.574921
#
# Train set for client: Accuracy: 44532/50000 (89%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8605/10000 (86%)
# Train Epoch: 48 [0/50000 (0%)]	Loss: 1.564168
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 1.606526
#
# Train set for client: Accuracy: 44547/50000 (89%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8642/10000 (86%)
# Train Epoch: 49 [0/50000 (0%)]	Loss: 1.560283
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 1.535688
#
# Train set for client: Accuracy: 44628/50000 (89%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8631/10000 (86%)
# Train Epoch: 50 [0/50000 (0%)]	Loss: 1.549300
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 1.557792
#
# Train set for client: Accuracy: 44666/50000 (89%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8549/10000 (85%)
# Train Epoch: 51 [0/50000 (0%)]	Loss: 1.549513
# Train Epoch: 51 [38400/50000 (77%)]	Loss: 1.585210
#
# Train set for client: Accuracy: 44674/50000 (89%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8626/10000 (86%)
# Train Epoch: 52 [0/50000 (0%)]	Loss: 1.541023
# Train Epoch: 52 [38400/50000 (77%)]	Loss: 1.589142
#
# Train set for client: Accuracy: 44746/50000 (89%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8527/10000 (85%)
# Train Epoch: 53 [0/50000 (0%)]	Loss: 1.558837
# Train Epoch: 53 [38400/50000 (77%)]	Loss: 1.561327
#
# Train set for client: Accuracy: 44840/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8605/10000 (86%)
# Train Epoch: 54 [0/50000 (0%)]	Loss: 1.661537
# Train Epoch: 54 [38400/50000 (77%)]	Loss: 1.579768
#
# Train set for client: Accuracy: 44864/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8648/10000 (86%)
# Train Epoch: 55 [0/50000 (0%)]	Loss: 1.558789
# Train Epoch: 55 [38400/50000 (77%)]	Loss: 1.530860
#
# Train set for client: Accuracy: 44622/50000 (89%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8660/10000 (87%)
# Train Epoch: 56 [0/50000 (0%)]	Loss: 1.600982
# Train Epoch: 56 [38400/50000 (77%)]	Loss: 1.570315
#
# Train set for client: Accuracy: 44879/50000 (90%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8550/10000 (86%)
# Train Epoch: 57 [0/50000 (0%)]	Loss: 1.536011
# Train Epoch: 57 [38400/50000 (77%)]	Loss: 1.513752
#
# Train set for client: Accuracy: 44934/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8649/10000 (86%)
# Train Epoch: 58 [0/50000 (0%)]	Loss: 1.536792
# Train Epoch: 58 [38400/50000 (77%)]	Loss: 1.570115
#
# Train set for client: Accuracy: 45018/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8632/10000 (86%)
# Train Epoch: 59 [0/50000 (0%)]	Loss: 1.563250
# Train Epoch: 59 [38400/50000 (77%)]	Loss: 1.514466
#
# Train set for client: Accuracy: 45085/50000 (90%)
#
#
# Test set for client: Average loss: 0.0125, Accuracy: 8727/10000 (87%)
# Train Epoch: 60 [0/50000 (0%)]	Loss: 1.510213
# Train Epoch: 60 [38400/50000 (77%)]	Loss: 1.551690
#
# Train set for client: Accuracy: 44986/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8694/10000 (87%)
# Train Epoch: 61 [0/50000 (0%)]	Loss: 1.573139
# Train Epoch: 61 [38400/50000 (77%)]	Loss: 1.531276
#
# Train set for client: Accuracy: 45078/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8705/10000 (87%)
# Train Epoch: 62 [0/50000 (0%)]	Loss: 1.577128
# Train Epoch: 62 [38400/50000 (77%)]	Loss: 1.572185
#
# Train set for client: Accuracy: 44961/50000 (90%)
#
#
# Test set for client: Average loss: 0.0129, Accuracy: 8302/10000 (83%)
# Train Epoch: 63 [0/50000 (0%)]	Loss: 1.553078
# Train Epoch: 63 [38400/50000 (77%)]	Loss: 1.568615
#
# Train set for client: Accuracy: 45076/50000 (90%)
#
#
# Test set for client: Average loss: 0.0125, Accuracy: 8781/10000 (88%)
# Train Epoch: 64 [0/50000 (0%)]	Loss: 1.546805
# Train Epoch: 64 [38400/50000 (77%)]	Loss: 1.560543
#
# Train set for client: Accuracy: 45251/50000 (91%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8702/10000 (87%)
# Train Epoch: 65 [0/50000 (0%)]	Loss: 1.491262
# Train Epoch: 65 [38400/50000 (77%)]	Loss: 1.552605
#
# Train set for client: Accuracy: 45219/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8645/10000 (86%)
# Train Epoch: 66 [0/50000 (0%)]	Loss: 1.554507
# Train Epoch: 66 [38400/50000 (77%)]	Loss: 1.560626
#
# Train set for client: Accuracy: 45226/50000 (90%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8721/10000 (87%)
# Train Epoch: 67 [0/50000 (0%)]	Loss: 1.531855
# Train Epoch: 67 [38400/50000 (77%)]	Loss: 1.549277
#
# Train set for client: Accuracy: 45385/50000 (91%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8734/10000 (87%)
# Train Epoch: 68 [0/50000 (0%)]	Loss: 1.598748
# Train Epoch: 68 [38400/50000 (77%)]	Loss: 1.594206
#
# Train set for client: Accuracy: 45295/50000 (91%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8647/10000 (86%)
# Train Epoch: 69 [0/50000 (0%)]	Loss: 1.541097
# Train Epoch: 69 [38400/50000 (77%)]	Loss: 1.538282
#
# Train set for client: Accuracy: 45310/50000 (91%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8706/10000 (87%)
# Train Epoch: 70 [0/50000 (0%)]	Loss: 1.532838
# Train Epoch: 70 [38400/50000 (77%)]	Loss: 1.547568
#
# Train set for client: Accuracy: 45436/50000 (91%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8721/10000 (87%)
# Train Epoch: 71 [0/50000 (0%)]	Loss: 1.538126
# Train Epoch: 71 [38400/50000 (77%)]	Loss: 1.593661
#
# Train set for client: Accuracy: 45511/50000 (91%)
#
#
# Test set for client: Average loss: 0.0125, Accuracy: 8756/10000 (88%)
# Train Epoch: 72 [0/50000 (0%)]	Loss: 1.549155
# Train Epoch: 72 [38400/50000 (77%)]	Loss: 1.555509
#
# Train set for client: Accuracy: 45345/50000 (91%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8683/10000 (87%)
# Train Epoch: 73 [0/50000 (0%)]	Loss: 1.554295
# Train Epoch: 73 [38400/50000 (77%)]	Loss: 1.545395
#
# Train set for client: Accuracy: 45387/50000 (91%)
#
#
# Test set for client: Average loss: 0.0125, Accuracy: 8746/10000 (87%)
# Train Epoch: 74 [0/50000 (0%)]	Loss: 1.555753
# Train Epoch: 74 [38400/50000 (77%)]	Loss: 1.586023
#
# Train set for client: Accuracy: 45387/50000 (91%)
#
#
# Test set for client: Average loss: 0.0125, Accuracy: 8750/10000 (88%)
# Train Epoch: 75 [0/50000 (0%)]	Loss: 1.520722
# Train Epoch: 75 [38400/50000 (77%)]	Loss: 1.566122
#
# Train set for client: Accuracy: 45406/50000 (91%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8619/10000 (86%)
# Train Epoch: 76 [0/50000 (0%)]	Loss: 1.601128
# Train Epoch: 76 [38400/50000 (77%)]	Loss: 1.535411
#
# Train set for client: Accuracy: 45504/50000 (91%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8688/10000 (87%)
# Train Epoch: 77 [0/50000 (0%)]	Loss: 1.574895
# Train Epoch: 77 [38400/50000 (77%)]	Loss: 1.537215
#
# Train set for client: Accuracy: 45531/50000 (91%)
#
#
# Test set for client: Average loss: 0.0125, Accuracy: 8767/10000 (88%)
# Train Epoch: 78 [0/50000 (0%)]	Loss: 1.519692
# Train Epoch: 78 [38400/50000 (77%)]	Loss: 1.589135
#
# Train set for client: Accuracy: 45453/50000 (91%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8711/10000 (87%)
# Train Epoch: 79 [0/50000 (0%)]	Loss: 1.529126
# Train Epoch: 79 [38400/50000 (77%)]	Loss: 1.589118
#
# Train set for client: Accuracy: 45559/50000 (91%)
#
#
# Test set for client: Average loss: 0.0129, Accuracy: 8330/10000 (83%)
# Train Epoch: 80 [0/50000 (0%)]	Loss: 1.537214
# Train Epoch: 80 [38400/50000 (77%)]	Loss: 1.529253
#
# Train set for client: Accuracy: 46335/50000 (93%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8932/10000 (89%)
# Train Epoch: 81 [0/50000 (0%)]	Loss: 1.550982
# Train Epoch: 81 [38400/50000 (77%)]	Loss: 1.536438
#
# Train set for client: Accuracy: 46750/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8918/10000 (89%)
# Train Epoch: 82 [0/50000 (0%)]	Loss: 1.524147
# Train Epoch: 82 [38400/50000 (77%)]	Loss: 1.510796
#
# Train set for client: Accuracy: 46750/50000 (94%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9010/10000 (90%)
# Train Epoch: 83 [0/50000 (0%)]	Loss: 1.488368
# Train Epoch: 83 [38400/50000 (77%)]	Loss: 1.514543
#
# Train set for client: Accuracy: 46783/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8940/10000 (89%)
# Train Epoch: 84 [0/50000 (0%)]	Loss: 1.478389
# Train Epoch: 84 [38400/50000 (77%)]	Loss: 1.524429
#
# Train set for client: Accuracy: 46885/50000 (94%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 8988/10000 (90%)
# Train Epoch: 85 [0/50000 (0%)]	Loss: 1.530197
# Train Epoch: 85 [38400/50000 (77%)]	Loss: 1.497308
#
# Train set for client: Accuracy: 46971/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8893/10000 (89%)
# Train Epoch: 86 [0/50000 (0%)]	Loss: 1.544156
# Train Epoch: 86 [38400/50000 (77%)]	Loss: 1.527290
#
# Train set for client: Accuracy: 46922/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8901/10000 (89%)
# Train Epoch: 87 [0/50000 (0%)]	Loss: 1.515996
# Train Epoch: 87 [38400/50000 (77%)]	Loss: 1.510989
#
# Train set for client: Accuracy: 46963/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8973/10000 (90%)
# Train Epoch: 88 [0/50000 (0%)]	Loss: 1.513049
# Train Epoch: 88 [38400/50000 (77%)]	Loss: 1.537814
#
# Train set for client: Accuracy: 47100/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8973/10000 (90%)
# Train Epoch: 89 [0/50000 (0%)]	Loss: 1.553228
# Train Epoch: 89 [38400/50000 (77%)]	Loss: 1.537206
#
# Train set for client: Accuracy: 47079/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8922/10000 (89%)
# Train Epoch: 90 [0/50000 (0%)]	Loss: 1.507023
# Train Epoch: 90 [38400/50000 (77%)]	Loss: 1.546530
#
# Train set for client: Accuracy: 47132/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8966/10000 (90%)
# Train Epoch: 91 [0/50000 (0%)]	Loss: 1.546530
# Train Epoch: 91 [38400/50000 (77%)]	Loss: 1.580173
#
# Train set for client: Accuracy: 47214/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8948/10000 (89%)
# Train Epoch: 92 [0/50000 (0%)]	Loss: 1.539279
# Train Epoch: 92 [38400/50000 (77%)]	Loss: 1.531619
#
# Train set for client: Accuracy: 47261/50000 (95%)
#
#
# Test set for client: Average loss: 0.0125, Accuracy: 8848/10000 (88%)
# Train Epoch: 93 [0/50000 (0%)]	Loss: 1.541623
# Train Epoch: 93 [38400/50000 (77%)]	Loss: 1.512070
#
# Train set for client: Accuracy: 47212/50000 (94%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 8999/10000 (90%)
# Train Epoch: 94 [0/50000 (0%)]	Loss: 1.522237
# Train Epoch: 94 [38400/50000 (77%)]	Loss: 1.508749
#
# Train set for client: Accuracy: 47219/50000 (94%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 8984/10000 (90%)
# Train Epoch: 95 [0/50000 (0%)]	Loss: 1.541388
# Train Epoch: 95 [38400/50000 (77%)]	Loss: 1.511538
#
# Train set for client: Accuracy: 47240/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8944/10000 (89%)
# Train Epoch: 96 [0/50000 (0%)]	Loss: 1.515141
# Train Epoch: 96 [38400/50000 (77%)]	Loss: 1.518330
#
# Train set for client: Accuracy: 47289/50000 (95%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9015/10000 (90%)
# Train Epoch: 97 [0/50000 (0%)]	Loss: 1.471262
# Train Epoch: 97 [38400/50000 (77%)]	Loss: 1.509216
#
# Train set for client: Accuracy: 47287/50000 (95%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 8992/10000 (90%)
# Train Epoch: 98 [0/50000 (0%)]	Loss: 1.530011
# Train Epoch: 98 [38400/50000 (77%)]	Loss: 1.537136
#
# Train set for client: Accuracy: 47246/50000 (94%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8894/10000 (89%)
# Train Epoch: 99 [0/50000 (0%)]	Loss: 1.547099
# Train Epoch: 99 [38400/50000 (77%)]	Loss: 1.509872
#
# Train set for client: Accuracy: 47308/50000 (95%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9012/10000 (90%)
# Train Epoch: 100 [0/50000 (0%)]	Loss: 1.576652
# Train Epoch: 100 [38400/50000 (77%)]	Loss: 1.519616
#
# Train set for client: Accuracy: 47372/50000 (95%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 8995/10000 (90%)
# Train Epoch: 101 [0/50000 (0%)]	Loss: 1.506590
# Train Epoch: 101 [38400/50000 (77%)]	Loss: 1.482591
#
# Train set for client: Accuracy: 47380/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8918/10000 (89%)
# Train Epoch: 102 [0/50000 (0%)]	Loss: 1.502972
# Train Epoch: 102 [38400/50000 (77%)]	Loss: 1.519768
#
# Train set for client: Accuracy: 47334/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8946/10000 (89%)
# Train Epoch: 103 [0/50000 (0%)]	Loss: 1.494443
# Train Epoch: 103 [38400/50000 (77%)]	Loss: 1.516134
#
# Train set for client: Accuracy: 47462/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8974/10000 (90%)
# Train Epoch: 104 [0/50000 (0%)]	Loss: 1.513140
# Train Epoch: 104 [38400/50000 (77%)]	Loss: 1.517353
#
# Train set for client: Accuracy: 47341/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8873/10000 (89%)
# Train Epoch: 105 [0/50000 (0%)]	Loss: 1.564224
# Train Epoch: 105 [38400/50000 (77%)]	Loss: 1.550219
#
# Train set for client: Accuracy: 47420/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8929/10000 (89%)
# Train Epoch: 106 [0/50000 (0%)]	Loss: 1.510744
# Train Epoch: 106 [38400/50000 (77%)]	Loss: 1.481989
#
# Train set for client: Accuracy: 47457/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8976/10000 (90%)
# Train Epoch: 107 [0/50000 (0%)]	Loss: 1.498035
# Train Epoch: 107 [38400/50000 (77%)]	Loss: 1.484700
#
# Train set for client: Accuracy: 47346/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8898/10000 (89%)
# Train Epoch: 108 [0/50000 (0%)]	Loss: 1.506886
# Train Epoch: 108 [38400/50000 (77%)]	Loss: 1.508098
#
# Train set for client: Accuracy: 47409/50000 (95%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 8996/10000 (90%)
# Train Epoch: 109 [0/50000 (0%)]	Loss: 1.520681
# Train Epoch: 109 [38400/50000 (77%)]	Loss: 1.514294
#
# Train set for client: Accuracy: 47456/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8899/10000 (89%)
# Train Epoch: 110 [0/50000 (0%)]	Loss: 1.513767
# Train Epoch: 110 [38400/50000 (77%)]	Loss: 1.544344
#
# Train set for client: Accuracy: 47349/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8896/10000 (89%)
# Train Epoch: 111 [0/50000 (0%)]	Loss: 1.510369
# Train Epoch: 111 [38400/50000 (77%)]	Loss: 1.503345
#
# Train set for client: Accuracy: 47353/50000 (95%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9003/10000 (90%)
# Train Epoch: 112 [0/50000 (0%)]	Loss: 1.525174
# Train Epoch: 112 [38400/50000 (77%)]	Loss: 1.530260
#
# Train set for client: Accuracy: 47428/50000 (95%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 8975/10000 (90%)
# Train Epoch: 113 [0/50000 (0%)]	Loss: 1.495990
# Train Epoch: 113 [38400/50000 (77%)]	Loss: 1.503710
#
# Train set for client: Accuracy: 47368/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8905/10000 (89%)
# Train Epoch: 114 [0/50000 (0%)]	Loss: 1.521594
# Train Epoch: 114 [38400/50000 (77%)]	Loss: 1.551638
#
# Train set for client: Accuracy: 47470/50000 (95%)
#
#
# Test set for client: Average loss: 0.0125, Accuracy: 8840/10000 (88%)
# Train Epoch: 115 [0/50000 (0%)]	Loss: 1.535707
# Train Epoch: 115 [38400/50000 (77%)]	Loss: 1.502791
#
# Train set for client: Accuracy: 47401/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8949/10000 (89%)
# Train Epoch: 116 [0/50000 (0%)]	Loss: 1.512747
# Train Epoch: 116 [38400/50000 (77%)]	Loss: 1.522087
#
# Train set for client: Accuracy: 47433/50000 (95%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 8985/10000 (90%)
# Train Epoch: 117 [0/50000 (0%)]	Loss: 1.543757
# Train Epoch: 117 [38400/50000 (77%)]	Loss: 1.486029
#
# Train set for client: Accuracy: 47430/50000 (95%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 8979/10000 (90%)
# Train Epoch: 118 [0/50000 (0%)]	Loss: 1.504809
# Train Epoch: 118 [38400/50000 (77%)]	Loss: 1.497321
#
# Train set for client: Accuracy: 47477/50000 (95%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 8994/10000 (90%)
# Train Epoch: 119 [0/50000 (0%)]	Loss: 1.487226
# Train Epoch: 119 [38400/50000 (77%)]	Loss: 1.530146
#
# Train set for client: Accuracy: 47538/50000 (95%)
#
#
# Test set for client: Average loss: 0.0124, Accuracy: 8912/10000 (89%)
# Train Epoch: 120 [0/50000 (0%)]	Loss: 1.537343
# Train Epoch: 120 [38400/50000 (77%)]	Loss: 1.502887
#
# Train set for client: Accuracy: 47904/50000 (96%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9041/10000 (90%)
# Train Epoch: 121 [0/50000 (0%)]	Loss: 1.477337
# Train Epoch: 121 [38400/50000 (77%)]	Loss: 1.479986
#
# Train set for client: Accuracy: 48110/50000 (96%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9085/10000 (91%)
# Train Epoch: 122 [0/50000 (0%)]	Loss: 1.503363
# Train Epoch: 122 [38400/50000 (77%)]	Loss: 1.491636
#
# Train set for client: Accuracy: 48146/50000 (96%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9091/10000 (91%)
# Train Epoch: 123 [0/50000 (0%)]	Loss: 1.486187
# Train Epoch: 123 [38400/50000 (77%)]	Loss: 1.528517
#
# Train set for client: Accuracy: 48261/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9089/10000 (91%)
# Train Epoch: 124 [0/50000 (0%)]	Loss: 1.497475
# Train Epoch: 124 [38400/50000 (77%)]	Loss: 1.508433
#
# Train set for client: Accuracy: 48334/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9121/10000 (91%)
# Train Epoch: 125 [0/50000 (0%)]	Loss: 1.493305
# Train Epoch: 125 [38400/50000 (77%)]	Loss: 1.527207
#
# Train set for client: Accuracy: 48314/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9074/10000 (91%)
# Train Epoch: 126 [0/50000 (0%)]	Loss: 1.485619
# Train Epoch: 126 [38400/50000 (77%)]	Loss: 1.494800
#
# Train set for client: Accuracy: 48314/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9128/10000 (91%)
# Train Epoch: 127 [0/50000 (0%)]	Loss: 1.510524
# Train Epoch: 127 [38400/50000 (77%)]	Loss: 1.499997
#
# Train set for client: Accuracy: 48407/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9127/10000 (91%)
# Train Epoch: 128 [0/50000 (0%)]	Loss: 1.530163
# Train Epoch: 128 [38400/50000 (77%)]	Loss: 1.498679
#
# Train set for client: Accuracy: 48431/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9126/10000 (91%)
# Train Epoch: 129 [0/50000 (0%)]	Loss: 1.490250
# Train Epoch: 129 [38400/50000 (77%)]	Loss: 1.485890
#
# Train set for client: Accuracy: 48411/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9126/10000 (91%)
# Train Epoch: 130 [0/50000 (0%)]	Loss: 1.511602
# Train Epoch: 130 [38400/50000 (77%)]	Loss: 1.512268
#
# Train set for client: Accuracy: 48475/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9135/10000 (91%)
# Train Epoch: 131 [0/50000 (0%)]	Loss: 1.496273
# Train Epoch: 131 [38400/50000 (77%)]	Loss: 1.481571
#
# Train set for client: Accuracy: 48457/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9124/10000 (91%)
# Train Epoch: 132 [0/50000 (0%)]	Loss: 1.488528
# Train Epoch: 132 [38400/50000 (77%)]	Loss: 1.498407
#
# Train set for client: Accuracy: 48491/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9139/10000 (91%)
# Train Epoch: 133 [0/50000 (0%)]	Loss: 1.478042
# Train Epoch: 133 [38400/50000 (77%)]	Loss: 1.488060
#
# Train set for client: Accuracy: 48470/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9128/10000 (91%)
# Train Epoch: 134 [0/50000 (0%)]	Loss: 1.500654
# Train Epoch: 134 [38400/50000 (77%)]	Loss: 1.504167
#
# Train set for client: Accuracy: 48526/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9123/10000 (91%)
# Train Epoch: 135 [0/50000 (0%)]	Loss: 1.488637
# Train Epoch: 135 [38400/50000 (77%)]	Loss: 1.484260
#
# Train set for client: Accuracy: 48508/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9122/10000 (91%)
# Train Epoch: 136 [0/50000 (0%)]	Loss: 1.500249
# Train Epoch: 136 [38400/50000 (77%)]	Loss: 1.492623
#
# Train set for client: Accuracy: 48586/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9145/10000 (91%)
# Train Epoch: 137 [0/50000 (0%)]	Loss: 1.504978
# Train Epoch: 137 [38400/50000 (77%)]	Loss: 1.485036
#
# Train set for client: Accuracy: 48582/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9108/10000 (91%)
# Train Epoch: 138 [0/50000 (0%)]	Loss: 1.477844
# Train Epoch: 138 [38400/50000 (77%)]	Loss: 1.484466
#
# Train set for client: Accuracy: 48631/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9106/10000 (91%)
# Train Epoch: 139 [0/50000 (0%)]	Loss: 1.479106
# Train Epoch: 139 [38400/50000 (77%)]	Loss: 1.477383
#
# Train set for client: Accuracy: 48628/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9120/10000 (91%)
# Train Epoch: 140 [0/50000 (0%)]	Loss: 1.487873
# Train Epoch: 140 [38400/50000 (77%)]	Loss: 1.494879
#
# Train set for client: Accuracy: 48607/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9132/10000 (91%)
# Train Epoch: 141 [0/50000 (0%)]	Loss: 1.492855
# Train Epoch: 141 [38400/50000 (77%)]	Loss: 1.490963
#
# Train set for client: Accuracy: 48630/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9105/10000 (91%)
# Train Epoch: 142 [0/50000 (0%)]	Loss: 1.492621
# Train Epoch: 142 [38400/50000 (77%)]	Loss: 1.499206
#
# Train set for client: Accuracy: 48683/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9100/10000 (91%)
# Train Epoch: 143 [0/50000 (0%)]	Loss: 1.485197
# Train Epoch: 143 [38400/50000 (77%)]	Loss: 1.522875
#
# Train set for client: Accuracy: 48634/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9134/10000 (91%)
# Train Epoch: 144 [0/50000 (0%)]	Loss: 1.473419
# Train Epoch: 144 [38400/50000 (77%)]	Loss: 1.483409
#
# Train set for client: Accuracy: 48678/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9127/10000 (91%)
# Train Epoch: 145 [0/50000 (0%)]	Loss: 1.488791
# Train Epoch: 145 [38400/50000 (77%)]	Loss: 1.488870
#
# Train set for client: Accuracy: 48722/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9095/10000 (91%)
# Train Epoch: 146 [0/50000 (0%)]	Loss: 1.478789
# Train Epoch: 146 [38400/50000 (77%)]	Loss: 1.482634
#
# Train set for client: Accuracy: 48643/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9047/10000 (90%)
# Train Epoch: 147 [0/50000 (0%)]	Loss: 1.469542
# Train Epoch: 147 [38400/50000 (77%)]	Loss: 1.485154
#
# Train set for client: Accuracy: 48690/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9145/10000 (91%)
# Train Epoch: 148 [0/50000 (0%)]	Loss: 1.505189
# Train Epoch: 148 [38400/50000 (77%)]	Loss: 1.487727
#
# Train set for client: Accuracy: 48675/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9135/10000 (91%)
# Train Epoch: 149 [0/50000 (0%)]	Loss: 1.501400
# Train Epoch: 149 [38400/50000 (77%)]	Loss: 1.504605
#
# Train set for client: Accuracy: 48708/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9106/10000 (91%)
# Train Epoch: 150 [0/50000 (0%)]	Loss: 1.512263
# Train Epoch: 150 [38400/50000 (77%)]	Loss: 1.500250
#
# Train set for client: Accuracy: 48688/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9120/10000 (91%)
# Train Epoch: 151 [0/50000 (0%)]	Loss: 1.477952
# Train Epoch: 151 [38400/50000 (77%)]	Loss: 1.470042
#
# Train set for client: Accuracy: 48748/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9120/10000 (91%)
# Train Epoch: 152 [0/50000 (0%)]	Loss: 1.485266
# Train Epoch: 152 [38400/50000 (77%)]	Loss: 1.487269
#
# Train set for client: Accuracy: 48746/50000 (97%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9143/10000 (91%)
# Train Epoch: 153 [0/50000 (0%)]	Loss: 1.480939
# Train Epoch: 153 [38400/50000 (77%)]	Loss: 1.492254
#
# Train set for client: Accuracy: 48753/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9154/10000 (92%)
# Train Epoch: 154 [0/50000 (0%)]	Loss: 1.471451
# Train Epoch: 154 [38400/50000 (77%)]	Loss: 1.492864
#
# Train set for client: Accuracy: 48777/50000 (98%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9083/10000 (91%)
# Train Epoch: 155 [0/50000 (0%)]	Loss: 1.493108
# Train Epoch: 155 [38400/50000 (77%)]	Loss: 1.498637
#
# Train set for client: Accuracy: 48751/50000 (98%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9101/10000 (91%)
# Train Epoch: 156 [0/50000 (0%)]	Loss: 1.499436
# Train Epoch: 156 [38400/50000 (77%)]	Loss: 1.474977
#
# Train set for client: Accuracy: 48754/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9125/10000 (91%)
# Train Epoch: 157 [0/50000 (0%)]	Loss: 1.472772
# Train Epoch: 157 [38400/50000 (77%)]	Loss: 1.475825
#
# Train set for client: Accuracy: 48748/50000 (97%)
#
#
# Test set for client: Average loss: 0.0123, Accuracy: 9104/10000 (91%)
# Train Epoch: 158 [0/50000 (0%)]	Loss: 1.485538
# Train Epoch: 158 [38400/50000 (77%)]	Loss: 1.499351
#
# Train set for client: Accuracy: 48796/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9147/10000 (91%)
# Train Epoch: 159 [0/50000 (0%)]	Loss: 1.478297
# Train Epoch: 159 [38400/50000 (77%)]	Loss: 1.508371
#
# Train set for client: Accuracy: 48803/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9132/10000 (91%)
# Train Epoch: 160 [0/50000 (0%)]	Loss: 1.477703
# Train Epoch: 160 [38400/50000 (77%)]	Loss: 1.479726
#
# Train set for client: Accuracy: 48910/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9171/10000 (92%)
# Train Epoch: 161 [0/50000 (0%)]	Loss: 1.482819
# Train Epoch: 161 [38400/50000 (77%)]	Loss: 1.461747
#
# Train set for client: Accuracy: 48980/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9188/10000 (92%)
# Train Epoch: 162 [0/50000 (0%)]	Loss: 1.462149
# Train Epoch: 162 [38400/50000 (77%)]	Loss: 1.477707
#
# Train set for client: Accuracy: 49019/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9201/10000 (92%)
# Train Epoch: 163 [0/50000 (0%)]	Loss: 1.488083
# Train Epoch: 163 [38400/50000 (77%)]	Loss: 1.462449
#
# Train set for client: Accuracy: 49020/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9183/10000 (92%)
# Train Epoch: 164 [0/50000 (0%)]	Loss: 1.485454
# Train Epoch: 164 [38400/50000 (77%)]	Loss: 1.493935
#
# Train set for client: Accuracy: 49109/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9167/10000 (92%)
# Train Epoch: 165 [0/50000 (0%)]	Loss: 1.508660
# Train Epoch: 165 [38400/50000 (77%)]	Loss: 1.480663
#
# Train set for client: Accuracy: 49033/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9185/10000 (92%)
# Train Epoch: 166 [0/50000 (0%)]	Loss: 1.477567
# Train Epoch: 166 [38400/50000 (77%)]	Loss: 1.483435
#
# Train set for client: Accuracy: 49085/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9193/10000 (92%)
# Train Epoch: 167 [0/50000 (0%)]	Loss: 1.477537
# Train Epoch: 167 [38400/50000 (77%)]	Loss: 1.500641
#
# Train set for client: Accuracy: 49075/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9197/10000 (92%)
# Train Epoch: 168 [0/50000 (0%)]	Loss: 1.470859
# Train Epoch: 168 [38400/50000 (77%)]	Loss: 1.469446
#
# Train set for client: Accuracy: 49100/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9176/10000 (92%)
# Train Epoch: 169 [0/50000 (0%)]	Loss: 1.485275
# Train Epoch: 169 [38400/50000 (77%)]	Loss: 1.470078
#
# Train set for client: Accuracy: 49149/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9198/10000 (92%)
# Train Epoch: 170 [0/50000 (0%)]	Loss: 1.470328
# Train Epoch: 170 [38400/50000 (77%)]	Loss: 1.490254
#
# Train set for client: Accuracy: 49142/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9202/10000 (92%)
# Train Epoch: 171 [0/50000 (0%)]	Loss: 1.491133
# Train Epoch: 171 [38400/50000 (77%)]	Loss: 1.475326
#
# Train set for client: Accuracy: 49155/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9178/10000 (92%)
# Train Epoch: 172 [0/50000 (0%)]	Loss: 1.477224
# Train Epoch: 172 [38400/50000 (77%)]	Loss: 1.481930
#
# Train set for client: Accuracy: 49149/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9212/10000 (92%)
# Train Epoch: 173 [0/50000 (0%)]	Loss: 1.462062
# Train Epoch: 173 [38400/50000 (77%)]	Loss: 1.493110
#
# Train set for client: Accuracy: 49127/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9212/10000 (92%)
# Train Epoch: 174 [0/50000 (0%)]	Loss: 1.479571
# Train Epoch: 174 [38400/50000 (77%)]	Loss: 1.469506
#
# Train set for client: Accuracy: 49169/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9197/10000 (92%)
# Train Epoch: 175 [0/50000 (0%)]	Loss: 1.469704
# Train Epoch: 175 [38400/50000 (77%)]	Loss: 1.472385
#
# Train set for client: Accuracy: 49166/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9206/10000 (92%)
# Train Epoch: 176 [0/50000 (0%)]	Loss: 1.477159
# Train Epoch: 176 [38400/50000 (77%)]	Loss: 1.481206
#
# Train set for client: Accuracy: 49153/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9170/10000 (92%)
# Train Epoch: 177 [0/50000 (0%)]	Loss: 1.478041
# Train Epoch: 177 [38400/50000 (77%)]	Loss: 1.477371
#
# Train set for client: Accuracy: 49212/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9176/10000 (92%)
# Train Epoch: 178 [0/50000 (0%)]	Loss: 1.477499
# Train Epoch: 178 [38400/50000 (77%)]	Loss: 1.477375
#
# Train set for client: Accuracy: 49169/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9162/10000 (92%)
# Train Epoch: 179 [0/50000 (0%)]	Loss: 1.493597
# Train Epoch: 179 [38400/50000 (77%)]	Loss: 1.470203
#
# Train set for client: Accuracy: 49226/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9173/10000 (92%)
# Train Epoch: 180 [0/50000 (0%)]	Loss: 1.462362
# Train Epoch: 180 [38400/50000 (77%)]	Loss: 1.461824
#
# Train set for client: Accuracy: 49176/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9181/10000 (92%)
# Train Epoch: 181 [0/50000 (0%)]	Loss: 1.492483
# Train Epoch: 181 [38400/50000 (77%)]	Loss: 1.469485
#
# Train set for client: Accuracy: 49216/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9183/10000 (92%)
# Train Epoch: 182 [0/50000 (0%)]	Loss: 1.485301
# Train Epoch: 182 [38400/50000 (77%)]	Loss: 1.486222
#
# Train set for client: Accuracy: 49236/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9176/10000 (92%)
# Train Epoch: 183 [0/50000 (0%)]	Loss: 1.492699
# Train Epoch: 183 [38400/50000 (77%)]	Loss: 1.469282
#
# Train set for client: Accuracy: 49178/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9208/10000 (92%)
# Train Epoch: 184 [0/50000 (0%)]	Loss: 1.483030
# Train Epoch: 184 [38400/50000 (77%)]	Loss: 1.492701
#
# Train set for client: Accuracy: 49220/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9195/10000 (92%)
# Train Epoch: 185 [0/50000 (0%)]	Loss: 1.475148
# Train Epoch: 185 [38400/50000 (77%)]	Loss: 1.462423
#
# Train set for client: Accuracy: 49237/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9171/10000 (92%)
# Train Epoch: 186 [0/50000 (0%)]	Loss: 1.471382
# Train Epoch: 186 [38400/50000 (77%)]	Loss: 1.470322
#
# Train set for client: Accuracy: 49237/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9183/10000 (92%)
# Train Epoch: 187 [0/50000 (0%)]	Loss: 1.478699
# Train Epoch: 187 [38400/50000 (77%)]	Loss: 1.474838
#
# Train set for client: Accuracy: 49224/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9197/10000 (92%)
# Train Epoch: 188 [0/50000 (0%)]	Loss: 1.492414
# Train Epoch: 188 [38400/50000 (77%)]	Loss: 1.469570
#
# Train set for client: Accuracy: 49254/50000 (99%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9198/10000 (92%)
# Train Epoch: 189 [0/50000 (0%)]	Loss: 1.476495
# Train Epoch: 189 [38400/50000 (77%)]	Loss: 1.476907
#
# Train set for client: Accuracy: 49266/50000 (99%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9206/10000 (92%)
# Train Epoch: 190 [0/50000 (0%)]	Loss: 1.469758
# Train Epoch: 190 [38400/50000 (77%)]	Loss: 1.492367
#
# Train set for client: Accuracy: 49270/50000 (99%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9202/10000 (92%)
# Train Epoch: 191 [0/50000 (0%)]	Loss: 1.469565
# Train Epoch: 191 [38400/50000 (77%)]	Loss: 1.481604
#
# Train set for client: Accuracy: 49240/50000 (98%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9190/10000 (92%)
# Train Epoch: 192 [0/50000 (0%)]	Loss: 1.477191
# Train Epoch: 192 [38400/50000 (77%)]	Loss: 1.492977
#
# Train set for client: Accuracy: 49273/50000 (99%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9175/10000 (92%)
# Train Epoch: 193 [0/50000 (0%)]	Loss: 1.462927
# Train Epoch: 193 [38400/50000 (77%)]	Loss: 1.493003
#
# Train set for client: Accuracy: 49283/50000 (99%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9191/10000 (92%)
# Train Epoch: 194 [0/50000 (0%)]	Loss: 1.501163
# Train Epoch: 194 [38400/50000 (77%)]	Loss: 1.473023
#
# Train set for client: Accuracy: 49297/50000 (99%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9200/10000 (92%)
# Train Epoch: 195 [0/50000 (0%)]	Loss: 1.462565
# Train Epoch: 195 [38400/50000 (77%)]	Loss: 1.461869
#
# Train set for client: Accuracy: 49304/50000 (99%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9205/10000 (92%)
# Train Epoch: 196 [0/50000 (0%)]	Loss: 1.470334
# Train Epoch: 196 [38400/50000 (77%)]	Loss: 1.477565
#
# Train set for client: Accuracy: 49326/50000 (99%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9205/10000 (92%)
# Train Epoch: 197 [0/50000 (0%)]	Loss: 1.470368
# Train Epoch: 197 [38400/50000 (77%)]	Loss: 1.477363
#
# Train set for client: Accuracy: 49295/50000 (99%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9178/10000 (92%)
# Train Epoch: 198 [0/50000 (0%)]	Loss: 1.461852
# Train Epoch: 198 [38400/50000 (77%)]	Loss: 1.469481
#
# Train set for client: Accuracy: 49320/50000 (99%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9200/10000 (92%)
# Train Epoch: 199 [0/50000 (0%)]	Loss: 1.469924
# Train Epoch: 199 [38400/50000 (77%)]	Loss: 1.494132
#
# Train set for client: Accuracy: 49296/50000 (99%)
#
#
# Test set for client: Average loss: 0.0122, Accuracy: 9203/10000 (92%)

# %%
def train_model(clients,client_optimisers,server,server_optimiser,device,train_loader,epoch):
    for client in clients:
        client.train()
    server.train()
    criterion = nn.CrossEntropyLoss()
    correct = 0
    previous_client = None
    for batch_idx, (data, target) in enumerate(train_loader):        
        data, target = data.to(device), target.to(device)

        client = clients[batch_idx%5]
        client_optimiser = client_optimisers[batch_idx%5]
        server_optimiser.zero_grad()
        client_optimiser.zero_grad()

        if previous_client:
            client.load_state_dict(previous_client.state_dict())

        ### execute client - feed forward network
        intermediate = client(data)
        remote = intermediate.detach().requires_grad_()
        ### execute server - feed forward network
        output = server(remote)
        loss = criterion(output,target)
        loss.backward()
        ### execute client back propagation
        grad = remote.grad.clone()
        intermediate.backward(grad)
        ### optimiser step
        server_optimiser.step()
        client_optimiser.step()
        previous_client = client

        pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()
        ### printing logs
        if batch_idx % 300 == 0:
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
    
    print('\nTrain set for client: Accuracy: {}/{} ({:.0f}%)\n'.format(
        correct, len(train_loader.dataset),
        100. * correct / len(train_loader.dataset)))

def adjust_learning_rate(optimizer, init_lr, epoch):
    lr = init_lr * (0.5 ** (epoch // 40))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

def test_model(clients,server,device,test_loader):
    for client in clients:
        client.eval()
    server.eval()
    criterion = nn.CrossEntropyLoss()
    for client in clients:
        with torch.no_grad():
            test_loss = 0
            correct = 0
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                intermediate = client(data)
                output = server(intermediate)
                test_loss += criterion(output, target).item()  # sum up batch loss
                pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
                correct += pred.eq(target.view_as(pred)).sum().item()
            
            test_loss /= len(test_loader.dataset)
            print('\nTest set for client: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
                test_loss, correct, len(test_loader.dataset),
                100. * correct / len(test_loader.dataset)))

if __name__ == "__main__":
    random.seed(7)
    torch.manual_seed(7)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    if torch.cuda.is_available():  
        dev = "cuda:0" 
    else:  
        dev = "cpu"
    device = torch.device(dev)

    train_loader,test_loader = get_cifar10_dataset(batch_size=128)

    clients=[]
    client_optimisers = []
    for i in range(5):
        client = vgg_client(input_channels=3,output_channels=10).to(device)
        client_optim = optim.SGD(client.parameters(),lr=1e-3,weight_decay=5e-4)
        clients.append(client)
        client_optimisers.append(client_optim)

    server = vgg_server(input_channels=256,output_channels=10).to(device)
    server_optim = optim.SGD(server.parameters(),lr=1e-3,weight_decay=5e-4)

    print("\n\nModel Summary")
    print("\nClient:")
    summary(clients[0],(3,32,32))
    print("\n\nServer:")
    summary(server,(256,4,4))

    init_lr = 0.1
    for i in range(1,50):
        for optimiser in client_optimisers:
            adjust_learning_rate(optimiser,init_lr,i)
        adjust_learning_rate(server_optim,init_lr,i)
        train_model(clients,client_optimisers,server,server_optim,device,train_loader,i)
        test_model(clients,server,device,test_loader)
    
    torch.save({'server':server.state_dict(),
            'client1':clients[0].state_dict(),
            'client2':clients[1].state_dict(),
            'client3':clients[2].state_dict(),
            'client4':clients[3].state_dict(),
            'client5':clients[4].state_dict()},"split-model-multi-agent.pt")
# Out:
# Files already downloaded and verified
#
#
# Model Summary
#
# Client:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#             Conv2d-4           [-1, 64, 32, 32]          36,928
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#               ReLU-6           [-1, 64, 32, 32]               0
#          MaxPool2d-7           [-1, 64, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]          73,856
#        BatchNorm2d-9          [-1, 128, 16, 16]             256
#              ReLU-10          [-1, 128, 16, 16]               0
#            Conv2d-11          [-1, 128, 16, 16]         147,584
#       BatchNorm2d-12          [-1, 128, 16, 16]             256
#              ReLU-13          [-1, 128, 16, 16]               0
#         MaxPool2d-14            [-1, 128, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         295,168
#       BatchNorm2d-16            [-1, 256, 8, 8]             512
#              ReLU-17            [-1, 256, 8, 8]               0
#            Conv2d-18            [-1, 256, 8, 8]         590,080
#       BatchNorm2d-19            [-1, 256, 8, 8]             512
#              ReLU-20            [-1, 256, 8, 8]               0
#            Conv2d-21            [-1, 256, 8, 8]         590,080
#       BatchNorm2d-22            [-1, 256, 8, 8]             512
#              ReLU-23            [-1, 256, 8, 8]               0
#         MaxPool2d-24            [-1, 256, 4, 4]               0
# ================================================================
# Total params: 1,737,792
# Trainable params: 1,737,792
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.84
# Params size (MB): 6.63
# Estimated Total Size (MB): 12.48
# ----------------------------------------------------------------
#
#
# Server:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 512, 4, 4]       1,180,160
#        BatchNorm2d-2            [-1, 512, 4, 4]           1,024
#               ReLU-3            [-1, 512, 4, 4]               0
#             Conv2d-4            [-1, 512, 4, 4]       2,359,808
#        BatchNorm2d-5            [-1, 512, 4, 4]           1,024
#               ReLU-6            [-1, 512, 4, 4]               0
#             Conv2d-7            [-1, 512, 4, 4]       2,359,808
#        BatchNorm2d-8            [-1, 512, 4, 4]           1,024
#               ReLU-9            [-1, 512, 4, 4]               0
#         MaxPool2d-10            [-1, 512, 2, 2]               0
#            Conv2d-11            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-12            [-1, 512, 2, 2]           1,024
#              ReLU-13            [-1, 512, 2, 2]               0
#            Conv2d-14            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-15            [-1, 512, 2, 2]           1,024
#              ReLU-16            [-1, 512, 2, 2]               0
#            Conv2d-17            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-18            [-1, 512, 2, 2]           1,024
#              ReLU-19            [-1, 512, 2, 2]               0
#         MaxPool2d-20            [-1, 512, 1, 1]               0
#           Flatten-21                  [-1, 512]               0
#            Linear-22                  [-1, 256]         131,328
#              ReLU-23                  [-1, 256]               0
#           Dropout-24                  [-1, 256]               0
#            Linear-25                  [-1, 128]          32,896
#              ReLU-26                  [-1, 128]               0
#           Dropout-27                  [-1, 128]               0
#            Linear-28                   [-1, 10]           1,290
#           Softmax-29                   [-1, 10]               0
# ================================================================
# Total params: 13,150,858
# Trainable params: 13,150,858
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 0.74
# Params size (MB): 50.17
# Estimated Total Size (MB): 50.92
# ----------------------------------------------------------------
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.303112
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 2.059596
#
# Train set for client: Accuracy: 15978/50000 (32%)
#
#
# Test set for client: Average loss: 0.0164, Accuracy: 3812/10000 (38%)
#
# Test set for client: Average loss: 0.0160, Accuracy: 4244/10000 (42%)
#
# Test set for client: Average loss: 0.0162, Accuracy: 4045/10000 (40%)
#
# Test set for client: Average loss: 0.0163, Accuracy: 3972/10000 (40%)
#
# Test set for client: Average loss: 0.0160, Accuracy: 4262/10000 (43%)
# Train Epoch: 2 [0/50000 (0%)]	Loss: 2.141925
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 1.938969
#
# Train set for client: Accuracy: 24267/50000 (49%)
#
#
# Test set for client: Average loss: 0.0167, Accuracy: 3364/10000 (34%)
#
# Test set for client: Average loss: 0.0157, Accuracy: 4756/10000 (48%)
#
# Test set for client: Average loss: 0.0157, Accuracy: 4670/10000 (47%)
#
# Test set for client: Average loss: 0.0156, Accuracy: 4856/10000 (49%)
#
# Test set for client: Average loss: 0.0159, Accuracy: 4427/10000 (44%)
# Train Epoch: 3 [0/50000 (0%)]	Loss: 2.084098
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 1.915931
#
# Train set for client: Accuracy: 27513/50000 (55%)
#
#
# Test set for client: Average loss: 0.0158, Accuracy: 4515/10000 (45%)
#
# Test set for client: Average loss: 0.0155, Accuracy: 4911/10000 (49%)
#
# Test set for client: Average loss: 0.0157, Accuracy: 4695/10000 (47%)
#
# Test set for client: Average loss: 0.0159, Accuracy: 4438/10000 (44%)
#
# Test set for client: Average loss: 0.0155, Accuracy: 4939/10000 (49%)
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.979493
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 1.825230
#
# Train set for client: Accuracy: 29718/50000 (59%)
#
#
# Test set for client: Average loss: 0.0151, Accuracy: 5464/10000 (55%)
#
# Test set for client: Average loss: 0.0146, Accuracy: 6141/10000 (61%)
#
# Test set for client: Average loss: 0.0145, Accuracy: 6185/10000 (62%)
#
# Test set for client: Average loss: 0.0148, Accuracy: 5894/10000 (59%)
#
# Test set for client: Average loss: 0.0150, Accuracy: 5611/10000 (56%)
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.869036
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 1.771913
#
# Train set for client: Accuracy: 31874/50000 (64%)
#
#
# Test set for client: Average loss: 0.0146, Accuracy: 6054/10000 (61%)
#
# Test set for client: Average loss: 0.0144, Accuracy: 6316/10000 (63%)
#
# Test set for client: Average loss: 0.0150, Accuracy: 5532/10000 (55%)
#
# Test set for client: Average loss: 0.0148, Accuracy: 5793/10000 (58%)
#
# Test set for client: Average loss: 0.0148, Accuracy: 5846/10000 (58%)
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.787284
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 1.827654
#
# Train set for client: Accuracy: 33387/50000 (67%)
#
#
# Test set for client: Average loss: 0.0141, Accuracy: 6727/10000 (67%)
#
# Test set for client: Average loss: 0.0139, Accuracy: 6936/10000 (69%)
#
# Test set for client: Average loss: 0.0139, Accuracy: 6972/10000 (70%)
#
# Test set for client: Average loss: 0.0140, Accuracy: 6842/10000 (68%)
#
# Test set for client: Average loss: 0.0140, Accuracy: 6878/10000 (69%)
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.756338
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 1.775524
#
# Train set for client: Accuracy: 34168/50000 (68%)
#
#
# Test set for client: Average loss: 0.0148, Accuracy: 5901/10000 (59%)
#
# Test set for client: Average loss: 0.0143, Accuracy: 6432/10000 (64%)
#
# Test set for client: Average loss: 0.0144, Accuracy: 6392/10000 (64%)
#
# Test set for client: Average loss: 0.0141, Accuracy: 6689/10000 (67%)
#
# Test set for client: Average loss: 0.0141, Accuracy: 6706/10000 (67%)
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.798105
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 1.765072
#
# Train set for client: Accuracy: 35202/50000 (70%)
#
#
# Test set for client: Average loss: 0.0138, Accuracy: 7134/10000 (71%)
#
# Test set for client: Average loss: 0.0141, Accuracy: 6805/10000 (68%)
#
# Test set for client: Average loss: 0.0143, Accuracy: 6469/10000 (65%)
#
# Test set for client: Average loss: 0.0139, Accuracy: 6994/10000 (70%)
#
# Test set for client: Average loss: 0.0140, Accuracy: 6834/10000 (68%)
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.689843
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 1.728339
#
# Train set for client: Accuracy: 35966/50000 (72%)
#
#
# Test set for client: Average loss: 0.0140, Accuracy: 6900/10000 (69%)
#
# Test set for client: Average loss: 0.0141, Accuracy: 6753/10000 (68%)
#
# Test set for client: Average loss: 0.0139, Accuracy: 6936/10000 (69%)
#
# Test set for client: Average loss: 0.0139, Accuracy: 6978/10000 (70%)
#
# Test set for client: Average loss: 0.0140, Accuracy: 6928/10000 (69%)
# Train Epoch: 10 [0/50000 (0%)]	Loss: 1.814596
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 1.743343
#
# Train set for client: Accuracy: 36350/50000 (73%)
#
#
# Test set for client: Average loss: 0.0141, Accuracy: 6818/10000 (68%)
#
# Test set for client: Average loss: 0.0142, Accuracy: 6667/10000 (67%)
#
# Test set for client: Average loss: 0.0140, Accuracy: 6859/10000 (69%)
#
# Test set for client: Average loss: 0.0142, Accuracy: 6699/10000 (67%)
#
# Test set for client: Average loss: 0.0143, Accuracy: 6518/10000 (65%)
# Train Epoch: 11 [0/50000 (0%)]	Loss: 1.730032
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 1.788098
#
# Train set for client: Accuracy: 36832/50000 (74%)
#
#
# Test set for client: Average loss: 0.0139, Accuracy: 6994/10000 (70%)
#
# Test set for client: Average loss: 0.0137, Accuracy: 7304/10000 (73%)
#
# Test set for client: Average loss: 0.0137, Accuracy: 7288/10000 (73%)
#
# Test set for client: Average loss: 0.0136, Accuracy: 7344/10000 (73%)
#
# Test set for client: Average loss: 0.0137, Accuracy: 7278/10000 (73%)
# Train Epoch: 12 [0/50000 (0%)]	Loss: 1.740793
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 1.746583
#
# Train set for client: Accuracy: 37209/50000 (74%)
#
#
# Test set for client: Average loss: 0.0138, Accuracy: 7097/10000 (71%)
#
# Test set for client: Average loss: 0.0136, Accuracy: 7384/10000 (74%)
#
# Test set for client: Average loss: 0.0136, Accuracy: 7368/10000 (74%)
#
# Test set for client: Average loss: 0.0136, Accuracy: 7403/10000 (74%)
#
# Test set for client: Average loss: 0.0136, Accuracy: 7362/10000 (74%)
# Train Epoch: 13 [0/50000 (0%)]	Loss: 1.684712
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 1.712726
#
# Train set for client: Accuracy: 37860/50000 (76%)
#
#
# Test set for client: Average loss: 0.0136, Accuracy: 7425/10000 (74%)
#
# Test set for client: Average loss: 0.0136, Accuracy: 7416/10000 (74%)
#
# Test set for client: Average loss: 0.0136, Accuracy: 7357/10000 (74%)
#
# Test set for client: Average loss: 0.0135, Accuracy: 7492/10000 (75%)
#
# Test set for client: Average loss: 0.0137, Accuracy: 7292/10000 (73%)
# Train Epoch: 14 [0/50000 (0%)]	Loss: 1.646286
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 1.694281
#
# Train set for client: Accuracy: 38100/50000 (76%)
#
#
# Test set for client: Average loss: 0.0135, Accuracy: 7500/10000 (75%)
#
# Test set for client: Average loss: 0.0136, Accuracy: 7405/10000 (74%)
#
# Test set for client: Average loss: 0.0137, Accuracy: 7270/10000 (73%)
#
# Test set for client: Average loss: 0.0139, Accuracy: 7046/10000 (70%)
#
# Test set for client: Average loss: 0.0136, Accuracy: 7369/10000 (74%)
# Train Epoch: 15 [0/50000 (0%)]	Loss: 1.733567
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 1.702773
#
# Train set for client: Accuracy: 38384/50000 (77%)
#
#
# Test set for client: Average loss: 0.0135, Accuracy: 7461/10000 (75%)
#
# Test set for client: Average loss: 0.0137, Accuracy: 7225/10000 (72%)
#
# Test set for client: Average loss: 0.0135, Accuracy: 7491/10000 (75%)
#
# Test set for client: Average loss: 0.0135, Accuracy: 7532/10000 (75%)
#
# Test set for client: Average loss: 0.0135, Accuracy: 7515/10000 (75%)
# Train Epoch: 16 [0/50000 (0%)]	Loss: 1.746159
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 1.659818
#
# Train set for client: Accuracy: 38576/50000 (77%)
#
#
# Test set for client: Average loss: 0.0134, Accuracy: 7612/10000 (76%)
#
# Test set for client: Average loss: 0.0133, Accuracy: 7730/10000 (77%)
#
# Test set for client: Average loss: 0.0135, Accuracy: 7540/10000 (75%)
#
# Test set for client: Average loss: 0.0134, Accuracy: 7587/10000 (76%)
#
# Test set for client: Average loss: 0.0133, Accuracy: 7768/10000 (78%)
# Train Epoch: 17 [0/50000 (0%)]	Loss: 1.708550
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 1.674480
#
# Train set for client: Accuracy: 39150/50000 (78%)
#
#
# Test set for client: Average loss: 0.0135, Accuracy: 7458/10000 (75%)
#
# Test set for client: Average loss: 0.0132, Accuracy: 7846/10000 (78%)
#
# Test set for client: Average loss: 0.0132, Accuracy: 7863/10000 (79%)
#
# Test set for client: Average loss: 0.0134, Accuracy: 7670/10000 (77%)
#
# Test set for client: Average loss: 0.0134, Accuracy: 7617/10000 (76%)
# Train Epoch: 18 [0/50000 (0%)]	Loss: 1.657013
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 1.732581
#
# Train set for client: Accuracy: 39304/50000 (79%)
#
#
# Test set for client: Average loss: 0.0135, Accuracy: 7507/10000 (75%)
#
# Test set for client: Average loss: 0.0133, Accuracy: 7776/10000 (78%)
#
# Test set for client: Average loss: 0.0133, Accuracy: 7772/10000 (78%)
#
# Test set for client: Average loss: 0.0133, Accuracy: 7773/10000 (78%)
#
# Test set for client: Average loss: 0.0134, Accuracy: 7670/10000 (77%)
# Train Epoch: 19 [0/50000 (0%)]	Loss: 1.726279
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 1.647255
#
# Train set for client: Accuracy: 39243/50000 (78%)
#
#
# Test set for client: Average loss: 0.0132, Accuracy: 7879/10000 (79%)
#
# Test set for client: Average loss: 0.0132, Accuracy: 7859/10000 (79%)
#
# Test set for client: Average loss: 0.0133, Accuracy: 7761/10000 (78%)
#
# Test set for client: Average loss: 0.0134, Accuracy: 7678/10000 (77%)
#
# Test set for client: Average loss: 0.0134, Accuracy: 7615/10000 (76%)
# Train Epoch: 20 [0/50000 (0%)]	Loss: 1.651683
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 1.646024
#
# Train set for client: Accuracy: 39602/50000 (79%)
#
#
# Test set for client: Average loss: 0.0132, Accuracy: 7852/10000 (79%)
#
# Test set for client: Average loss: 0.0134, Accuracy: 7684/10000 (77%)
#
# Test set for client: Average loss: 0.0132, Accuracy: 7827/10000 (78%)
#
# Test set for client: Average loss: 0.0132, Accuracy: 7868/10000 (79%)
#
# Test set for client: Average loss: 0.0133, Accuracy: 7817/10000 (78%)
# Train Epoch: 21 [0/50000 (0%)]	Loss: 1.699602
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 1.611839
#
# Train set for client: Accuracy: 39867/50000 (80%)
#
#
# Test set for client: Average loss: 0.0139, Accuracy: 6970/10000 (70%)
#
# Test set for client: Average loss: 0.0133, Accuracy: 7777/10000 (78%)
#
# Test set for client: Average loss: 0.0132, Accuracy: 7839/10000 (78%)
#
# Test set for client: Average loss: 0.0133, Accuracy: 7762/10000 (78%)
#
# Test set for client: Average loss: 0.0136, Accuracy: 7453/10000 (75%)
# Train Epoch: 22 [0/50000 (0%)]	Loss: 1.621655
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 1.672490
#
# Train set for client: Accuracy: 40130/50000 (80%)
#
#
# Test set for client: Average loss: 0.0135, Accuracy: 7502/10000 (75%)
#
# Test set for client: Average loss: 0.0133, Accuracy: 7711/10000 (77%)
#
# Test set for client: Average loss: 0.0133, Accuracy: 7725/10000 (77%)
#
# Test set for client: Average loss: 0.0133, Accuracy: 7717/10000 (77%)
#
# Test set for client: Average loss: 0.0133, Accuracy: 7699/10000 (77%)
# Train Epoch: 23 [0/50000 (0%)]	Loss: 1.647343
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 1.627942
#
# Train set for client: Accuracy: 40331/50000 (81%)
#
#
# Test set for client: Average loss: 0.0131, Accuracy: 7973/10000 (80%)
#
# Test set for client: Average loss: 0.0134, Accuracy: 7659/10000 (77%)
#
# Test set for client: Average loss: 0.0133, Accuracy: 7770/10000 (78%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 7954/10000 (80%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 8021/10000 (80%)
# Train Epoch: 24 [0/50000 (0%)]	Loss: 1.628724
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 1.634905
#
# Train set for client: Accuracy: 40345/50000 (81%)
#
#
# Test set for client: Average loss: 0.0133, Accuracy: 7808/10000 (78%)
#
# Test set for client: Average loss: 0.0133, Accuracy: 7768/10000 (78%)
#
# Test set for client: Average loss: 0.0132, Accuracy: 7932/10000 (79%)
#
# Test set for client: Average loss: 0.0133, Accuracy: 7819/10000 (78%)
#
# Test set for client: Average loss: 0.0132, Accuracy: 7901/10000 (79%)
# Train Epoch: 25 [0/50000 (0%)]	Loss: 1.661837
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 1.607705
#
# Train set for client: Accuracy: 40711/50000 (81%)
#
#
# Test set for client: Average loss: 0.0132, Accuracy: 7878/10000 (79%)
#
# Test set for client: Average loss: 0.0132, Accuracy: 7864/10000 (79%)
#
# Test set for client: Average loss: 0.0132, Accuracy: 7836/10000 (78%)
#
# Test set for client: Average loss: 0.0134, Accuracy: 7663/10000 (77%)
#
# Test set for client: Average loss: 0.0133, Accuracy: 7770/10000 (78%)
# Train Epoch: 26 [0/50000 (0%)]	Loss: 1.673570
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 1.615297
#
# Train set for client: Accuracy: 40697/50000 (81%)
#
#
# Test set for client: Average loss: 0.0135, Accuracy: 7458/10000 (75%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 8048/10000 (80%)
#
# Test set for client: Average loss: 0.0130, Accuracy: 8160/10000 (82%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 7999/10000 (80%)
#
# Test set for client: Average loss: 0.0132, Accuracy: 7848/10000 (78%)
# Train Epoch: 27 [0/50000 (0%)]	Loss: 1.624129
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 1.622198
#
# Train set for client: Accuracy: 41048/50000 (82%)
#
#
# Test set for client: Average loss: 0.0131, Accuracy: 8036/10000 (80%)
#
# Test set for client: Average loss: 0.0130, Accuracy: 8103/10000 (81%)
#
# Test set for client: Average loss: 0.0130, Accuracy: 8141/10000 (81%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 8082/10000 (81%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 8077/10000 (81%)
# Train Epoch: 28 [0/50000 (0%)]	Loss: 1.663493
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 1.625386
#
# Train set for client: Accuracy: 41064/50000 (82%)
#
#
# Test set for client: Average loss: 0.0133, Accuracy: 7781/10000 (78%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 8038/10000 (80%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 8036/10000 (80%)
#
# Test set for client: Average loss: 0.0132, Accuracy: 7940/10000 (79%)
#
# Test set for client: Average loss: 0.0132, Accuracy: 7879/10000 (79%)
# Train Epoch: 29 [0/50000 (0%)]	Loss: 1.659549
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 1.601750
#
# Train set for client: Accuracy: 41129/50000 (82%)
#
#
# Test set for client: Average loss: 0.0132, Accuracy: 7916/10000 (79%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 8014/10000 (80%)
#
# Test set for client: Average loss: 0.0132, Accuracy: 7911/10000 (79%)
#
# Test set for client: Average loss: 0.0132, Accuracy: 7938/10000 (79%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 7947/10000 (79%)
# Train Epoch: 30 [0/50000 (0%)]	Loss: 1.681581
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 1.586292
#
# Train set for client: Accuracy: 41501/50000 (83%)
#
#
# Test set for client: Average loss: 0.0131, Accuracy: 8033/10000 (80%)
#
# Test set for client: Average loss: 0.0129, Accuracy: 8248/10000 (82%)
#
# Test set for client: Average loss: 0.0130, Accuracy: 8194/10000 (82%)
#
# Test set for client: Average loss: 0.0129, Accuracy: 8275/10000 (83%)
#
# Test set for client: Average loss: 0.0129, Accuracy: 8220/10000 (82%)
# Train Epoch: 31 [0/50000 (0%)]	Loss: 1.633586
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 1.607292
#
# Train set for client: Accuracy: 41603/50000 (83%)
#
#
# Test set for client: Average loss: 0.0130, Accuracy: 8075/10000 (81%)
#
# Test set for client: Average loss: 0.0129, Accuracy: 8228/10000 (82%)
#
# Test set for client: Average loss: 0.0129, Accuracy: 8236/10000 (82%)
#
# Test set for client: Average loss: 0.0129, Accuracy: 8216/10000 (82%)
#
# Test set for client: Average loss: 0.0130, Accuracy: 8125/10000 (81%)
# Train Epoch: 32 [0/50000 (0%)]	Loss: 1.629140
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 1.631621
#
# Train set for client: Accuracy: 41471/50000 (83%)
#
#
# Test set for client: Average loss: 0.0133, Accuracy: 7838/10000 (78%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 7995/10000 (80%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 8049/10000 (80%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 8037/10000 (80%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 7984/10000 (80%)
# Train Epoch: 33 [0/50000 (0%)]	Loss: 1.624143
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 1.571307
#
# Train set for client: Accuracy: 41743/50000 (83%)
#
#
# Test set for client: Average loss: 0.0135, Accuracy: 7512/10000 (75%)
#
# Test set for client: Average loss: 0.0130, Accuracy: 8118/10000 (81%)
#
# Test set for client: Average loss: 0.0136, Accuracy: 7361/10000 (74%)
#
# Test set for client: Average loss: 0.0134, Accuracy: 7677/10000 (77%)
#
# Test set for client: Average loss: 0.0135, Accuracy: 7570/10000 (76%)
# Train Epoch: 34 [0/50000 (0%)]	Loss: 1.697837
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 1.664632
#
# Train set for client: Accuracy: 41768/50000 (84%)
#
#
# Test set for client: Average loss: 0.0130, Accuracy: 8151/10000 (82%)
#
# Test set for client: Average loss: 0.0130, Accuracy: 8115/10000 (81%)
#
# Test set for client: Average loss: 0.0130, Accuracy: 8185/10000 (82%)
#
# Test set for client: Average loss: 0.0129, Accuracy: 8246/10000 (82%)
#
# Test set for client: Average loss: 0.0130, Accuracy: 8209/10000 (82%)
# Train Epoch: 35 [0/50000 (0%)]	Loss: 1.584370
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 1.663915
#
# Train set for client: Accuracy: 41935/50000 (84%)
#
#
# Test set for client: Average loss: 0.0131, Accuracy: 7979/10000 (80%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 8046/10000 (80%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 8013/10000 (80%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 8035/10000 (80%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 7999/10000 (80%)
# Train Epoch: 36 [0/50000 (0%)]	Loss: 1.684252
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 1.657293
#
# Train set for client: Accuracy: 41927/50000 (84%)
#
#
# Test set for client: Average loss: 0.0131, Accuracy: 8064/10000 (81%)
#
# Test set for client: Average loss: 0.0130, Accuracy: 8126/10000 (81%)
#
# Test set for client: Average loss: 0.0130, Accuracy: 8128/10000 (81%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 8036/10000 (80%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 8056/10000 (81%)
# Train Epoch: 37 [0/50000 (0%)]	Loss: 1.573214
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 1.616670
#
# Train set for client: Accuracy: 42174/50000 (84%)
#
#
# Test set for client: Average loss: 0.0132, Accuracy: 7931/10000 (79%)
#
# Test set for client: Average loss: 0.0130, Accuracy: 8130/10000 (81%)
#
# Test set for client: Average loss: 0.0129, Accuracy: 8243/10000 (82%)
#
# Test set for client: Average loss: 0.0129, Accuracy: 8212/10000 (82%)
#
# Test set for client: Average loss: 0.0130, Accuracy: 8125/10000 (81%)
# Train Epoch: 38 [0/50000 (0%)]	Loss: 1.593051
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 1.646115
#
# Train set for client: Accuracy: 42313/50000 (85%)
#
#
# Test set for client: Average loss: 0.0128, Accuracy: 8400/10000 (84%)
#
# Test set for client: Average loss: 0.0129, Accuracy: 8331/10000 (83%)
#
# Test set for client: Average loss: 0.0129, Accuracy: 8294/10000 (83%)
#
# Test set for client: Average loss: 0.0128, Accuracy: 8377/10000 (84%)
#
# Test set for client: Average loss: 0.0128, Accuracy: 8383/10000 (84%)
# Train Epoch: 39 [0/50000 (0%)]	Loss: 1.589280
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 1.620358
#
# Train set for client: Accuracy: 42279/50000 (85%)
#
#
# Test set for client: Average loss: 0.0132, Accuracy: 7920/10000 (79%)
#
# Test set for client: Average loss: 0.0129, Accuracy: 8263/10000 (83%)
#
# Test set for client: Average loss: 0.0129, Accuracy: 8292/10000 (83%)
#
# Test set for client: Average loss: 0.0130, Accuracy: 8129/10000 (81%)
#
# Test set for client: Average loss: 0.0131, Accuracy: 8060/10000 (81%)
# Train Epoch: 40 [0/50000 (0%)]	Loss: 1.617570
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 1.568205
#
# Train set for client: Accuracy: 43577/50000 (87%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8599/10000 (86%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8607/10000 (86%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8593/10000 (86%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8606/10000 (86%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8615/10000 (86%)
# Train Epoch: 41 [0/50000 (0%)]	Loss: 1.579001
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 1.560021
#
# Train set for client: Accuracy: 43861/50000 (88%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8677/10000 (87%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8680/10000 (87%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8675/10000 (87%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8677/10000 (87%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8676/10000 (87%)
# Train Epoch: 42 [0/50000 (0%)]	Loss: 1.598529
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 1.573506
#
# Train set for client: Accuracy: 44130/50000 (88%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8544/10000 (85%)
#
# Test set for client: Average loss: 0.0127, Accuracy: 8534/10000 (85%)
#
# Test set for client: Average loss: 0.0127, Accuracy: 8570/10000 (86%)
#
# Test set for client: Average loss: 0.0127, Accuracy: 8543/10000 (85%)
#
# Test set for client: Average loss: 0.0127, Accuracy: 8547/10000 (85%)
# Train Epoch: 43 [0/50000 (0%)]	Loss: 1.597215
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 1.595690
#
# Train set for client: Accuracy: 44046/50000 (88%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8683/10000 (87%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8684/10000 (87%)
#
# Test set for client: Average loss: 0.0125, Accuracy: 8736/10000 (87%)
#
# Test set for client: Average loss: 0.0125, Accuracy: 8727/10000 (87%)
#
# Test set for client: Average loss: 0.0125, Accuracy: 8723/10000 (87%)
# Train Epoch: 44 [0/50000 (0%)]	Loss: 1.548464
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 1.579703
#
# Train set for client: Accuracy: 44269/50000 (89%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8631/10000 (86%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8644/10000 (86%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8646/10000 (86%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8663/10000 (87%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8615/10000 (86%)
# Train Epoch: 45 [0/50000 (0%)]	Loss: 1.583654
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 1.600097
#
# Train set for client: Accuracy: 44320/50000 (89%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8630/10000 (86%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8657/10000 (87%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8615/10000 (86%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8596/10000 (86%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8639/10000 (86%)
# Train Epoch: 46 [0/50000 (0%)]	Loss: 1.541949
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 1.606351
#
# Train set for client: Accuracy: 44379/50000 (89%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8682/10000 (87%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8692/10000 (87%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8680/10000 (87%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8703/10000 (87%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8705/10000 (87%)
# Train Epoch: 47 [0/50000 (0%)]	Loss: 1.588632
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 1.560990
#
# Train set for client: Accuracy: 44597/50000 (89%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8465/10000 (85%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8631/10000 (86%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8641/10000 (86%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8666/10000 (87%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8646/10000 (86%)
# Train Epoch: 48 [0/50000 (0%)]	Loss: 1.549509
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 1.563514
#
# Train set for client: Accuracy: 44461/50000 (89%)
#
#
# Test set for client: Average loss: 0.0126, Accuracy: 8675/10000 (87%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8625/10000 (86%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8656/10000 (87%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8664/10000 (87%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8666/10000 (87%)
# Train Epoch: 49 [0/50000 (0%)]	Loss: 1.540343
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 1.621320
#
# Train set for client: Accuracy: 44560/50000 (89%)
#
#
# Test set for client: Average loss: 0.0127, Accuracy: 8579/10000 (86%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8617/10000 (86%)
#
# Test set for client: Average loss: 0.0127, Accuracy: 8569/10000 (86%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8622/10000 (86%)
#
# Test set for client: Average loss: 0.0126, Accuracy: 8655/10000 (87%)
