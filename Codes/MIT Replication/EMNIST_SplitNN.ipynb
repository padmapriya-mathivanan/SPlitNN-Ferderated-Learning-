# %%
from torchvision import datasets,transforms
import torch
import random
import torch.nn.functional as f
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchsummary import summary

# %%
'''LeNet in PyTorch.'''
import torch.nn as nn
import torch.nn.functional as F

class LeNet(nn.Module):
    def __init__(self,input_channel=3,output_channel=10):
        super(LeNet, self).__init__()
        self.conv1 = nn.Conv2d(input_channel, 6, 5)
        self.maxpool1 = nn.MaxPool2d((2,2))
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.maxpool2 = nn.MaxPool2d((2,2))
        self.fc1 = nn.Linear(256,120)
        self.fc2   = nn.Linear(120, 84)
        self.fc3   = nn.Linear(84, output_channel)
        self.output_channel = output_channel

    def forward(self, x):
        out = F.relu(self.conv1(x))
        out = self.maxpool1(out)
        out = F.relu(self.conv2(out))
        out = self.maxpool2(out)
        out = out.view(out.size(0), -1)
        out = F.relu(self.fc1(out))
        out = F.relu(self.fc2(out))
        out = F.softmax(self.fc3(out))
        return out


class LeNetServer(nn.Module):
    def __init__(self,input_channel=256,output_channel=10):
        super(LeNetServer, self).__init__()
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.maxpool2 = nn.MaxPool2d((2,2))
        self.fc1 = nn.Linear(input_channel,120)
        self.fc2   = nn.Linear(120, 84)
        self.fc3   = nn.Linear(84, output_channel)
        self.output_channel = output_channel

    def forward(self, x):
        out = F.relu(self.conv2(x))
        out = self.maxpool2(out)
        out = out.view(out.size(0), -1)
        out = F.relu(self.fc1(out))
        out = F.relu(self.fc2(out))
        out = F.softmax(self.fc3(out))
        return out

class LeNetClient(nn.Module):
    def __init__(self,input_channel=3):
        super(LeNetClient, self).__init__()
        self.conv1 = nn.Conv2d(input_channel, 6, 5)
        self.maxpool1 = nn.MaxPool2d((2,2))

    def forward(self, x):
        out = F.relu(self.conv1(x))
        out = self.maxpool1(out)
        return out

# %%
'''VGG11/13/16/19 in Pytorch.'''
import torch
import torch.nn as nn
import torch.nn.functional as F


cfg = {
    'VGG11': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512],
    'VGG16_client' : [64, 64, 'M', 128, 128, 'M', 256, 256, 'M'],
    'VGG16_server' : [512, 512, 512, 'M', 512, 512, 512],
    'VGG11_client' : [64, 'M'],
    'VGG11_server' : [128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M']
}


class VGG(nn.Module):
    def __init__(self, vgg_name, in_channels = 3,dense_output = 10):
        super(VGG, self).__init__()
        self.features = self._make_layers(cfg[vgg_name],in_channels)
        self.classifier = nn.Sequential(nn.Linear(512, 256),
                            nn.ReLU(inplace=True),nn.Dropout(p=0.25),nn.Linear(256, 128),
                            nn.ReLU(inplace=True),nn.Dropout(p=0.25),nn.Linear(128,dense_output))

    def forward(self, x):
        out = self.features(x)
        out = out.view(out.size(0), -1)
        out = self.classifier(out)
        out = F.softmax(out)
        return out

    def _make_layers(self, cfg, in_channels):
        layers = []
        for x in cfg:
            if x == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                           nn.BatchNorm2d(x),
                           nn.ReLU(inplace=True)]
                in_channels = x
        return nn.Sequential(*layers)

class VGGClient(nn.Module):
    def __init__(self, vgg_name,in_channels=3):
        super(VGGClient, self).__init__()
        self.features = self._make_layers(cfg[vgg_name],in_channels)

    def forward(self, x):
        out = self.features(x)
        return out

    def _make_layers(self, cfg,in_channels):
        layers = []
        for x in cfg:
            if x == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                           nn.BatchNorm2d(x),
                           nn.ReLU(inplace=True)]
                in_channels = x
        return nn.Sequential(*layers)

# %%
def get_emnist_dataset():
    train_dataset = datasets.EMNIST('./data', split='balanced', train=True, download=True,
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1751,), (0.3267,))
                       ]))

    test_dataset = datasets.EMNIST('./data', split='balanced', train=False, transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1751,), (0.3267,))
                       ]))

    train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=64, shuffle=True)
    test_loader = torch.utils.data.DataLoader(test_dataset,batch_size=64, shuffle=False)

    return train_loader,test_loader

# %%
def train(server,server_opt,client,client_opt,device,train_loader,epoch):
    server.train()
    criterion = nn.CrossEntropyLoss()
    cli_length = len(client)
    for i in range(cli_length):
        client[i].train()
    client_parameters = None
    correct = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        ### picking the client to process this batch of data
        clt = client[batch_idx%cli_length]
        clt_opt = client_opt[batch_idx%cli_length]
        
        if client_parameters:
            clt.load_state_dict(client_parameters.state_dict())

        data, target = data.to(device), target.to(device)
        server_opt.zero_grad()
        clt_opt.zero_grad()
        
        ### passing the result of the client to the server classifier
        intermediate = clt(data)
        intermediate = intermediate.detach().requires_grad_()
        intermediate.to(device)        
        ### calculating the loss at the server
        output = server(intermediate)
        loss = criterion(output,target)
        loss.backward()
        server_opt.step()
        
        ### passing the gradient calculated at the server to the client
        grad = intermediate.grad.clone()
        intermediate.backward(grad)
        clt_opt.step()
        client_parameters = clt

        pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()
        ### printing logs
        if batch_idx % 400 == 0:
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
    
    print("training accuracy : {:.2f}%".format(100.0*correct/len(train_loader.dataset)))

def test(client,server,device,test_loader):
    server.eval()
    criterion = nn.CrossEntropyLoss()
    for i in range(len(client)):
        client[i].eval()

    with torch.no_grad():
        for i in range(len(client)):
            test_loss = 0
            correct = 0
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = client[i](data)
                output = server(output)
                test_loss += criterion(output, target).item()  # sum up batch loss
                pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
                correct += pred.eq(target.view_as(pred)).sum().item()
                
            test_loss /= len(test_loader.dataset)
            print('\nTest set for client-{}: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(i,
                test_loss, correct, len(test_loader.dataset),
                100. * correct / len(test_loader.dataset)))

def adjust_learning_rate(optimizer, init_lr, epoch):
    lr = init_lr * (0.5 ** (epoch // 50))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
if __name__ == "__main__":
    random.seed(7)
    torch.manual_seed(7)
    if torch.cuda.is_available():  
        dev = "cuda:0" 
    else:  
        dev = "cpu"
    device = torch.device(dev)
    train_loader,test_loader = get_mnist_dataset()

    server = VGG(vgg_name='VGG16_server',in_channels=256,dense_output=47).to(device)
    server_optim = optim.SGD(server.parameters(),lr=1e-3,weight_decay=5e-4)

    clients=[]
    client_optim=[]
    for i in range(5):
        cli = VGGClient(vgg_name='VGG16_client',in_channels=1).to(device)
        clients.append(cli)
        client_optim.append(optim.SGD(cli.parameters(),lr=1e-3,weight_decay=5e-4))
    
    print("\n\nModel Summary")
    print("\nClient:")
    summary(clients[0],(1,28,28))
    print("\n\nServer:")
    summary(server,(256,3,3))

    init_lr = 0.1
    for i in range(1,200):
        adjust_learning_rate(server_optim,init_lr,i)
        for op in client_optim:
            adjust_learning_rate(op,init_lr,i)
        train(server,server_optim,clients,client_optim,device,train_loader,i)
        test(clients,server,device,test_loader)

    torch.save({'server':server.state_dict(),
            'client1':clients[0].state_dict(),
            'client2':clients[1].state_dict(),
            'client3':clients[2].state_dict(),
            'client4':clients[2].state_dict(),
            'client5':clients[3].state_dict()},"split-model.pt")
# Out:
# Model Summary
#
# Client:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 28, 28]             640
#        BatchNorm2d-2           [-1, 64, 28, 28]             128
#               ReLU-3           [-1, 64, 28, 28]               0
#             Conv2d-4           [-1, 64, 28, 28]          36,928
#        BatchNorm2d-5           [-1, 64, 28, 28]             128
#               ReLU-6           [-1, 64, 28, 28]               0
#          MaxPool2d-7           [-1, 64, 14, 14]               0
#             Conv2d-8          [-1, 128, 14, 14]          73,856
#        BatchNorm2d-9          [-1, 128, 14, 14]             256
#              ReLU-10          [-1, 128, 14, 14]               0
#            Conv2d-11          [-1, 128, 14, 14]         147,584
#       BatchNorm2d-12          [-1, 128, 14, 14]             256
#              ReLU-13          [-1, 128, 14, 14]               0
#         MaxPool2d-14            [-1, 128, 7, 7]               0
#            Conv2d-15            [-1, 256, 7, 7]         295,168
#       BatchNorm2d-16            [-1, 256, 7, 7]             512
#              ReLU-17            [-1, 256, 7, 7]               0
#            Conv2d-18            [-1, 256, 7, 7]         590,080
#       BatchNorm2d-19            [-1, 256, 7, 7]             512
#              ReLU-20            [-1, 256, 7, 7]               0
#         MaxPool2d-21            [-1, 256, 3, 3]               0
# ================================================================
# Total params: 1,146,048
# Trainable params: 1,146,048
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 4.18
# Params size (MB): 4.37
# Estimated Total Size (MB): 8.56
# ----------------------------------------------------------------
#
#
# Server:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 512, 3, 3]       1,180,160
#        BatchNorm2d-2            [-1, 512, 3, 3]           1,024
#               ReLU-3            [-1, 512, 3, 3]               0
#             Conv2d-4            [-1, 512, 3, 3]       2,359,808
#        BatchNorm2d-5            [-1, 512, 3, 3]           1,024
#               ReLU-6            [-1, 512, 3, 3]               0
#             Conv2d-7            [-1, 512, 3, 3]       2,359,808
#        BatchNorm2d-8            [-1, 512, 3, 3]           1,024
#               ReLU-9            [-1, 512, 3, 3]               0
#         MaxPool2d-10            [-1, 512, 1, 1]               0
#            Conv2d-11            [-1, 512, 1, 1]       2,359,808
#       BatchNorm2d-12            [-1, 512, 1, 1]           1,024
#              ReLU-13            [-1, 512, 1, 1]               0
#            Conv2d-14            [-1, 512, 1, 1]       2,359,808
#       BatchNorm2d-15            [-1, 512, 1, 1]           1,024
#              ReLU-16            [-1, 512, 1, 1]               0
#            Conv2d-17            [-1, 512, 1, 1]       2,359,808
#       BatchNorm2d-18            [-1, 512, 1, 1]           1,024
#              ReLU-19            [-1, 512, 1, 1]               0
#            Linear-20                  [-1, 256]         131,328
#              ReLU-21                  [-1, 256]               0
#           Dropout-22                  [-1, 256]               0
#            Linear-23                  [-1, 128]          32,896
#              ReLU-24                  [-1, 128]               0
#           Dropout-25                  [-1, 128]               0
#            Linear-26                   [-1, 47]           6,063
# ================================================================
# Total params: 13,155,631
# Trainable params: 13,155,631
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.36
# Params size (MB): 50.18
# Estimated Total Size (MB): 50.56
# ----------------------------------------------------------------
# Train Epoch: 1 [0/112800 (0%)]	Loss: 3.850151
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Train Epoch: 1 [25600/112800 (23%)]	Loss: 3.846100
# Train Epoch: 1 [51200/112800 (45%)]	Loss: 3.807540
# Train Epoch: 1 [76800/112800 (68%)]	Loss: 3.773494
# Train Epoch: 1 [102400/112800 (91%)]	Loss: 3.732697
# training accuracy : 10.97%
#
# Test set for client-0: Average loss: 0.0580, Accuracy: 3183/18800 (17%)
#
#
# Test set for client-1: Average loss: 0.0580, Accuracy: 3184/18800 (17%)
#
#
# Test set for client-2: Average loss: 0.0580, Accuracy: 3185/18800 (17%)
#
#
# Test set for client-3: Average loss: 0.0580, Accuracy: 3189/18800 (17%)
#
#
# Test set for client-4: Average loss: 0.0580, Accuracy: 3182/18800 (17%)
#
# Train Epoch: 2 [0/112800 (0%)]	Loss: 3.654934
# Train Epoch: 2 [25600/112800 (23%)]	Loss: 3.592323
# Train Epoch: 2 [51200/112800 (45%)]	Loss: 3.642239
# Train Epoch: 2 [76800/112800 (68%)]	Loss: 3.630128
# Train Epoch: 2 [102400/112800 (91%)]	Loss: 3.539530
# training accuracy : 23.76%
#
# Test set for client-0: Average loss: 0.0563, Accuracy: 5222/18800 (28%)
#
#
# Test set for client-1: Average loss: 0.0563, Accuracy: 5217/18800 (28%)
#
#
# Test set for client-2: Average loss: 0.0563, Accuracy: 5218/18800 (28%)
#
#
# Test set for client-3: Average loss: 0.0563, Accuracy: 5224/18800 (28%)
#
#
# Test set for client-4: Average loss: 0.0563, Accuracy: 5223/18800 (28%)
#
# Train Epoch: 3 [0/112800 (0%)]	Loss: 3.570281
# Train Epoch: 3 [25600/112800 (23%)]	Loss: 3.599915
# Train Epoch: 3 [51200/112800 (45%)]	Loss: 3.465479
# Train Epoch: 3 [76800/112800 (68%)]	Loss: 3.551236
# Train Epoch: 3 [102400/112800 (91%)]	Loss: 3.485659
# training accuracy : 34.59%
#
# Test set for client-0: Average loss: 0.0544, Accuracy: 7542/18800 (40%)
#
#
# Test set for client-1: Average loss: 0.0544, Accuracy: 7540/18800 (40%)
#
#
# Test set for client-2: Average loss: 0.0544, Accuracy: 7539/18800 (40%)
#
#
# Test set for client-3: Average loss: 0.0544, Accuracy: 7547/18800 (40%)
#
#
# Test set for client-4: Average loss: 0.0544, Accuracy: 7547/18800 (40%)
#
# Train Epoch: 4 [0/112800 (0%)]	Loss: 3.518432
# Train Epoch: 4 [25600/112800 (23%)]	Loss: 3.552943
# Train Epoch: 4 [51200/112800 (45%)]	Loss: 3.431449
# Train Epoch: 4 [76800/112800 (68%)]	Loss: 3.434789
# Train Epoch: 4 [102400/112800 (91%)]	Loss: 3.359518
# training accuracy : 45.24%
#
# Test set for client-0: Average loss: 0.0527, Accuracy: 9667/18800 (51%)
#
#
# Test set for client-1: Average loss: 0.0527, Accuracy: 9660/18800 (51%)
#
#
# Test set for client-2: Average loss: 0.0527, Accuracy: 9663/18800 (51%)
#
#
# Test set for client-3: Average loss: 0.0527, Accuracy: 9668/18800 (51%)
#
#
# Test set for client-4: Average loss: 0.0527, Accuracy: 9664/18800 (51%)
#
# Train Epoch: 5 [0/112800 (0%)]	Loss: 3.334901
# Train Epoch: 5 [25600/112800 (23%)]	Loss: 3.289443
# Train Epoch: 5 [51200/112800 (45%)]	Loss: 3.288167
# Train Epoch: 5 [76800/112800 (68%)]	Loss: 3.301020
# Train Epoch: 5 [102400/112800 (91%)]	Loss: 3.198553
# training accuracy : 60.06%
#
# Test set for client-0: Average loss: 0.0502, Accuracy: 12839/18800 (68%)
#
#
# Test set for client-1: Average loss: 0.0502, Accuracy: 12839/18800 (68%)
#
#
# Test set for client-2: Average loss: 0.0502, Accuracy: 12831/18800 (68%)
#
#
# Test set for client-3: Average loss: 0.0502, Accuracy: 12840/18800 (68%)
#
#
# Test set for client-4: Average loss: 0.0502, Accuracy: 12836/18800 (68%)
#
# Train Epoch: 6 [0/112800 (0%)]	Loss: 3.159975
# Train Epoch: 6 [25600/112800 (23%)]	Loss: 3.235907
# Train Epoch: 6 [51200/112800 (45%)]	Loss: 3.183644
# Train Epoch: 6 [76800/112800 (68%)]	Loss: 3.167312
# Train Epoch: 6 [102400/112800 (91%)]	Loss: 3.241614
# training accuracy : 70.95%
#
# Test set for client-0: Average loss: 0.0498, Accuracy: 13233/18800 (70%)
#
#
# Test set for client-1: Average loss: 0.0498, Accuracy: 13236/18800 (70%)
#
#
# Test set for client-2: Average loss: 0.0498, Accuracy: 13234/18800 (70%)
#
#
# Test set for client-3: Average loss: 0.0498, Accuracy: 13226/18800 (70%)
#
#
# Test set for client-4: Average loss: 0.0498, Accuracy: 13231/18800 (70%)
#
# Train Epoch: 7 [0/112800 (0%)]	Loss: 3.209522
# Train Epoch: 7 [25600/112800 (23%)]	Loss: 3.153008
# Train Epoch: 7 [51200/112800 (45%)]	Loss: 3.088815
# Train Epoch: 7 [76800/112800 (68%)]	Loss: 3.182345
# Train Epoch: 7 [102400/112800 (91%)]	Loss: 3.159807
# training accuracy : 74.60%
#
# Test set for client-0: Average loss: 0.0491, Accuracy: 14090/18800 (75%)
#
#
# Test set for client-1: Average loss: 0.0491, Accuracy: 14091/18800 (75%)
#
#
# Test set for client-2: Average loss: 0.0491, Accuracy: 14093/18800 (75%)
#
#
# Test set for client-3: Average loss: 0.0491, Accuracy: 14091/18800 (75%)
#
#
# Test set for client-4: Average loss: 0.0491, Accuracy: 14095/18800 (75%)
#
# Train Epoch: 8 [0/112800 (0%)]	Loss: 3.156081
# Train Epoch: 8 [25600/112800 (23%)]	Loss: 3.112959
# Train Epoch: 8 [51200/112800 (45%)]	Loss: 3.191458
# Train Epoch: 8 [76800/112800 (68%)]	Loss: 3.200917
# Train Epoch: 8 [102400/112800 (91%)]	Loss: 3.227636
# training accuracy : 77.49%
#
# Test set for client-0: Average loss: 0.0490, Accuracy: 14189/18800 (75%)
#
#
# Test set for client-1: Average loss: 0.0490, Accuracy: 14195/18800 (76%)
#
#
# Test set for client-2: Average loss: 0.0490, Accuracy: 14203/18800 (76%)
#
#
# Test set for client-3: Average loss: 0.0490, Accuracy: 14203/18800 (76%)
#
#
# Test set for client-4: Average loss: 0.0490, Accuracy: 14194/18800 (76%)
#
# Train Epoch: 9 [0/112800 (0%)]	Loss: 3.052908
# Train Epoch: 9 [25600/112800 (23%)]	Loss: 3.095019
# Train Epoch: 9 [51200/112800 (45%)]	Loss: 3.115926
# Train Epoch: 9 [76800/112800 (68%)]	Loss: 3.119427
# Train Epoch: 9 [102400/112800 (91%)]	Loss: 3.108502
# training accuracy : 79.02%
#
# Test set for client-0: Average loss: 0.0486, Accuracy: 14717/18800 (78%)
#
#
# Test set for client-1: Average loss: 0.0486, Accuracy: 14713/18800 (78%)
#
#
# Test set for client-2: Average loss: 0.0486, Accuracy: 14711/18800 (78%)
#
#
# Test set for client-3: Average loss: 0.0486, Accuracy: 14718/18800 (78%)
#
#
# Test set for client-4: Average loss: 0.0486, Accuracy: 14720/18800 (78%)
#
# Train Epoch: 10 [0/112800 (0%)]	Loss: 3.090456
# Train Epoch: 10 [25600/112800 (23%)]	Loss: 3.093868
# Train Epoch: 10 [51200/112800 (45%)]	Loss: 3.104678
# Train Epoch: 10 [76800/112800 (68%)]	Loss: 3.048537
# Train Epoch: 10 [102400/112800 (91%)]	Loss: 3.052977
# training accuracy : 80.52%
#
# Test set for client-0: Average loss: 0.0483, Accuracy: 15122/18800 (80%)
#
#
# Test set for client-1: Average loss: 0.0483, Accuracy: 15121/18800 (80%)
#
#
# Test set for client-2: Average loss: 0.0483, Accuracy: 15130/18800 (80%)
#
#
# Test set for client-3: Average loss: 0.0482, Accuracy: 15131/18800 (80%)
#
#
# Test set for client-4: Average loss: 0.0482, Accuracy: 15135/18800 (81%)
#
# Train Epoch: 11 [0/112800 (0%)]	Loss: 3.095278
# Train Epoch: 11 [25600/112800 (23%)]	Loss: 3.094202
# Train Epoch: 11 [51200/112800 (45%)]	Loss: 3.063572
# Train Epoch: 11 [76800/112800 (68%)]	Loss: 3.081650
# Train Epoch: 11 [102400/112800 (91%)]	Loss: 2.998008
# training accuracy : 81.89%
#
# Test set for client-0: Average loss: 0.0483, Accuracy: 15065/18800 (80%)
#
#
# Test set for client-1: Average loss: 0.0483, Accuracy: 15057/18800 (80%)
#
#
# Test set for client-2: Average loss: 0.0483, Accuracy: 15067/18800 (80%)
#
#
# Test set for client-3: Average loss: 0.0483, Accuracy: 15062/18800 (80%)
#
#
# Test set for client-4: Average loss: 0.0483, Accuracy: 15057/18800 (80%)
#
# Train Epoch: 12 [0/112800 (0%)]	Loss: 3.055386
# Train Epoch: 12 [25600/112800 (23%)]	Loss: 3.074495
# Train Epoch: 12 [51200/112800 (45%)]	Loss: 3.056648
# Train Epoch: 12 [76800/112800 (68%)]	Loss: 3.075340
# Train Epoch: 12 [102400/112800 (91%)]	Loss: 3.010909
# training accuracy : 82.27%
#
# Test set for client-0: Average loss: 0.0482, Accuracy: 15111/18800 (80%)
#
#
# Test set for client-1: Average loss: 0.0482, Accuracy: 15124/18800 (80%)
#
#
# Test set for client-2: Average loss: 0.0482, Accuracy: 15124/18800 (80%)
#
#
# Test set for client-3: Average loss: 0.0482, Accuracy: 15112/18800 (80%)
#
#
# Test set for client-4: Average loss: 0.0482, Accuracy: 15108/18800 (80%)
#
# Train Epoch: 13 [0/112800 (0%)]	Loss: 3.070157
# Train Epoch: 13 [25600/112800 (23%)]	Loss: 3.056464
# Train Epoch: 13 [51200/112800 (45%)]	Loss: 3.056813
# Train Epoch: 13 [76800/112800 (68%)]	Loss: 3.024481
# Train Epoch: 13 [102400/112800 (91%)]	Loss: 3.040415
# training accuracy : 82.48%
#
# Test set for client-0: Average loss: 0.0481, Accuracy: 15262/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0481, Accuracy: 15259/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0481, Accuracy: 15265/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0481, Accuracy: 15261/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0481, Accuracy: 15270/18800 (81%)
#
# Train Epoch: 14 [0/112800 (0%)]	Loss: 3.034053
# Train Epoch: 14 [25600/112800 (23%)]	Loss: 3.120097
# Train Epoch: 14 [51200/112800 (45%)]	Loss: 3.002987
# Train Epoch: 14 [76800/112800 (68%)]	Loss: 2.966589
# Train Epoch: 14 [102400/112800 (91%)]	Loss: 3.012403
# training accuracy : 82.86%
#
# Test set for client-0: Average loss: 0.0483, Accuracy: 15106/18800 (80%)
#
#
# Test set for client-1: Average loss: 0.0483, Accuracy: 15100/18800 (80%)
#
#
# Test set for client-2: Average loss: 0.0483, Accuracy: 15102/18800 (80%)
#
#
# Test set for client-3: Average loss: 0.0483, Accuracy: 15105/18800 (80%)
#
#
# Test set for client-4: Average loss: 0.0483, Accuracy: 15104/18800 (80%)
#
# Train Epoch: 15 [0/112800 (0%)]	Loss: 3.061128
# Train Epoch: 15 [25600/112800 (23%)]	Loss: 3.089473
# Train Epoch: 15 [51200/112800 (45%)]	Loss: 3.037416
# Train Epoch: 15 [76800/112800 (68%)]	Loss: 3.097307
# Train Epoch: 15 [102400/112800 (91%)]	Loss: 3.016869
# training accuracy : 83.14%
#
# Test set for client-0: Average loss: 0.0489, Accuracy: 14356/18800 (76%)
#
#
# Test set for client-1: Average loss: 0.0489, Accuracy: 14366/18800 (76%)
#
#
# Test set for client-2: Average loss: 0.0489, Accuracy: 14354/18800 (76%)
#
#
# Test set for client-3: Average loss: 0.0489, Accuracy: 14373/18800 (76%)
#
#
# Test set for client-4: Average loss: 0.0489, Accuracy: 14364/18800 (76%)
#
# Train Epoch: 16 [0/112800 (0%)]	Loss: 3.138518
# Train Epoch: 16 [25600/112800 (23%)]	Loss: 3.060414
# Train Epoch: 16 [51200/112800 (45%)]	Loss: 3.085244
# Train Epoch: 16 [76800/112800 (68%)]	Loss: 3.089047
# Train Epoch: 16 [102400/112800 (91%)]	Loss: 2.999227
# training accuracy : 83.28%
#
# Test set for client-0: Average loss: 0.0481, Accuracy: 15243/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0481, Accuracy: 15243/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0481, Accuracy: 15244/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0481, Accuracy: 15236/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0481, Accuracy: 15242/18800 (81%)
#
# Train Epoch: 17 [0/112800 (0%)]	Loss: 3.048007
# Train Epoch: 17 [25600/112800 (23%)]	Loss: 3.101412
# Train Epoch: 17 [51200/112800 (45%)]	Loss: 3.083187
# Train Epoch: 17 [76800/112800 (68%)]	Loss: 3.010671
# Train Epoch: 17 [102400/112800 (91%)]	Loss: 3.023687
# training accuracy : 83.29%
#
# Test set for client-0: Average loss: 0.0486, Accuracy: 14691/18800 (78%)
#
#
# Test set for client-1: Average loss: 0.0486, Accuracy: 14685/18800 (78%)
#
#
# Test set for client-2: Average loss: 0.0486, Accuracy: 14691/18800 (78%)
#
#
# Test set for client-3: Average loss: 0.0486, Accuracy: 14680/18800 (78%)
#
#
# Test set for client-4: Average loss: 0.0486, Accuracy: 14679/18800 (78%)
#
# Train Epoch: 18 [0/112800 (0%)]	Loss: 3.092382
# Train Epoch: 18 [25600/112800 (23%)]	Loss: 3.005089
# Train Epoch: 18 [51200/112800 (45%)]	Loss: 3.092434
# Train Epoch: 18 [76800/112800 (68%)]	Loss: 3.077791
# Train Epoch: 18 [102400/112800 (91%)]	Loss: 3.020607
# training accuracy : 83.51%
#
# Test set for client-0: Average loss: 0.0482, Accuracy: 15202/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0482, Accuracy: 15200/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0482, Accuracy: 15201/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0482, Accuracy: 15210/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0482, Accuracy: 15201/18800 (81%)
#
# Train Epoch: 19 [0/112800 (0%)]	Loss: 3.049581
# Train Epoch: 19 [25600/112800 (23%)]	Loss: 2.997446
# Train Epoch: 19 [51200/112800 (45%)]	Loss: 3.015135
# Train Epoch: 19 [76800/112800 (68%)]	Loss: 3.086992
# Train Epoch: 19 [102400/112800 (91%)]	Loss: 2.998481
# training accuracy : 83.49%
#
# Test set for client-0: Average loss: 0.0481, Accuracy: 15218/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0482, Accuracy: 15217/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0482, Accuracy: 15215/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0481, Accuracy: 15221/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0481, Accuracy: 15223/18800 (81%)
#
# Train Epoch: 20 [0/112800 (0%)]	Loss: 3.006317
# Train Epoch: 20 [25600/112800 (23%)]	Loss: 3.061132
# Train Epoch: 20 [51200/112800 (45%)]	Loss: 3.080648
# Train Epoch: 20 [76800/112800 (68%)]	Loss: 3.096946
# Train Epoch: 20 [102400/112800 (91%)]	Loss: 3.055341
# training accuracy : 83.70%
#
# Test set for client-0: Average loss: 0.0482, Accuracy: 15159/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0482, Accuracy: 15161/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0482, Accuracy: 15166/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0482, Accuracy: 15161/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0482, Accuracy: 15161/18800 (81%)
#
# Train Epoch: 21 [0/112800 (0%)]	Loss: 3.029943
# Train Epoch: 21 [25600/112800 (23%)]	Loss: 2.986532
# Train Epoch: 21 [51200/112800 (45%)]	Loss: 3.025796
# Train Epoch: 21 [76800/112800 (68%)]	Loss: 3.016215
# Train Epoch: 21 [102400/112800 (91%)]	Loss: 3.002690
# training accuracy : 83.59%
#
# Test set for client-0: Average loss: 0.0483, Accuracy: 15026/18800 (80%)
#
#
# Test set for client-1: Average loss: 0.0483, Accuracy: 15027/18800 (80%)
#
#
# Test set for client-2: Average loss: 0.0483, Accuracy: 15027/18800 (80%)
#
#
# Test set for client-3: Average loss: 0.0483, Accuracy: 15018/18800 (80%)
#
#
# Test set for client-4: Average loss: 0.0483, Accuracy: 15018/18800 (80%)
#
# Train Epoch: 22 [0/112800 (0%)]	Loss: 3.018561
# Train Epoch: 22 [25600/112800 (23%)]	Loss: 3.074060
# Train Epoch: 22 [51200/112800 (45%)]	Loss: 3.112817
# Train Epoch: 22 [76800/112800 (68%)]	Loss: 3.094360
# Train Epoch: 22 [102400/112800 (91%)]	Loss: 3.118181
# training accuracy : 83.59%
#
# Test set for client-0: Average loss: 0.0482, Accuracy: 15154/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0482, Accuracy: 15149/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0482, Accuracy: 15150/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0482, Accuracy: 15140/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0482, Accuracy: 15150/18800 (81%)
#
# Train Epoch: 23 [0/112800 (0%)]	Loss: 3.034320
# Train Epoch: 23 [25600/112800 (23%)]	Loss: 3.025580
# Train Epoch: 23 [51200/112800 (45%)]	Loss: 3.080801
# Train Epoch: 23 [76800/112800 (68%)]	Loss: 3.106723
# Train Epoch: 23 [102400/112800 (91%)]	Loss: 2.996705
# training accuracy : 83.66%
#
# Test set for client-0: Average loss: 0.0484, Accuracy: 14947/18800 (80%)
#
#
# Test set for client-1: Average loss: 0.0484, Accuracy: 14945/18800 (79%)
#
#
# Test set for client-2: Average loss: 0.0484, Accuracy: 14957/18800 (80%)
#
#
# Test set for client-3: Average loss: 0.0484, Accuracy: 14947/18800 (80%)
#
#
# Test set for client-4: Average loss: 0.0484, Accuracy: 14958/18800 (80%)
#
# Train Epoch: 24 [0/112800 (0%)]	Loss: 3.061468
# Train Epoch: 24 [25600/112800 (23%)]	Loss: 3.015252
# Train Epoch: 24 [51200/112800 (45%)]	Loss: 3.036218
# Train Epoch: 24 [76800/112800 (68%)]	Loss: 3.106992
# Train Epoch: 24 [102400/112800 (91%)]	Loss: 3.123863
# training accuracy : 83.63%
#
# Test set for client-0: Average loss: 0.0480, Accuracy: 15358/18800 (82%)
#
#
# Test set for client-1: Average loss: 0.0480, Accuracy: 15358/18800 (82%)
#
#
# Test set for client-2: Average loss: 0.0480, Accuracy: 15351/18800 (82%)
#
#
# Test set for client-3: Average loss: 0.0480, Accuracy: 15355/18800 (82%)
#
#
# Test set for client-4: Average loss: 0.0480, Accuracy: 15356/18800 (82%)
#
# Train Epoch: 25 [0/112800 (0%)]	Loss: 3.091952
# Train Epoch: 25 [25600/112800 (23%)]	Loss: 3.068748
# Train Epoch: 25 [51200/112800 (45%)]	Loss: 3.050698
# Train Epoch: 25 [76800/112800 (68%)]	Loss: 3.086021
# Train Epoch: 25 [102400/112800 (91%)]	Loss: 3.022983
# training accuracy : 83.57%
#
# Test set for client-0: Average loss: 0.0481, Accuracy: 15291/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0481, Accuracy: 15294/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0481, Accuracy: 15287/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0481, Accuracy: 15287/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0481, Accuracy: 15283/18800 (81%)
#
# Train Epoch: 26 [0/112800 (0%)]	Loss: 3.040734
# Train Epoch: 26 [25600/112800 (23%)]	Loss: 3.100744
# Train Epoch: 26 [51200/112800 (45%)]	Loss: 3.073533
# Train Epoch: 26 [76800/112800 (68%)]	Loss: 3.086599
# Train Epoch: 26 [102400/112800 (91%)]	Loss: 2.984403
# training accuracy : 83.89%
#
# Test set for client-0: Average loss: 0.0481, Accuracy: 15253/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0481, Accuracy: 15253/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0481, Accuracy: 15253/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0481, Accuracy: 15255/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0481, Accuracy: 15253/18800 (81%)
#
# Train Epoch: 27 [0/112800 (0%)]	Loss: 3.108038
# Train Epoch: 27 [25600/112800 (23%)]	Loss: 3.100186
# Train Epoch: 27 [51200/112800 (45%)]	Loss: 3.143156
# Train Epoch: 27 [76800/112800 (68%)]	Loss: 2.997847
# Train Epoch: 27 [102400/112800 (91%)]	Loss: 3.033911
# training accuracy : 83.83%
#
# Test set for client-0: Average loss: 0.0481, Accuracy: 15313/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0481, Accuracy: 15309/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0481, Accuracy: 15315/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0481, Accuracy: 15316/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0481, Accuracy: 15316/18800 (81%)
#
# Train Epoch: 28 [0/112800 (0%)]	Loss: 3.054363
# Train Epoch: 28 [25600/112800 (23%)]	Loss: 3.013094
# Train Epoch: 28 [51200/112800 (45%)]	Loss: 3.106188
# Train Epoch: 28 [76800/112800 (68%)]	Loss: 3.075717
# Train Epoch: 28 [102400/112800 (91%)]	Loss: 3.015644
# training accuracy : 83.66%
#
# Test set for client-0: Average loss: 0.0481, Accuracy: 15265/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0481, Accuracy: 15264/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0481, Accuracy: 15264/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0481, Accuracy: 15265/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0481, Accuracy: 15269/18800 (81%)
#
# Train Epoch: 29 [0/112800 (0%)]	Loss: 2.999673
# Train Epoch: 29 [25600/112800 (23%)]	Loss: 3.037388
# Train Epoch: 29 [51200/112800 (45%)]	Loss: 3.138494
# Train Epoch: 29 [76800/112800 (68%)]	Loss: 2.999949
# Train Epoch: 29 [102400/112800 (91%)]	Loss: 3.076765
# training accuracy : 83.71%
#
# Test set for client-0: Average loss: 0.0483, Accuracy: 15034/18800 (80%)
#
#
# Test set for client-1: Average loss: 0.0483, Accuracy: 15040/18800 (80%)
#
#
# Test set for client-2: Average loss: 0.0483, Accuracy: 15039/18800 (80%)
#
#
# Test set for client-3: Average loss: 0.0483, Accuracy: 15035/18800 (80%)
#
#
# Test set for client-4: Average loss: 0.0483, Accuracy: 15035/18800 (80%)
#
# Train Epoch: 30 [0/112800 (0%)]	Loss: 3.081685
# Train Epoch: 30 [25600/112800 (23%)]	Loss: 3.030813
# Train Epoch: 30 [51200/112800 (45%)]	Loss: 3.031515
# Train Epoch: 30 [76800/112800 (68%)]	Loss: 3.080400
# Train Epoch: 30 [102400/112800 (91%)]	Loss: 3.042153
# training accuracy : 83.67%
#
# Test set for client-0: Average loss: 0.0481, Accuracy: 15247/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0481, Accuracy: 15245/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0481, Accuracy: 15240/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0481, Accuracy: 15248/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0481, Accuracy: 15246/18800 (81%)
#
# Train Epoch: 31 [0/112800 (0%)]	Loss: 2.995851
# Train Epoch: 31 [25600/112800 (23%)]	Loss: 3.044768
# Train Epoch: 31 [51200/112800 (45%)]	Loss: 3.009950
# Train Epoch: 31 [76800/112800 (68%)]	Loss: 2.993727
# Train Epoch: 31 [102400/112800 (91%)]	Loss: 3.100306
# training accuracy : 83.88%
#
# Test set for client-0: Average loss: 0.0480, Accuracy: 15354/18800 (82%)
#
#
# Test set for client-1: Average loss: 0.0480, Accuracy: 15354/18800 (82%)
#
#
# Test set for client-2: Average loss: 0.0480, Accuracy: 15350/18800 (82%)
#
#
# Test set for client-3: Average loss: 0.0480, Accuracy: 15348/18800 (82%)
#
#
# Test set for client-4: Average loss: 0.0480, Accuracy: 15350/18800 (82%)
#
# Train Epoch: 32 [0/112800 (0%)]	Loss: 3.031426
# Train Epoch: 32 [25600/112800 (23%)]	Loss: 3.063651
# Train Epoch: 32 [51200/112800 (45%)]	Loss: 3.108274
# Train Epoch: 32 [76800/112800 (68%)]	Loss: 3.071469
# Train Epoch: 32 [102400/112800 (91%)]	Loss: 3.083020
# training accuracy : 83.80%
#
# Test set for client-0: Average loss: 0.0480, Accuracy: 15361/18800 (82%)
#
#
# Test set for client-1: Average loss: 0.0480, Accuracy: 15358/18800 (82%)
#
#
# Test set for client-2: Average loss: 0.0480, Accuracy: 15365/18800 (82%)
#
#
# Test set for client-3: Average loss: 0.0480, Accuracy: 15363/18800 (82%)
#
#
# Test set for client-4: Average loss: 0.0480, Accuracy: 15364/18800 (82%)
#
# Train Epoch: 33 [0/112800 (0%)]	Loss: 3.000077
# Train Epoch: 33 [25600/112800 (23%)]	Loss: 3.070266
# Train Epoch: 33 [51200/112800 (45%)]	Loss: 3.068776
# Train Epoch: 33 [76800/112800 (68%)]	Loss: 3.092389
# Train Epoch: 33 [102400/112800 (91%)]	Loss: 3.046415
# training accuracy : 83.86%
#
# Test set for client-0: Average loss: 0.0483, Accuracy: 15058/18800 (80%)
#
#
# Test set for client-1: Average loss: 0.0483, Accuracy: 15063/18800 (80%)
#
#
# Test set for client-2: Average loss: 0.0483, Accuracy: 15049/18800 (80%)
#
#
# Test set for client-3: Average loss: 0.0483, Accuracy: 15053/18800 (80%)
#
#
# Test set for client-4: Average loss: 0.0483, Accuracy: 15063/18800 (80%)
#
# Train Epoch: 34 [0/112800 (0%)]	Loss: 3.102557
# Train Epoch: 34 [25600/112800 (23%)]	Loss: 3.003793
# Train Epoch: 34 [51200/112800 (45%)]	Loss: 3.105117
# Train Epoch: 34 [76800/112800 (68%)]	Loss: 2.954993
# Train Epoch: 34 [102400/112800 (91%)]	Loss: 3.079664
# training accuracy : 83.80%
#
# Test set for client-0: Average loss: 0.0482, Accuracy: 15207/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0482, Accuracy: 15209/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0482, Accuracy: 15207/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0482, Accuracy: 15207/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0482, Accuracy: 15207/18800 (81%)
#
# Train Epoch: 35 [0/112800 (0%)]	Loss: 3.110087
# Train Epoch: 35 [25600/112800 (23%)]	Loss: 3.086822
# Train Epoch: 35 [51200/112800 (45%)]	Loss: 3.052899
# Train Epoch: 35 [76800/112800 (68%)]	Loss: 3.092700
# Train Epoch: 35 [102400/112800 (91%)]	Loss: 3.132645
# training accuracy : 83.79%
#
# Test set for client-0: Average loss: 0.0482, Accuracy: 15240/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0482, Accuracy: 15235/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0482, Accuracy: 15241/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0482, Accuracy: 15231/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0482, Accuracy: 15234/18800 (81%)
#
# Train Epoch: 36 [0/112800 (0%)]	Loss: 3.014817
# Train Epoch: 36 [25600/112800 (23%)]	Loss: 3.055589
# Train Epoch: 36 [51200/112800 (45%)]	Loss: 2.976068
# Train Epoch: 36 [76800/112800 (68%)]	Loss: 3.023575
# Train Epoch: 36 [102400/112800 (91%)]	Loss: 3.047295
# training accuracy : 83.92%
#
# Test set for client-0: Average loss: 0.0483, Accuracy: 15079/18800 (80%)
#
#
# Test set for client-1: Average loss: 0.0483, Accuracy: 15083/18800 (80%)
#
#
# Test set for client-2: Average loss: 0.0483, Accuracy: 15075/18800 (80%)
#
#
# Test set for client-3: Average loss: 0.0483, Accuracy: 15073/18800 (80%)
#
#
# Test set for client-4: Average loss: 0.0483, Accuracy: 15073/18800 (80%)
#
# Train Epoch: 37 [0/112800 (0%)]	Loss: 3.075987
# Train Epoch: 37 [25600/112800 (23%)]	Loss: 3.061110
# Train Epoch: 37 [51200/112800 (45%)]	Loss: 3.073152
# Train Epoch: 37 [76800/112800 (68%)]	Loss: 3.108166
# Train Epoch: 37 [102400/112800 (91%)]	Loss: 3.025307
# training accuracy : 84.06%
#
# Test set for client-0: Average loss: 0.0487, Accuracy: 14585/18800 (78%)
#
#
# Test set for client-1: Average loss: 0.0487, Accuracy: 14584/18800 (78%)
#
#
# Test set for client-2: Average loss: 0.0487, Accuracy: 14579/18800 (78%)
#
#
# Test set for client-3: Average loss: 0.0487, Accuracy: 14582/18800 (78%)
#
#
# Test set for client-4: Average loss: 0.0487, Accuracy: 14579/18800 (78%)
#
# Train Epoch: 38 [0/112800 (0%)]	Loss: 3.110995
# Train Epoch: 38 [25600/112800 (23%)]	Loss: 3.058336
# Train Epoch: 38 [51200/112800 (45%)]	Loss: 3.027498
# Train Epoch: 38 [76800/112800 (68%)]	Loss: 3.019389
# Train Epoch: 38 [102400/112800 (91%)]	Loss: 3.068563
# training accuracy : 84.07%
#
# Test set for client-0: Average loss: 0.0481, Accuracy: 15295/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0481, Accuracy: 15301/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0481, Accuracy: 15308/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0481, Accuracy: 15295/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0481, Accuracy: 15304/18800 (81%)
#
# Train Epoch: 39 [0/112800 (0%)]	Loss: 3.013851
# Train Epoch: 39 [25600/112800 (23%)]	Loss: 3.007821
# Train Epoch: 39 [51200/112800 (45%)]	Loss: 3.013217
# Train Epoch: 39 [76800/112800 (68%)]	Loss: 3.121779
# Train Epoch: 39 [102400/112800 (91%)]	Loss: 2.982651
# training accuracy : 84.02%
#
# Test set for client-0: Average loss: 0.0480, Accuracy: 15339/18800 (82%)
#
#
# Test set for client-1: Average loss: 0.0480, Accuracy: 15330/18800 (82%)
#
#
# Test set for client-2: Average loss: 0.0480, Accuracy: 15332/18800 (82%)
#
#
# Test set for client-3: Average loss: 0.0480, Accuracy: 15335/18800 (82%)
#
#
# Test set for client-4: Average loss: 0.0480, Accuracy: 15337/18800 (82%)
#
# Train Epoch: 40 [0/112800 (0%)]	Loss: 3.079731
# Train Epoch: 40 [25600/112800 (23%)]	Loss: 3.047166
# Train Epoch: 40 [51200/112800 (45%)]	Loss: 3.027758
# Train Epoch: 40 [76800/112800 (68%)]	Loss: 2.996921
# Train Epoch: 40 [102400/112800 (91%)]	Loss: 3.041299
# training accuracy : 84.02%
#
# Test set for client-0: Average loss: 0.0481, Accuracy: 15283/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0481, Accuracy: 15282/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0481, Accuracy: 15286/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0481, Accuracy: 15286/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0481, Accuracy: 15281/18800 (81%)
#
# Train Epoch: 41 [0/112800 (0%)]	Loss: 3.140807
# Train Epoch: 41 [25600/112800 (23%)]	Loss: 3.091710
# Train Epoch: 41 [51200/112800 (45%)]	Loss: 3.097419
# Train Epoch: 41 [76800/112800 (68%)]	Loss: 3.049299
# Train Epoch: 41 [102400/112800 (91%)]	Loss: 3.000531
# training accuracy : 84.24%
#
# Test set for client-0: Average loss: 0.0481, Accuracy: 15308/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0481, Accuracy: 15316/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0481, Accuracy: 15315/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0481, Accuracy: 15315/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0481, Accuracy: 15316/18800 (81%)
#
# Train Epoch: 42 [0/112800 (0%)]	Loss: 3.041459
# Train Epoch: 42 [25600/112800 (23%)]	Loss: 3.067547
# Train Epoch: 42 [51200/112800 (45%)]	Loss: 3.000763
# Train Epoch: 42 [76800/112800 (68%)]	Loss: 3.065889
# Train Epoch: 42 [102400/112800 (91%)]	Loss: 3.121425
# training accuracy : 84.15%
#
# Test set for client-0: Average loss: 0.0483, Accuracy: 15026/18800 (80%)
#
#
# Test set for client-1: Average loss: 0.0483, Accuracy: 15024/18800 (80%)
#
#
# Test set for client-2: Average loss: 0.0483, Accuracy: 15014/18800 (80%)
#
#
# Test set for client-3: Average loss: 0.0483, Accuracy: 15032/18800 (80%)
#
#
# Test set for client-4: Average loss: 0.0483, Accuracy: 15028/18800 (80%)
#
# Train Epoch: 43 [0/112800 (0%)]	Loss: 3.042060
# Train Epoch: 43 [25600/112800 (23%)]	Loss: 3.130780
# Train Epoch: 43 [51200/112800 (45%)]	Loss: 3.076841
# Train Epoch: 43 [76800/112800 (68%)]	Loss: 3.082817
# Train Epoch: 43 [102400/112800 (91%)]	Loss: 2.985067
# training accuracy : 83.92%
#
# Test set for client-0: Average loss: 0.0482, Accuracy: 15153/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0482, Accuracy: 15146/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0482, Accuracy: 15148/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0482, Accuracy: 15149/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0482, Accuracy: 15154/18800 (81%)
#
# Train Epoch: 44 [0/112800 (0%)]	Loss: 3.050121
# Train Epoch: 44 [25600/112800 (23%)]	Loss: 3.002120
# Train Epoch: 44 [51200/112800 (45%)]	Loss: 3.016724
# Train Epoch: 44 [76800/112800 (68%)]	Loss: 2.991029
# Train Epoch: 44 [102400/112800 (91%)]	Loss: 3.018175
# training accuracy : 84.11%
#
# Test set for client-0: Average loss: 0.0482, Accuracy: 15106/18800 (80%)
#
#
# Test set for client-1: Average loss: 0.0482, Accuracy: 15097/18800 (80%)
#
#
# Test set for client-2: Average loss: 0.0482, Accuracy: 15097/18800 (80%)
#
#
# Test set for client-3: Average loss: 0.0482, Accuracy: 15100/18800 (80%)
#
#
# Test set for client-4: Average loss: 0.0482, Accuracy: 15103/18800 (80%)
#
# Train Epoch: 45 [0/112800 (0%)]	Loss: 3.006510
# Train Epoch: 45 [25600/112800 (23%)]	Loss: 3.074357
# Train Epoch: 45 [51200/112800 (45%)]	Loss: 3.059320
# Train Epoch: 45 [76800/112800 (68%)]	Loss: 3.082057
# Train Epoch: 45 [102400/112800 (91%)]	Loss: 3.043769
# training accuracy : 83.97%
#
# Test set for client-0: Average loss: 0.0496, Accuracy: 13526/18800 (72%)
#
#
# Test set for client-1: Average loss: 0.0496, Accuracy: 13527/18800 (72%)
#
#
# Test set for client-2: Average loss: 0.0496, Accuracy: 13527/18800 (72%)
#
#
# Test set for client-3: Average loss: 0.0496, Accuracy: 13540/18800 (72%)
#
#
# Test set for client-4: Average loss: 0.0496, Accuracy: 13539/18800 (72%)
#
# Train Epoch: 46 [0/112800 (0%)]	Loss: 3.018364
# Train Epoch: 46 [25600/112800 (23%)]	Loss: 3.002104
# Train Epoch: 46 [51200/112800 (45%)]	Loss: 3.018023
# Train Epoch: 46 [76800/112800 (68%)]	Loss: 3.035859
# Train Epoch: 46 [102400/112800 (91%)]	Loss: 3.000928
# training accuracy : 84.12%
#
# Test set for client-0: Average loss: 0.0481, Accuracy: 15294/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0481, Accuracy: 15296/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0481, Accuracy: 15301/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0481, Accuracy: 15293/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0481, Accuracy: 15293/18800 (81%)
#
# Train Epoch: 47 [0/112800 (0%)]	Loss: 3.025222
# Train Epoch: 47 [25600/112800 (23%)]	Loss: 3.066971
# Train Epoch: 47 [51200/112800 (45%)]	Loss: 3.103219
# Train Epoch: 47 [76800/112800 (68%)]	Loss: 3.029873
# Train Epoch: 47 [102400/112800 (91%)]	Loss: 3.085561
# training accuracy : 84.19%
#
# Test set for client-0: Average loss: 0.0480, Accuracy: 15436/18800 (82%)
#
#
# Test set for client-1: Average loss: 0.0480, Accuracy: 15437/18800 (82%)
#
#
# Test set for client-2: Average loss: 0.0480, Accuracy: 15438/18800 (82%)
#
#
# Test set for client-3: Average loss: 0.0480, Accuracy: 15437/18800 (82%)
#
#
# Test set for client-4: Average loss: 0.0479, Accuracy: 15435/18800 (82%)
#
# Train Epoch: 48 [0/112800 (0%)]	Loss: 3.106910
# Train Epoch: 48 [25600/112800 (23%)]	Loss: 3.046955
# Train Epoch: 48 [51200/112800 (45%)]	Loss: 3.117179
# Train Epoch: 48 [76800/112800 (68%)]	Loss: 3.079079
# Train Epoch: 48 [102400/112800 (91%)]	Loss: 2.952993
# training accuracy : 84.62%
#
# Test set for client-0: Average loss: 0.0478, Accuracy: 15684/18800 (83%)
#
#
# Test set for client-1: Average loss: 0.0478, Accuracy: 15679/18800 (83%)
#
#
# Test set for client-2: Average loss: 0.0478, Accuracy: 15683/18800 (83%)
#
#
# Test set for client-3: Average loss: 0.0478, Accuracy: 15682/18800 (83%)
#
#
# Test set for client-4: Average loss: 0.0478, Accuracy: 15681/18800 (83%)
#
# Train Epoch: 49 [0/112800 (0%)]	Loss: 3.016811
# Train Epoch: 49 [25600/112800 (23%)]	Loss: 3.091480
# Train Epoch: 49 [51200/112800 (45%)]	Loss: 3.032974
# Train Epoch: 49 [76800/112800 (68%)]	Loss: 3.003962
# Train Epoch: 49 [102400/112800 (91%)]	Loss: 3.066353
# training accuracy : 85.38%
#
# Test set for client-0: Average loss: 0.0480, Accuracy: 15344/18800 (82%)
#
#
# Test set for client-1: Average loss: 0.0480, Accuracy: 15345/18800 (82%)
#
#
# Test set for client-2: Average loss: 0.0480, Accuracy: 15346/18800 (82%)
#
#
# Test set for client-3: Average loss: 0.0480, Accuracy: 15344/18800 (82%)
#
#
# Test set for client-4: Average loss: 0.0480, Accuracy: 15346/18800 (82%)
#
# Train Epoch: 50 [0/112800 (0%)]	Loss: 3.067553
# Train Epoch: 50 [25600/112800 (23%)]	Loss: 3.044492
# Train Epoch: 50 [51200/112800 (45%)]	Loss: 2.999949
# Train Epoch: 50 [76800/112800 (68%)]	Loss: 3.062759
# Train Epoch: 50 [102400/112800 (91%)]	Loss: 3.005803
# training accuracy : 87.50%
#
# Test set for client-0: Average loss: 0.0476, Accuracy: 15910/18800 (85%)
#
#
# Test set for client-1: Average loss: 0.0476, Accuracy: 15910/18800 (85%)
#
#
# Test set for client-2: Average loss: 0.0476, Accuracy: 15908/18800 (85%)
#
#
# Test set for client-3: Average loss: 0.0476, Accuracy: 15906/18800 (85%)
#
#
# Test set for client-4: Average loss: 0.0476, Accuracy: 15907/18800 (85%)
#
# Train Epoch: 51 [0/112800 (0%)]	Loss: 3.029107
# Train Epoch: 51 [25600/112800 (23%)]	Loss: 2.997986
# Train Epoch: 51 [51200/112800 (45%)]	Loss: 3.029234
# Train Epoch: 51 [76800/112800 (68%)]	Loss: 3.056838
# Train Epoch: 51 [102400/112800 (91%)]	Loss: 3.070790
# training accuracy : 87.89%
#
# Test set for client-0: Average loss: 0.0476, Accuracy: 15841/18800 (84%)
#
#
# Test set for client-1: Average loss: 0.0476, Accuracy: 15836/18800 (84%)
#
#
# Test set for client-2: Average loss: 0.0476, Accuracy: 15838/18800 (84%)
#
#
# Test set for client-3: Average loss: 0.0476, Accuracy: 15836/18800 (84%)
#
#
# Test set for client-4: Average loss: 0.0476, Accuracy: 15838/18800 (84%)
#
# Train Epoch: 52 [0/112800 (0%)]	Loss: 3.006232
# Train Epoch: 52 [25600/112800 (23%)]	Loss: 3.035609
# Train Epoch: 52 [51200/112800 (45%)]	Loss: 3.015764
# Train Epoch: 52 [76800/112800 (68%)]	Loss: 2.947460
# Train Epoch: 52 [102400/112800 (91%)]	Loss: 3.043141
# training accuracy : 87.95%
#
# Test set for client-0: Average loss: 0.0476, Accuracy: 15828/18800 (84%)
#
#
# Test set for client-1: Average loss: 0.0476, Accuracy: 15827/18800 (84%)
#
#
# Test set for client-2: Average loss: 0.0476, Accuracy: 15827/18800 (84%)
#
#
# Test set for client-3: Average loss: 0.0477, Accuracy: 15826/18800 (84%)
#
#
# Test set for client-4: Average loss: 0.0476, Accuracy: 15828/18800 (84%)
#
# Train Epoch: 53 [0/112800 (0%)]	Loss: 3.020043
# Train Epoch: 53 [25600/112800 (23%)]	Loss: 3.006265
# Train Epoch: 53 [51200/112800 (45%)]	Loss: 3.011410
# Train Epoch: 53 [76800/112800 (68%)]	Loss: 3.030695
# Train Epoch: 53 [102400/112800 (91%)]	Loss: 2.983543
# training accuracy : 88.10%
#
# Test set for client-0: Average loss: 0.0477, Accuracy: 15746/18800 (84%)
#
#
# Test set for client-1: Average loss: 0.0477, Accuracy: 15744/18800 (84%)
#
#
# Test set for client-2: Average loss: 0.0477, Accuracy: 15750/18800 (84%)
#
#
# Test set for client-3: Average loss: 0.0477, Accuracy: 15745/18800 (84%)
#
#
# Test set for client-4: Average loss: 0.0477, Accuracy: 15744/18800 (84%)
#
# Train Epoch: 54 [0/112800 (0%)]	Loss: 2.999918
# Train Epoch: 54 [25600/112800 (23%)]	Loss: 3.024971
# Train Epoch: 54 [51200/112800 (45%)]	Loss: 2.979652
# Train Epoch: 54 [76800/112800 (68%)]	Loss: 2.999402
# Train Epoch: 54 [102400/112800 (91%)]	Loss: 3.030879
# training accuracy : 87.93%
#
# Test set for client-0: Average loss: 0.0476, Accuracy: 15860/18800 (84%)
#
#
# Test set for client-1: Average loss: 0.0476, Accuracy: 15865/18800 (84%)
#
#
# Test set for client-2: Average loss: 0.0476, Accuracy: 15856/18800 (84%)
#
#
# Test set for client-3: Average loss: 0.0476, Accuracy: 15856/18800 (84%)
#
#
# Test set for client-4: Average loss: 0.0476, Accuracy: 15857/18800 (84%)
#
# Train Epoch: 55 [0/112800 (0%)]	Loss: 3.046621
# Train Epoch: 55 [25600/112800 (23%)]	Loss: 3.031432
# Train Epoch: 55 [51200/112800 (45%)]	Loss: 3.045314
# Train Epoch: 55 [76800/112800 (68%)]	Loss: 2.965996
# Train Epoch: 55 [102400/112800 (91%)]	Loss: 2.965741
# training accuracy : 88.01%
#
# Test set for client-0: Average loss: 0.0476, Accuracy: 15906/18800 (85%)
#
#
# Test set for client-1: Average loss: 0.0476, Accuracy: 15902/18800 (85%)
#
#
# Test set for client-2: Average loss: 0.0476, Accuracy: 15903/18800 (85%)
#
#
# Test set for client-3: Average loss: 0.0476, Accuracy: 15900/18800 (85%)
#
#
# Test set for client-4: Average loss: 0.0476, Accuracy: 15903/18800 (85%)
#
# Train Epoch: 56 [0/112800 (0%)]	Loss: 2.993141
# Train Epoch: 56 [25600/112800 (23%)]	Loss: 2.990978
# Train Epoch: 56 [51200/112800 (45%)]	Loss: 2.981710
# Train Epoch: 56 [76800/112800 (68%)]	Loss: 3.013399
# Train Epoch: 56 [102400/112800 (91%)]	Loss: 3.022930
# training accuracy : 88.09%
#
# Test set for client-0: Average loss: 0.0478, Accuracy: 15678/18800 (83%)
#
#
# Test set for client-1: Average loss: 0.0478, Accuracy: 15676/18800 (83%)
#
#
# Test set for client-2: Average loss: 0.0478, Accuracy: 15680/18800 (83%)
#
#
# Test set for client-3: Average loss: 0.0478, Accuracy: 15673/18800 (83%)
#
#
# Test set for client-4: Average loss: 0.0478, Accuracy: 15679/18800 (83%)
#
# Train Epoch: 57 [0/112800 (0%)]	Loss: 2.983902
# Train Epoch: 57 [25600/112800 (23%)]	Loss: 2.981379
# Train Epoch: 57 [51200/112800 (45%)]	Loss: 3.047091
# Train Epoch: 57 [76800/112800 (68%)]	Loss: 3.000531
# Train Epoch: 57 [102400/112800 (91%)]	Loss: 2.973469
# training accuracy : 88.06%
#
# Test set for client-0: Average loss: 0.0477, Accuracy: 15743/18800 (84%)
#
#
# Test set for client-1: Average loss: 0.0477, Accuracy: 15745/18800 (84%)
#
#
# Test set for client-2: Average loss: 0.0477, Accuracy: 15746/18800 (84%)
#
#
# Test set for client-3: Average loss: 0.0477, Accuracy: 15748/18800 (84%)
#
#
# Test set for client-4: Average loss: 0.0477, Accuracy: 15745/18800 (84%)
#
# Train Epoch: 58 [0/112800 (0%)]	Loss: 2.952734
# Train Epoch: 58 [25600/112800 (23%)]	Loss: 2.970632
# Train Epoch: 58 [51200/112800 (45%)]	Loss: 3.022915
# Train Epoch: 58 [76800/112800 (68%)]	Loss: 3.030128
# Train Epoch: 58 [102400/112800 (91%)]	Loss: 3.034358
# training accuracy : 88.02%
#
# Test set for client-0: Average loss: 0.0477, Accuracy: 15771/18800 (84%)
#
#
# Test set for client-1: Average loss: 0.0477, Accuracy: 15766/18800 (84%)
#
#
# Test set for client-2: Average loss: 0.0477, Accuracy: 15760/18800 (84%)
#
#
# Test set for client-3: Average loss: 0.0477, Accuracy: 15764/18800 (84%)
#
#
# Test set for client-4: Average loss: 0.0477, Accuracy: 15768/18800 (84%)
#
# Train Epoch: 59 [0/112800 (0%)]	Loss: 2.982382
# Train Epoch: 59 [25600/112800 (23%)]	Loss: 3.014553
# Train Epoch: 59 [51200/112800 (45%)]	Loss: 3.017204
# Train Epoch: 59 [76800/112800 (68%)]	Loss: 2.981581
# Train Epoch: 59 [102400/112800 (91%)]	Loss: 3.076105
# training accuracy : 88.03%
#
# Test set for client-0: Average loss: 0.0477, Accuracy: 15775/18800 (84%)
#
#
# Test set for client-1: Average loss: 0.0477, Accuracy: 15776/18800 (84%)
#
#
# Test set for client-2: Average loss: 0.0477, Accuracy: 15777/18800 (84%)
#
#
# Test set for client-3: Average loss: 0.0477, Accuracy: 15776/18800 (84%)
#
#
# Test set for client-4: Average loss: 0.0477, Accuracy: 15773/18800 (84%)
#
# Train Epoch: 60 [0/112800 (0%)]	Loss: 2.998933
# Train Epoch: 60 [25600/112800 (23%)]	Loss: 2.955280
# Train Epoch: 60 [51200/112800 (45%)]	Loss: 3.021757
# Train Epoch: 60 [76800/112800 (68%)]	Loss: 3.005085
# Train Epoch: 60 [102400/112800 (91%)]	Loss: 3.058736
# training accuracy : 88.03%
#
# Test set for client-0: Average loss: 0.0476, Accuracy: 15870/18800 (84%)
#
#
# Test set for client-1: Average loss: 0.0476, Accuracy: 15871/18800 (84%)
#
#
# Test set for client-2: Average loss: 0.0476, Accuracy: 15863/18800 (84%)
#
#
# Test set for client-3: Average loss: 0.0476, Accuracy: 15871/18800 (84%)
#
#
# Test set for client-4: Average loss: 0.0476, Accuracy: 15870/18800 (84%)
#
# Train Epoch: 61 [0/112800 (0%)]	Loss: 2.982957
# Train Epoch: 61 [25600/112800 (23%)]	Loss: 3.028281
# Train Epoch: 61 [51200/112800 (45%)]	Loss: 2.968302
# Train Epoch: 61 [76800/112800 (68%)]	Loss: 2.984097
# Train Epoch: 61 [102400/112800 (91%)]	Loss: 2.946176
# training accuracy : 87.87%
#
# Test set for client-0: Average loss: 0.0482, Accuracy: 15178/18800 (81%)
#
#
# Test set for client-1: Average loss: 0.0482, Accuracy: 15174/18800 (81%)
#
#
# Test set for client-2: Average loss: 0.0482, Accuracy: 15168/18800 (81%)
#
#
# Test set for client-3: Average loss: 0.0482, Accuracy: 15176/18800 (81%)
#
#
# Test set for client-4: Average loss: 0.0482, Accuracy: 15179/18800 (81%)
#
# Train Epoch: 62 [0/112800 (0%)]	Loss: 3.073414
# Train Epoch: 62 [25600/112800 (23%)]	Loss: 3.010545
# Train Epoch: 62 [51200/112800 (45%)]	Loss: 2.935040
# Train Epoch: 62 [76800/112800 (68%)]	Loss: 2.994618
# Train Epoch: 62 [102400/112800 (91%)]	Loss: 3.053838
# training accuracy : 87.97%
#
# Test set for client-0: Average loss: 0.0480, Accuracy: 15430/18800 (82%)
#
#
# Test set for client-1: Average loss: 0.0480, Accuracy: 15421/18800 (82%)
#
#
# Test set for client-2: Average loss: 0.0480, Accuracy: 15416/18800 (82%)
#
#
# Test set for client-3: Average loss: 0.0480, Accuracy: 15430/18800 (82%)
#
#
# Test set for client-4: Average loss: 0.0480, Accuracy: 15425/18800 (82%)
#
# Train Epoch: 63 [0/112800 (0%)]	Loss: 2.975559
# Train Epoch: 63 [25600/112800 (23%)]	Loss: 3.025455
# Train Epoch: 63 [51200/112800 (45%)]	Loss: 3.062769
# Train Epoch: 63 [76800/112800 (68%)]	Loss: 2.951086
# Train Epoch: 63 [102400/112800 (91%)]	Loss: 3.016480
# training accuracy : 88.00%
#
# Test set for client-0: Average loss: 0.0477, Accuracy: 15745/18800 (84%)
#
#
# Test set for client-1: Average loss: 0.0477, Accuracy: 15747/18800 (84%)
#
#
# Test set for client-2: Average loss: 0.0477, Accuracy: 15744/18800 (84%)
#
#
# Test set for client-3: Average loss: 0.0477, Accuracy: 15740/18800 (84%)
#
#
# Test set for client-4: Average loss: 0.0477, Accuracy: 15746/18800 (84%)
#
# Train Epoch: 64 [0/112800 (0%)]	Loss: 3.008147
# Train Epoch: 64 [25600/112800 (23%)]	Loss: 3.012914
# Train Epoch: 64 [51200/112800 (45%)]	Loss: 2.951856
# Train Epoch: 64 [76800/112800 (68%)]	Loss: 3.056600
# Train Epoch: 64 [102400/112800 (91%)]	Loss: 3.049531
# training accuracy : 87.91%
#
# Test set for client-0: Average loss: 0.0478, Accuracy: 15622/18800 (83%)
#
#
# Test set for client-1: Average loss: 0.0478, Accuracy: 15619/18800 (83%)
#
#
# Test set for client-2: Average loss: 0.0478, Accuracy: 15616/18800 (83%)
#
#
# Test set for client-3: Average loss: 0.0478, Accuracy: 15624/18800 (83%)
#
#
# Test set for client-4: Average loss: 0.0478, Accuracy: 15623/18800 (83%)
#
# Train Epoch: 65 [0/112800 (0%)]	Loss: 2.948048
# Train Epoch: 65 [25600/112800 (23%)]	Loss: 3.005986
# Train Epoch: 65 [51200/112800 (45%)]	Loss: 3.031333
# Train Epoch: 65 [76800/112800 (68%)]	Loss: 2.997104
# Train Epoch: 65 [102400/112800 (91%)]	Loss: 3.060730
# training accuracy : 88.06%
#
# Test set for client-0: Average loss: 0.0479, Accuracy: 15547/18800 (83%)
#
#
# Test set for client-1: Average loss: 0.0479, Accuracy: 15547/18800 (83%)
#
#
# Test set for client-2: Average loss: 0.0479, Accuracy: 15547/18800 (83%)
#
#
# Test set for client-3: Average loss: 0.0479, Accuracy: 15542/18800 (83%)
#
#
# Test set for client-4: Average loss: 0.0479, Accuracy: 15544/18800 (83%)
#
# Train Epoch: 66 [0/112800 (0%)]	Loss: 2.980913
# Train Epoch: 66 [25600/112800 (23%)]	Loss: 3.032805
# Train Epoch: 66 [51200/112800 (45%)]	Loss: 3.003875
# Train Epoch: 66 [76800/112800 (68%)]	Loss: 3.020027
# Train Epoch: 66 [102400/112800 (91%)]	Loss: 2.951985
# training accuracy : 88.05%
#
# Test set for client-0: Average loss: 0.0490, Accuracy: 14201/18800 (76%)
#
#
# Test set for client-1: Average loss: 0.0490, Accuracy: 14210/18800 (76%)
#
#
# Test set for client-2: Average loss: 0.0490, Accuracy: 14251/18800 (76%)
#
#
# Test set for client-3: Average loss: 0.0490, Accuracy: 14225/18800 (76%)
#
#
# Test set for client-4: Average loss: 0.0490, Accuracy: 14219/18800 (76%)
#
# Train Epoch: 67 [0/112800 (0%)]	Loss: 3.059561
# Train Epoch: 67 [25600/112800 (23%)]	Loss: 3.020165

# %%
from torchvision import datasets,transforms
import torch

import random
import torch.nn.functional as f
import torch.nn as nn
import torch.optim as optim

def get_emnist_dataset():
    train_dataset = datasets.EMNIST('./data',split='balanced', train=True, download=True,
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1751,), (0.3267,))
                       ]))

    test_dataset = datasets.EMNIST('./data', split='balanced',train=False, transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1751,), (0.3267,))
                       ]))

    train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=64, shuffle=True)
    test_loader = torch.utils.data.DataLoader(test_dataset,batch_size=64, shuffle=False)

    return train_loader,test_loader

def train_single_model(client,client_opt,device,train_loader,epoch):
    client.train()
    criterion = nn.CrossEntropyLoss()
    correct = 0
    for batch_idx, (data, target) in enumerate(train_loader):        
        data, target = data.to(device), target.to(device)
        client_opt.zero_grad()
        output = client(data)
        loss = criterion(output,target)
        loss.backward()
        client_opt.step()

        pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()
        ### printing logs
        if batch_idx % 500 == 0:
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
        
    print("training accuracy : {:.2f}%".format(100.0*correct/len(train_loader.dataset)))

def test_single_model(client,device,test_loader):
    client.eval()
    criterion = nn.CrossEntropyLoss()
    with torch.no_grad():
        test_loss = 0
        correct = 0
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = client(data)
            test_loss += criterion(output, target).item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
        
        test_loss /= len(test_loader.dataset)
        print('\nTest set for client: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, correct, len(test_loader.dataset),
            100. * correct / len(test_loader.dataset)))

def adjust_learning_rate(optimizer, init_lr, epoch):
    lr = init_lr * (0.5 ** (epoch // 25))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

if __name__ == "__main__":
    random.seed(7)
    torch.manual_seed(7)
    if torch.cuda.is_available():  
        dev = "cuda:0" 
    else:  
        dev = "cpu"
    device = torch.device(dev)

    train_loader,test_loader = get_emnist_dataset()
    
    client = VGG(vgg_name='VGG16',in_channels=1,dense_output=47).to(device)
    client_optim = optim.SGD(client.parameters(),lr=1e-3,weight_decay=5e-4)
    init_lr = 0.1

    for i in range(1,100):
        adjust_learning_rate(client_optim,init_lr,i)
        train_single_model(client,client_optim,device,train_loader,i)
        test_single_model(client,device,test_loader)
    
    torch.save(client.state_dict(),"single-model.pt")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Train Epoch: 1 [0/112800 (0%)]	Loss: 3.850313
# Train Epoch: 1 [32000/112800 (28%)]	Loss: 3.774830
# Train Epoch: 1 [64000/112800 (57%)]	Loss: 3.717552
# Train Epoch: 1 [96000/112800 (85%)]	Loss: 3.781635
# training accuracy : 10.49%
#
# Test set for client: Average loss: 0.0579, Accuracy: 3096/18800 (16%)
#
# Train Epoch: 2 [0/112800 (0%)]	Loss: 3.694689
# Train Epoch: 2 [32000/112800 (28%)]	Loss: 3.621490
# Train Epoch: 2 [64000/112800 (57%)]	Loss: 3.690891
# Train Epoch: 2 [96000/112800 (85%)]	Loss: 3.584619
# training accuracy : 22.02%
#
# Test set for client: Average loss: 0.0558, Accuracy: 5758/18800 (31%)
#
# Train Epoch: 3 [0/112800 (0%)]	Loss: 3.554548
# Train Epoch: 3 [32000/112800 (28%)]	Loss: 3.480539
# Train Epoch: 3 [64000/112800 (57%)]	Loss: 3.482689
# Train Epoch: 3 [96000/112800 (85%)]	Loss: 3.486669
# training accuracy : 37.23%
#
# Test set for client: Average loss: 0.0539, Accuracy: 8201/18800 (44%)
#
# Train Epoch: 4 [0/112800 (0%)]	Loss: 3.498254
# Train Epoch: 4 [32000/112800 (28%)]	Loss: 3.319617
# Train Epoch: 4 [64000/112800 (57%)]	Loss: 3.298617
# Train Epoch: 4 [96000/112800 (85%)]	Loss: 3.340815
# training accuracy : 49.17%
#
# Test set for client: Average loss: 0.0524, Accuracy: 9958/18800 (53%)
#
# Train Epoch: 5 [0/112800 (0%)]	Loss: 3.340873
# Train Epoch: 5 [32000/112800 (28%)]	Loss: 3.371501
# Train Epoch: 5 [64000/112800 (57%)]	Loss: 3.297484
# Train Epoch: 5 [96000/112800 (85%)]	Loss: 3.317565
# training accuracy : 58.81%
#
# Test set for client: Average loss: 0.0508, Accuracy: 11972/18800 (64%)
#
# Train Epoch: 6 [0/112800 (0%)]	Loss: 3.312201
# Train Epoch: 6 [32000/112800 (28%)]	Loss: 3.155736
# Train Epoch: 6 [64000/112800 (57%)]	Loss: 3.143449
# Train Epoch: 6 [96000/112800 (85%)]	Loss: 3.067134
# training accuracy : 74.98%
#
# Test set for client: Average loss: 0.0484, Accuracy: 14948/18800 (80%)
#
# Train Epoch: 7 [0/112800 (0%)]	Loss: 3.071131
# Train Epoch: 7 [32000/112800 (28%)]	Loss: 3.123184
# Train Epoch: 7 [64000/112800 (57%)]	Loss: 3.059130
# Train Epoch: 7 [96000/112800 (85%)]	Loss: 3.136687
# training accuracy : 80.47%
#
# Test set for client: Average loss: 0.0484, Accuracy: 14904/18800 (79%)
#
# Train Epoch: 8 [0/112800 (0%)]	Loss: 3.138895
# Train Epoch: 8 [32000/112800 (28%)]	Loss: 3.027994
# Train Epoch: 8 [64000/112800 (57%)]	Loss: 3.138465
# Train Epoch: 8 [96000/112800 (85%)]	Loss: 3.078242
# training accuracy : 80.85%
#
# Test set for client: Average loss: 0.0481, Accuracy: 15260/18800 (81%)
#
# Train Epoch: 9 [0/112800 (0%)]	Loss: 3.093297
# Train Epoch: 9 [32000/112800 (28%)]	Loss: 3.107105
# Train Epoch: 9 [64000/112800 (57%)]	Loss: 3.011201
# Train Epoch: 9 [96000/112800 (85%)]	Loss: 3.045421
# training accuracy : 81.38%
#
# Test set for client: Average loss: 0.0480, Accuracy: 15333/18800 (82%)
#
# Train Epoch: 10 [0/112800 (0%)]	Loss: 3.072789
# Train Epoch: 10 [32000/112800 (28%)]	Loss: 2.998173
# Train Epoch: 10 [64000/112800 (57%)]	Loss: 3.000097
# Train Epoch: 10 [96000/112800 (85%)]	Loss: 3.034070
# training accuracy : 82.95%
#
# Test set for client: Average loss: 0.0481, Accuracy: 15248/18800 (81%)
#
# Train Epoch: 11 [0/112800 (0%)]	Loss: 3.098723
# Train Epoch: 11 [32000/112800 (28%)]	Loss: 3.099365
# Train Epoch: 11 [64000/112800 (57%)]	Loss: 3.012680
# Train Epoch: 11 [96000/112800 (85%)]	Loss: 3.067168
# training accuracy : 83.31%
#
# Test set for client: Average loss: 0.0480, Accuracy: 15418/18800 (82%)
#
# Train Epoch: 12 [0/112800 (0%)]	Loss: 2.983360
# Train Epoch: 12 [32000/112800 (28%)]	Loss: 3.054771
# Train Epoch: 12 [64000/112800 (57%)]	Loss: 3.094227
# Train Epoch: 12 [96000/112800 (85%)]	Loss: 3.076607
# training accuracy : 83.67%
#
# Test set for client: Average loss: 0.0477, Accuracy: 15726/18800 (84%)
#
# Train Epoch: 13 [0/112800 (0%)]	Loss: 3.108122
# Train Epoch: 13 [32000/112800 (28%)]	Loss: 3.044270
# Train Epoch: 13 [64000/112800 (57%)]	Loss: 3.059180
# Train Epoch: 13 [96000/112800 (85%)]	Loss: 3.033750
# training accuracy : 83.56%
#
# Test set for client: Average loss: 0.0479, Accuracy: 15537/18800 (83%)
#
# Train Epoch: 14 [0/112800 (0%)]	Loss: 3.090278
# Train Epoch: 14 [32000/112800 (28%)]	Loss: 3.023236
# Train Epoch: 14 [64000/112800 (57%)]	Loss: 3.059898
# Train Epoch: 14 [96000/112800 (85%)]	Loss: 3.029547
# training accuracy : 83.84%
#
# Test set for client: Average loss: 0.0478, Accuracy: 15628/18800 (83%)
#
# Train Epoch: 15 [0/112800 (0%)]	Loss: 3.152268
# Train Epoch: 15 [32000/112800 (28%)]	Loss: 3.030158
# Train Epoch: 15 [64000/112800 (57%)]	Loss: 3.118400
# Train Epoch: 15 [96000/112800 (85%)]	Loss: 3.112444
# training accuracy : 83.90%
#
# Test set for client: Average loss: 0.0478, Accuracy: 15588/18800 (83%)
#
# Train Epoch: 16 [0/112800 (0%)]	Loss: 3.014138
# Train Epoch: 16 [32000/112800 (28%)]	Loss: 3.073202
# Train Epoch: 16 [64000/112800 (57%)]	Loss: 2.982213
# Train Epoch: 16 [96000/112800 (85%)]	Loss: 3.075391
# training accuracy : 83.59%
#
# Test set for client: Average loss: 0.0477, Accuracy: 15692/18800 (83%)
#
# Train Epoch: 17 [0/112800 (0%)]	Loss: 3.004365
# Train Epoch: 17 [32000/112800 (28%)]	Loss: 3.110301
# Train Epoch: 17 [64000/112800 (57%)]	Loss: 2.971686
# Train Epoch: 17 [96000/112800 (85%)]	Loss: 3.027648
# training accuracy : 83.69%
#
# Test set for client: Average loss: 0.0477, Accuracy: 15751/18800 (84%)
#
# Train Epoch: 18 [0/112800 (0%)]	Loss: 2.994696
# Train Epoch: 18 [32000/112800 (28%)]	Loss: 3.045239
# Train Epoch: 18 [64000/112800 (57%)]	Loss: 3.028277
# Train Epoch: 18 [96000/112800 (85%)]	Loss: 3.089606
# training accuracy : 83.94%
#
# Test set for client: Average loss: 0.0478, Accuracy: 15657/18800 (83%)
#
# Train Epoch: 19 [0/112800 (0%)]	Loss: 3.072166
# Train Epoch: 19 [32000/112800 (28%)]	Loss: 3.061427
# Train Epoch: 19 [64000/112800 (57%)]	Loss: 3.002016
# Train Epoch: 19 [96000/112800 (85%)]	Loss: 3.013111
# training accuracy : 83.83%
#
# Test set for client: Average loss: 0.0477, Accuracy: 15772/18800 (84%)
#
# Train Epoch: 20 [0/112800 (0%)]	Loss: 3.043097
# Train Epoch: 20 [32000/112800 (28%)]	Loss: 3.032228
# Train Epoch: 20 [64000/112800 (57%)]	Loss: 3.029085
# Train Epoch: 20 [96000/112800 (85%)]	Loss: 3.127008
# training accuracy : 83.88%
#
# Test set for client: Average loss: 0.0478, Accuracy: 15610/18800 (83%)
#
# Train Epoch: 21 [0/112800 (0%)]	Loss: 3.091078
# Train Epoch: 21 [32000/112800 (28%)]	Loss: 3.069725
# Train Epoch: 21 [64000/112800 (57%)]	Loss: 3.030067
# Train Epoch: 21 [96000/112800 (85%)]	Loss: 3.108527
# training accuracy : 83.97%
#
# Test set for client: Average loss: 0.0478, Accuracy: 15629/18800 (83%)
#
# Train Epoch: 22 [0/112800 (0%)]	Loss: 2.997566
# Train Epoch: 22 [32000/112800 (28%)]	Loss: 3.054572
# Train Epoch: 22 [64000/112800 (57%)]	Loss: 3.076045
# Train Epoch: 22 [96000/112800 (85%)]	Loss: 3.076482
# training accuracy : 84.02%
#
# Test set for client: Average loss: 0.0478, Accuracy: 15617/18800 (83%)
#
# Train Epoch: 23 [0/112800 (0%)]	Loss: 3.049270
# Train Epoch: 23 [32000/112800 (28%)]	Loss: 3.017800
# Train Epoch: 23 [64000/112800 (57%)]	Loss: 3.074749
# Train Epoch: 23 [96000/112800 (85%)]	Loss: 3.016141
# training accuracy : 83.91%
#
# Test set for client: Average loss: 0.0479, Accuracy: 15470/18800 (82%)
#
# Train Epoch: 24 [0/112800 (0%)]	Loss: 3.007998
# Train Epoch: 24 [32000/112800 (28%)]	Loss: 3.017462
# Train Epoch: 24 [64000/112800 (57%)]	Loss: 2.950813
# Train Epoch: 24 [96000/112800 (85%)]	Loss: 3.015139
# training accuracy : 83.95%
#
# Test set for client: Average loss: 0.0478, Accuracy: 15628/18800 (83%)
#
# Train Epoch: 25 [0/112800 (0%)]	Loss: 3.055350
# Train Epoch: 25 [32000/112800 (28%)]	Loss: 3.057751
# Train Epoch: 25 [64000/112800 (57%)]	Loss: 3.035076
# Train Epoch: 25 [96000/112800 (85%)]	Loss: 3.031297
# training accuracy : 84.88%
#
# Test set for client: Average loss: 0.0476, Accuracy: 15793/18800 (84%)
#
# Train Epoch: 26 [0/112800 (0%)]	Loss: 3.075998
# Train Epoch: 26 [32000/112800 (28%)]	Loss: 2.978887
# Train Epoch: 26 [64000/112800 (57%)]	Loss: 3.074766
# Train Epoch: 26 [96000/112800 (85%)]	Loss: 3.050296
# training accuracy : 85.18%
#
# Test set for client: Average loss: 0.0477, Accuracy: 15786/18800 (84%)
#
# Train Epoch: 27 [0/112800 (0%)]	Loss: 3.059569
# Train Epoch: 27 [32000/112800 (28%)]	Loss: 3.065469
# Train Epoch: 27 [64000/112800 (57%)]	Loss: 3.125108
# Train Epoch: 27 [96000/112800 (85%)]	Loss: 3.028988
# training accuracy : 85.17%
#
# Test set for client: Average loss: 0.0478, Accuracy: 15568/18800 (83%)
#
# Train Epoch: 28 [0/112800 (0%)]	Loss: 3.045735
# Train Epoch: 28 [32000/112800 (28%)]	Loss: 2.996722
# Train Epoch: 28 [64000/112800 (57%)]	Loss: 3.029480
# Train Epoch: 28 [96000/112800 (85%)]	Loss: 3.056553
# training accuracy : 85.22%
#
# Test set for client: Average loss: 0.0476, Accuracy: 15841/18800 (84%)
#
# Train Epoch: 29 [0/112800 (0%)]	Loss: 3.028638
# Train Epoch: 29 [32000/112800 (28%)]	Loss: 3.089794
# Train Epoch: 29 [64000/112800 (57%)]	Loss: 2.993997
# Train Epoch: 29 [96000/112800 (85%)]	Loss: 3.058698
# training accuracy : 85.19%
#
# Test set for client: Average loss: 0.0477, Accuracy: 15785/18800 (84%)
#
# Train Epoch: 30 [0/112800 (0%)]	Loss: 2.975035
# Train Epoch: 30 [32000/112800 (28%)]	Loss: 3.044091
# Train Epoch: 30 [64000/112800 (57%)]	Loss: 3.027835
# Train Epoch: 30 [96000/112800 (85%)]	Loss: 2.944999
# training accuracy : 85.26%
#
# Test set for client: Average loss: 0.0476, Accuracy: 15863/18800 (84%)
#
# Train Epoch: 31 [0/112800 (0%)]	Loss: 3.088419
# Train Epoch: 31 [32000/112800 (28%)]	Loss: 2.998415
# Train Epoch: 31 [64000/112800 (57%)]	Loss: 2.998445
# Train Epoch: 31 [96000/112800 (85%)]	Loss: 3.069777
# training accuracy : 85.12%
#
# Test set for client: Average loss: 0.0477, Accuracy: 15746/18800 (84%)
#
# Train Epoch: 32 [0/112800 (0%)]	Loss: 3.029245
# Train Epoch: 32 [32000/112800 (28%)]	Loss: 3.105798
# Train Epoch: 32 [64000/112800 (57%)]	Loss: 3.066836
# Train Epoch: 32 [96000/112800 (85%)]	Loss: 3.137321
# training accuracy : 84.99%
#
# Test set for client: Average loss: 0.0476, Accuracy: 15842/18800 (84%)
#
# Train Epoch: 33 [0/112800 (0%)]	Loss: 3.044297
# Train Epoch: 33 [32000/112800 (28%)]	Loss: 3.121612
# Train Epoch: 33 [64000/112800 (57%)]	Loss: 3.051627
# Train Epoch: 33 [96000/112800 (85%)]	Loss: 3.017651
# training accuracy : 85.03%
#
# Test set for client: Average loss: 0.0477, Accuracy: 15750/18800 (84%)
#
# Train Epoch: 34 [0/112800 (0%)]	Loss: 3.059583
