# %%
from torchvision import datasets,transforms
import torch
import random
import torch.nn.functional as f
import torch.nn as nn
import torch.optim as optim
from torchsummary import summary

# %%
def get_mnist_dataset(batch_size=32):
    train_dataset = datasets.MNIST('../data', train=True, download=True,
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))
                       ]))

    test_dataset = datasets.MNIST('../data', train=False, transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))
                       ]))

    train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=batch_size, shuffle=True)
    test_loader = torch.utils.data.DataLoader(test_dataset,batch_size=batch_size, shuffle=False)
    return train_loader,test_loader

# %%
def train_single_model(model,optimiser,device,train_loader,epoch):
    model.train()
    criterion = nn.CrossEntropyLoss()
    correct = 0
    for batch_idx, (data, target) in enumerate(train_loader):        
        data, target = data.to(device), target.to(device)
        optimiser.zero_grad()
        output = model(data)
        loss = criterion(output,target)
        loss.backward()
        optimiser.step()

        pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()
        ### printing logs
        if batch_idx % 300 == 0:
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
    
    print('\nTrain set for client: Accuracy: {}/{} ({:.0f}%)\n'.format(
        correct, len(train_loader.dataset),
        100. * correct / len(train_loader.dataset)))

# %%
def test_single_model(model,device,test_loader):
    model.eval()
    criterion = nn.CrossEntropyLoss()
    with torch.no_grad():
        test_loss = 0
        correct = 0
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += criterion(output, target).item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
        
        test_loss /= len(test_loader.dataset)
        history = print('\nTest set for client: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, correct, len(test_loader.dataset),
            100. * correct / len(test_loader.dataset)))

# %%
import torch.nn as nn

class Flatten(nn.Module):
    def forward(self, x):
        batch_size = x.shape[0]
        return x.view(batch_size, -1)

lenet = lambda input_channels,output_channels : nn.Sequential(
            nn.Conv2d(input_channels, 6, 5),
            nn.ReLU(),
            nn.MaxPool2d((2,2)),
            nn.Conv2d(6, 16, 5),
            nn.ReLU(),
            nn.MaxPool2d((2,2)),
            Flatten(),
            nn.Linear(256,120),
            nn.ReLU(),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Linear(84, output_channels),
            nn.Softmax())

lenet_client = lambda input_channels : nn.Sequential(
            nn.Conv2d(input_channels, 6, 5),
            nn.ReLU(),
            nn.MaxPool2d((2,2)),
            nn.Conv2d(6, 16, 5),
            nn.ReLU(),
            nn.MaxPool2d((2,2)),
            Flatten())

lenet_server = lambda input_channels,output_channels : nn.Sequential(
            nn.Linear(input_channels,120),
            nn.ReLU(),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Linear(84, output_channels),
            nn.Softmax())

# %%
if __name__ == "__main__":
    random.seed(7)
    torch.manual_seed(7)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    if torch.cuda.is_available():  
        dev = "cuda:0" 
    else:  
        dev = "cpu"
    device = torch.device(dev)

    train_loader,test_loader = get_mnist_dataset(batch_size=64)

    model = lenet(input_channels=1,output_channels=10).to(device)
    client_optim = optim.SGD(model.parameters(),lr=1e-2,weight_decay=5e-3)

    for i in range(1,50):
        train_single_model(model,client_optim,device,train_loader,i)
        test_single_model(model,device,test_loader)
    
    torch.save(model.state_dict(),"single-model.pt")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302203
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 2.302436
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 2.302009
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 2.301419
#
# Train set for client: Accuracy: 7508/60000 (13%)
#
#
# Test set for client: Average loss: 0.0361, Accuracy: 1609/10000 (16%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 2.301574
# Train Epoch: 2 [19200/60000 (32%)]	Loss: 2.300418
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 2.300820
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 2.300778
#
# Train set for client: Accuracy: 12553/60000 (21%)
#
#
# Test set for client: Average loss: 0.0361, Accuracy: 2174/10000 (22%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 2.299872
# Train Epoch: 3 [19200/60000 (32%)]	Loss: 2.300125
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 2.298145
# Train Epoch: 3 [57600/60000 (96%)]	Loss: 2.298918
#
# Train set for client: Accuracy: 13038/60000 (22%)
#
#
# Test set for client: Average loss: 0.0361, Accuracy: 2307/10000 (23%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 2.297184
# Train Epoch: 4 [19200/60000 (32%)]	Loss: 2.295661
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 2.290864
# Train Epoch: 4 [57600/60000 (96%)]	Loss: 2.283117
#
# Train set for client: Accuracy: 18450/60000 (31%)
#
#
# Test set for client: Average loss: 0.0359, Accuracy: 3288/10000 (33%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 2.282181
# Train Epoch: 5 [19200/60000 (32%)]	Loss: 2.247844
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 2.109218
# Train Epoch: 5 [57600/60000 (96%)]	Loss: 1.922883
#
# Train set for client: Accuracy: 20024/60000 (33%)
#
#
# Test set for client: Average loss: 0.0307, Accuracy: 5981/10000 (60%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 1.976474
# Train Epoch: 6 [19200/60000 (32%)]	Loss: 1.747884
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 1.666372
# Train Epoch: 6 [57600/60000 (96%)]	Loss: 1.697398
#
# Train set for client: Accuracy: 42789/60000 (71%)
#
#
# Test set for client: Average loss: 0.0266, Accuracy: 7842/10000 (78%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 1.828488
# Train Epoch: 7 [19200/60000 (32%)]	Loss: 1.678325
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 1.676799
# Train Epoch: 7 [57600/60000 (96%)]	Loss: 1.668120
#
# Train set for client: Accuracy: 47203/60000 (79%)
#
#
# Test set for client: Average loss: 0.0262, Accuracy: 8034/10000 (80%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 1.585606
# Train Epoch: 8 [19200/60000 (32%)]	Loss: 1.701377
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 1.741521
# Train Epoch: 8 [57600/60000 (96%)]	Loss: 1.686547
#
# Train set for client: Accuracy: 48461/60000 (81%)
#
#
# Test set for client: Average loss: 0.0260, Accuracy: 8222/10000 (82%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 1.817022
# Train Epoch: 9 [19200/60000 (32%)]	Loss: 1.662044
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 1.688940
# Train Epoch: 9 [57600/60000 (96%)]	Loss: 1.649739
#
# Train set for client: Accuracy: 49382/60000 (82%)
#
#
# Test set for client: Average loss: 0.0257, Accuracy: 8317/10000 (83%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 1.669208
# Train Epoch: 10 [19200/60000 (32%)]	Loss: 1.575876
# Train Epoch: 10 [38400/60000 (64%)]	Loss: 1.562480
# Train Epoch: 10 [57600/60000 (96%)]	Loss: 1.568170
#
# Train set for client: Accuracy: 54229/60000 (90%)
#
#
# Test set for client: Average loss: 0.0243, Accuracy: 9269/10000 (93%)
#
# Train Epoch: 11 [0/60000 (0%)]	Loss: 1.605170
# Train Epoch: 11 [19200/60000 (32%)]	Loss: 1.533155
# Train Epoch: 11 [38400/60000 (64%)]	Loss: 1.529843
# Train Epoch: 11 [57600/60000 (96%)]	Loss: 1.492056
#
# Train set for client: Accuracy: 55868/60000 (93%)
#
#
# Test set for client: Average loss: 0.0241, Accuracy: 9387/10000 (94%)
#
# Train Epoch: 12 [0/60000 (0%)]	Loss: 1.539201
# Train Epoch: 12 [19200/60000 (32%)]	Loss: 1.553916
# Train Epoch: 12 [38400/60000 (64%)]	Loss: 1.535571
# Train Epoch: 12 [57600/60000 (96%)]	Loss: 1.583147
#
# Train set for client: Accuracy: 56429/60000 (94%)
#
#
# Test set for client: Average loss: 0.0239, Accuracy: 9484/10000 (95%)
#
# Train Epoch: 13 [0/60000 (0%)]	Loss: 1.518495
# Train Epoch: 13 [19200/60000 (32%)]	Loss: 1.525984
# Train Epoch: 13 [38400/60000 (64%)]	Loss: 1.537930
# Train Epoch: 13 [57600/60000 (96%)]	Loss: 1.480993
#
# Train set for client: Accuracy: 56826/60000 (95%)
#
#
# Test set for client: Average loss: 0.0238, Accuracy: 9537/10000 (95%)
#
# Train Epoch: 14 [0/60000 (0%)]	Loss: 1.491227
# Train Epoch: 14 [19200/60000 (32%)]	Loss: 1.527168
# Train Epoch: 14 [38400/60000 (64%)]	Loss: 1.515737
# Train Epoch: 14 [57600/60000 (96%)]	Loss: 1.503436
#
# Train set for client: Accuracy: 57126/60000 (95%)
#
#
# Test set for client: Average loss: 0.0238, Accuracy: 9549/10000 (95%)
#
# Train Epoch: 15 [0/60000 (0%)]	Loss: 1.508595
# Train Epoch: 15 [19200/60000 (32%)]	Loss: 1.512557
# Train Epoch: 15 [38400/60000 (64%)]	Loss: 1.521310
# Train Epoch: 15 [57600/60000 (96%)]	Loss: 1.503664
#
# Train set for client: Accuracy: 57348/60000 (96%)
#
#
# Test set for client: Average loss: 0.0237, Accuracy: 9628/10000 (96%)
#
# Train Epoch: 16 [0/60000 (0%)]	Loss: 1.548694
# Train Epoch: 16 [19200/60000 (32%)]	Loss: 1.543663
# Train Epoch: 16 [38400/60000 (64%)]	Loss: 1.505043
# Train Epoch: 16 [57600/60000 (96%)]	Loss: 1.494397
#
# Train set for client: Accuracy: 57525/60000 (96%)
#
#
# Test set for client: Average loss: 0.0237, Accuracy: 9629/10000 (96%)
#
# Train Epoch: 17 [0/60000 (0%)]	Loss: 1.503276
# Train Epoch: 17 [19200/60000 (32%)]	Loss: 1.506577
# Train Epoch: 17 [38400/60000 (64%)]	Loss: 1.490590
# Train Epoch: 17 [57600/60000 (96%)]	Loss: 1.484511
#
# Train set for client: Accuracy: 57614/60000 (96%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9638/10000 (96%)
#
# Train Epoch: 18 [0/60000 (0%)]	Loss: 1.513792
# Train Epoch: 18 [19200/60000 (32%)]	Loss: 1.548092
# Train Epoch: 18 [38400/60000 (64%)]	Loss: 1.522534
# Train Epoch: 18 [57600/60000 (96%)]	Loss: 1.486612
#
# Train set for client: Accuracy: 57734/60000 (96%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9659/10000 (97%)
#
# Train Epoch: 19 [0/60000 (0%)]	Loss: 1.485002
# Train Epoch: 19 [19200/60000 (32%)]	Loss: 1.531666
# Train Epoch: 19 [38400/60000 (64%)]	Loss: 1.480678
# Train Epoch: 19 [57600/60000 (96%)]	Loss: 1.510772
#
# Train set for client: Accuracy: 57858/60000 (96%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9641/10000 (96%)
#
# Train Epoch: 20 [0/60000 (0%)]	Loss: 1.498028
# Train Epoch: 20 [19200/60000 (32%)]	Loss: 1.515593
# Train Epoch: 20 [38400/60000 (64%)]	Loss: 1.497618
# Train Epoch: 20 [57600/60000 (96%)]	Loss: 1.497485
#
# Train set for client: Accuracy: 57951/60000 (97%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9694/10000 (97%)
#
# Train Epoch: 21 [0/60000 (0%)]	Loss: 1.514310
# Train Epoch: 21 [19200/60000 (32%)]	Loss: 1.522972
# Train Epoch: 21 [38400/60000 (64%)]	Loss: 1.530704
# Train Epoch: 21 [57600/60000 (96%)]	Loss: 1.516005
#
# Train set for client: Accuracy: 57979/60000 (97%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9694/10000 (97%)
#
# Train Epoch: 22 [0/60000 (0%)]	Loss: 1.488588
# Train Epoch: 22 [19200/60000 (32%)]	Loss: 1.509637
# Train Epoch: 22 [38400/60000 (64%)]	Loss: 1.497092
# Train Epoch: 22 [57600/60000 (96%)]	Loss: 1.467544
#
# Train set for client: Accuracy: 58051/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9719/10000 (97%)
#
# Train Epoch: 23 [0/60000 (0%)]	Loss: 1.471378
# Train Epoch: 23 [19200/60000 (32%)]	Loss: 1.511941
# Train Epoch: 23 [38400/60000 (64%)]	Loss: 1.506852
# Train Epoch: 23 [57600/60000 (96%)]	Loss: 1.502833
#
# Train set for client: Accuracy: 58113/60000 (97%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9693/10000 (97%)
#
# Train Epoch: 24 [0/60000 (0%)]	Loss: 1.486562
# Train Epoch: 24 [19200/60000 (32%)]	Loss: 1.515949
# Train Epoch: 24 [38400/60000 (64%)]	Loss: 1.507466
# Train Epoch: 24 [57600/60000 (96%)]	Loss: 1.494301
#
# Train set for client: Accuracy: 58135/60000 (97%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9663/10000 (97%)
#
# Train Epoch: 25 [0/60000 (0%)]	Loss: 1.480834
# Train Epoch: 25 [19200/60000 (32%)]	Loss: 1.510251
# Train Epoch: 25 [38400/60000 (64%)]	Loss: 1.479410
# Train Epoch: 25 [57600/60000 (96%)]	Loss: 1.508884
#
# Train set for client: Accuracy: 58193/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9722/10000 (97%)
#
# Train Epoch: 26 [0/60000 (0%)]	Loss: 1.507680
# Train Epoch: 26 [19200/60000 (32%)]	Loss: 1.498844
# Train Epoch: 26 [38400/60000 (64%)]	Loss: 1.516910
# Train Epoch: 26 [57600/60000 (96%)]	Loss: 1.499576
#
# Train set for client: Accuracy: 58241/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9735/10000 (97%)
#
# Train Epoch: 27 [0/60000 (0%)]	Loss: 1.513873
# Train Epoch: 27 [19200/60000 (32%)]	Loss: 1.471802
# Train Epoch: 27 [38400/60000 (64%)]	Loss: 1.484998
# Train Epoch: 27 [57600/60000 (96%)]	Loss: 1.507851
#
# Train set for client: Accuracy: 58258/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9731/10000 (97%)
#
# Train Epoch: 28 [0/60000 (0%)]	Loss: 1.514124
# Train Epoch: 28 [19200/60000 (32%)]	Loss: 1.472183
# Train Epoch: 28 [38400/60000 (64%)]	Loss: 1.491853
# Train Epoch: 28 [57600/60000 (96%)]	Loss: 1.525600
#
# Train set for client: Accuracy: 58288/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9739/10000 (97%)
#
# Train Epoch: 29 [0/60000 (0%)]	Loss: 1.484574
# Train Epoch: 29 [19200/60000 (32%)]	Loss: 1.503543
# Train Epoch: 29 [38400/60000 (64%)]	Loss: 1.465185
# Train Epoch: 29 [57600/60000 (96%)]	Loss: 1.554707
#
# Train set for client: Accuracy: 58327/60000 (97%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9700/10000 (97%)
#
# Train Epoch: 30 [0/60000 (0%)]	Loss: 1.481049
# Train Epoch: 30 [19200/60000 (32%)]	Loss: 1.528806
# Train Epoch: 30 [38400/60000 (64%)]	Loss: 1.486547
# Train Epoch: 30 [57600/60000 (96%)]	Loss: 1.478980
#
# Train set for client: Accuracy: 58343/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9744/10000 (97%)
#
# Train Epoch: 31 [0/60000 (0%)]	Loss: 1.492681
# Train Epoch: 31 [19200/60000 (32%)]	Loss: 1.514127
# Train Epoch: 31 [38400/60000 (64%)]	Loss: 1.481032
# Train Epoch: 31 [57600/60000 (96%)]	Loss: 1.494007
#
# Train set for client: Accuracy: 58363/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9712/10000 (97%)
#
# Train Epoch: 32 [0/60000 (0%)]	Loss: 1.515138
# Train Epoch: 32 [19200/60000 (32%)]	Loss: 1.489215
# Train Epoch: 32 [38400/60000 (64%)]	Loss: 1.496852
# Train Epoch: 32 [57600/60000 (96%)]	Loss: 1.467901
#
# Train set for client: Accuracy: 58345/60000 (97%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9719/10000 (97%)
#
# Train Epoch: 33 [0/60000 (0%)]	Loss: 1.542921
# Train Epoch: 33 [19200/60000 (32%)]	Loss: 1.512429
# Train Epoch: 33 [38400/60000 (64%)]	Loss: 1.482927
# Train Epoch: 33 [57600/60000 (96%)]	Loss: 1.510358
#
# Train set for client: Accuracy: 58377/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9742/10000 (97%)
#
# Train Epoch: 34 [0/60000 (0%)]	Loss: 1.480281
# Train Epoch: 34 [19200/60000 (32%)]	Loss: 1.492889
# Train Epoch: 34 [38400/60000 (64%)]	Loss: 1.526459
# Train Epoch: 34 [57600/60000 (96%)]	Loss: 1.506547
#
# Train set for client: Accuracy: 58415/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9758/10000 (98%)
#
# Train Epoch: 35 [0/60000 (0%)]	Loss: 1.493880
# Train Epoch: 35 [19200/60000 (32%)]	Loss: 1.517795
# Train Epoch: 35 [38400/60000 (64%)]	Loss: 1.487756
# Train Epoch: 35 [57600/60000 (96%)]	Loss: 1.486139
#
# Train set for client: Accuracy: 58428/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9769/10000 (98%)
#
# Train Epoch: 36 [0/60000 (0%)]	Loss: 1.484223
# Train Epoch: 36 [19200/60000 (32%)]	Loss: 1.494003
# Train Epoch: 36 [38400/60000 (64%)]	Loss: 1.492684
# Train Epoch: 36 [57600/60000 (96%)]	Loss: 1.468513
#
# Train set for client: Accuracy: 58451/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9762/10000 (98%)
#
# Train Epoch: 37 [0/60000 (0%)]	Loss: 1.480960
# Train Epoch: 37 [19200/60000 (32%)]	Loss: 1.473443
# Train Epoch: 37 [38400/60000 (64%)]	Loss: 1.477073
# Train Epoch: 37 [57600/60000 (96%)]	Loss: 1.480204
#
# Train set for client: Accuracy: 58463/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9749/10000 (97%)
#
# Train Epoch: 38 [0/60000 (0%)]	Loss: 1.483583
# Train Epoch: 38 [19200/60000 (32%)]	Loss: 1.502380
# Train Epoch: 38 [38400/60000 (64%)]	Loss: 1.492971
# Train Epoch: 38 [57600/60000 (96%)]	Loss: 1.510432
#
# Train set for client: Accuracy: 58458/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9762/10000 (98%)
#
# Train Epoch: 39 [0/60000 (0%)]	Loss: 1.516217
# Train Epoch: 39 [19200/60000 (32%)]	Loss: 1.479888
# Train Epoch: 39 [38400/60000 (64%)]	Loss: 1.521355
# Train Epoch: 39 [57600/60000 (96%)]	Loss: 1.515298
#
# Train set for client: Accuracy: 58459/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9759/10000 (98%)
#
# Train Epoch: 40 [0/60000 (0%)]	Loss: 1.482556
# Train Epoch: 40 [19200/60000 (32%)]	Loss: 1.502422
# Train Epoch: 40 [38400/60000 (64%)]	Loss: 1.503959
# Train Epoch: 40 [57600/60000 (96%)]	Loss: 1.481942
#
# Train set for client: Accuracy: 58488/60000 (97%)
#
#
# Test set for client: Average loss: 0.0234, Accuracy: 9770/10000 (98%)
#
# Train Epoch: 41 [0/60000 (0%)]	Loss: 1.490169
# Train Epoch: 41 [19200/60000 (32%)]	Loss: 1.527801
# Train Epoch: 41 [38400/60000 (64%)]	Loss: 1.518198
# Train Epoch: 41 [57600/60000 (96%)]	Loss: 1.500725
#
# Train set for client: Accuracy: 58475/60000 (97%)
#
#
# Test set for client: Average loss: 0.0234, Accuracy: 9780/10000 (98%)
#
# Train Epoch: 42 [0/60000 (0%)]	Loss: 1.487216
# Train Epoch: 42 [19200/60000 (32%)]	Loss: 1.494577
# Train Epoch: 42 [38400/60000 (64%)]	Loss: 1.506656
# Train Epoch: 42 [57600/60000 (96%)]	Loss: 1.493231
#
# Train set for client: Accuracy: 58505/60000 (98%)
#
#
# Test set for client: Average loss: 0.0234, Accuracy: 9770/10000 (98%)
#
# Train Epoch: 43 [0/60000 (0%)]	Loss: 1.478577
# Train Epoch: 43 [19200/60000 (32%)]	Loss: 1.493946
# Train Epoch: 43 [38400/60000 (64%)]	Loss: 1.483411
# Train Epoch: 43 [57600/60000 (96%)]	Loss: 1.515682
#
# Train set for client: Accuracy: 58521/60000 (98%)
#
#
# Test set for client: Average loss: 0.0234, Accuracy: 9766/10000 (98%)
#
# Train Epoch: 44 [0/60000 (0%)]	Loss: 1.512602
# Train Epoch: 44 [19200/60000 (32%)]	Loss: 1.498999
# Train Epoch: 44 [38400/60000 (64%)]	Loss: 1.489023
# Train Epoch: 44 [57600/60000 (96%)]	Loss: 1.468668
#
# Train set for client: Accuracy: 58498/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9763/10000 (98%)
#
# Train Epoch: 45 [0/60000 (0%)]	Loss: 1.470953
# Train Epoch: 45 [19200/60000 (32%)]	Loss: 1.484495
# Train Epoch: 45 [38400/60000 (64%)]	Loss: 1.481435
# Train Epoch: 45 [57600/60000 (96%)]	Loss: 1.484396
#
# Train set for client: Accuracy: 58501/60000 (98%)
#
#
# Test set for client: Average loss: 0.0234, Accuracy: 9778/10000 (98%)
#
# Train Epoch: 46 [0/60000 (0%)]	Loss: 1.505679
# Train Epoch: 46 [19200/60000 (32%)]	Loss: 1.504072
# Train Epoch: 46 [38400/60000 (64%)]	Loss: 1.503158
# Train Epoch: 46 [57600/60000 (96%)]	Loss: 1.511507
#
# Train set for client: Accuracy: 58554/60000 (98%)
#
#
# Test set for client: Average loss: 0.0234, Accuracy: 9772/10000 (98%)
#
# Train Epoch: 47 [0/60000 (0%)]	Loss: 1.487952
# Train Epoch: 47 [19200/60000 (32%)]	Loss: 1.514445
# Train Epoch: 47 [38400/60000 (64%)]	Loss: 1.492651
# Train Epoch: 47 [57600/60000 (96%)]	Loss: 1.512458
#
# Train set for client: Accuracy: 58549/60000 (98%)
#
#
# Test set for client: Average loss: 0.0234, Accuracy: 9772/10000 (98%)
#
# Train Epoch: 48 [0/60000 (0%)]	Loss: 1.479218
# Train Epoch: 48 [19200/60000 (32%)]	Loss: 1.488203
# Train Epoch: 48 [38400/60000 (64%)]	Loss: 1.472848
# Train Epoch: 48 [57600/60000 (96%)]	Loss: 1.494222
#
# Train set for client: Accuracy: 58551/60000 (98%)
#
#
# Test set for client: Average loss: 0.0234, Accuracy: 9763/10000 (98%)
#
# Train Epoch: 49 [0/60000 (0%)]	Loss: 1.498185
# Train Epoch: 49 [19200/60000 (32%)]	Loss: 1.493189
# Train Epoch: 49 [38400/60000 (64%)]	Loss: 1.510793
# Train Epoch: 49 [57600/60000 (96%)]	Loss: 1.484210
#
# Train set for client: Accuracy: 58568/60000 (98%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9760/10000 (98%)

# %%
def train_model(client,client_optimiser,server,server_optimiser,device,train_loader,epoch):
    client.train()
    server.train()
    criterion = nn.CrossEntropyLoss()
    correct = 0
    for batch_idx, (data, target) in enumerate(train_loader):        
        data, target = data.to(device), target.to(device)
        client_optimiser.zero_grad()
        server_optimiser.zero_grad()

        ### execute client - feed forward network
        intermediate = client(data)
        remote = intermediate.detach().requires_grad_()
        ### execute server - feed forward network
        output = server(remote)
        loss = criterion(output,target)
        loss.backward()
        ### execute client back propagation
        grad = remote.grad.clone()
        intermediate.backward(grad)
        ### optimiser step
        server_optimiser.step()
        client_optimiser.step()

        pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()
        ### printing logs
        if batch_idx % 300 == 0:
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
    
    print('\nTrain set for client: Accuracy: {}/{} ({:.0f}%)\n'.format(
        correct, len(train_loader.dataset),
        100. * correct / len(train_loader.dataset)))
    
def test_model(client,server,device,test_loader):
  client.eval()
  server.eval()
  criterion = nn.CrossEntropyLoss()
  with torch.no_grad():
      test_loss = 0
      correct = 0
      for data, target in test_loader:
          data, target = data.to(device), target.to(device)
          intermediate = client(data)
          output = server(intermediate)
          test_loss += criterion(output, target).item()  # sum up batch loss
          pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
          correct += pred.eq(target.view_as(pred)).sum().item()
      
      test_loss /= len(test_loader.dataset)
      print('\nTest set for client: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
          test_loss, correct, len(test_loader.dataset),
          100. * correct / len(test_loader.dataset)))

# %%
if __name__ == "__main__":
    random.seed(7)
    torch.manual_seed(7)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    if torch.cuda.is_available():  
        dev = "cuda:0" 
    else:  
        dev = "cpu"
    device = torch.device(dev)

    train_loader,test_loader = get_mnist_dataset(batch_size=64)

    client = lenet_client(input_channels=1).to(device)
    client_optim = optim.SGD(client.parameters(),lr=1e-2,weight_decay=5e-3)

    server = lenet_server(input_channels=256,output_channels=10).to(device)
    server_optim = optim.SGD(server.parameters(),lr=1e-2,weight_decay=5e-3)

    print("\n\nModel Summary")
    print("\nClient:")
    summary(client,(1,28,28))
    print("\n\nServer:")
    summary(server,(1,256))

    for i in range(1,50):
        train_model(client,client_optim,server,server_optim,device,train_loader,i)
        history1 = test_model(client,server,device,test_loader)
    
    torch.save({'server':server.state_dict(),
            'client':client.state_dict()},"split-model-single-agent.pt")
# Out:
# Model Summary
#
# Client:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 24, 24]             156
#               ReLU-2            [-1, 6, 24, 24]               0
#          MaxPool2d-3            [-1, 6, 12, 12]               0
#             Conv2d-4             [-1, 16, 8, 8]           2,416
#               ReLU-5             [-1, 16, 8, 8]               0
#          MaxPool2d-6             [-1, 16, 4, 4]               0
#            Flatten-7                  [-1, 256]               0
# ================================================================
# Total params: 2,572
# Trainable params: 2,572
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.08
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.09
# ----------------------------------------------------------------
#
#
# Server:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1               [-1, 1, 120]          30,840
#               ReLU-2               [-1, 1, 120]               0
#             Linear-3                [-1, 1, 84]          10,164
#               ReLU-4                [-1, 1, 84]               0
#             Linear-5                [-1, 1, 10]             850
#            Softmax-6                [-1, 1, 10]               0
# ================================================================
# Total params: 41,854
# Trainable params: 41,854
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.16
# Estimated Total Size (MB): 0.16
# ----------------------------------------------------------------
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302277
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 2.303382
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 2.301913
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 2.301521
#
# Train set for client: Accuracy: 7458/60000 (12%)
#
#
# Test set for client: Average loss: 0.0361, Accuracy: 1615/10000 (16%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 2.301989
# Train Epoch: 2 [19200/60000 (32%)]	Loss: 2.301589
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 2.298955
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 2.299975
#
# Train set for client: Accuracy: 12449/60000 (21%)
#
#
# Test set for client: Average loss: 0.0361, Accuracy: 2178/10000 (22%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 2.303036
# Train Epoch: 3 [19200/60000 (32%)]	Loss: 2.300316
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 2.299141
# Train Epoch: 3 [57600/60000 (96%)]	Loss: 2.297773
#
# Train set for client: Accuracy: 13209/60000 (22%)
#
#
# Test set for client: Average loss: 0.0361, Accuracy: 2295/10000 (23%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 2.297574
# Train Epoch: 4 [19200/60000 (32%)]	Loss: 2.295912
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 2.293005
# Train Epoch: 4 [57600/60000 (96%)]	Loss: 2.284199
#
# Train set for client: Accuracy: 18270/60000 (30%)
#
#
# Test set for client: Average loss: 0.0359, Accuracy: 3288/10000 (33%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 2.286741
# Train Epoch: 5 [19200/60000 (32%)]	Loss: 2.201233
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 2.181071
# Train Epoch: 5 [57600/60000 (96%)]	Loss: 2.015555
#
# Train set for client: Accuracy: 19952/60000 (33%)
#
#
# Test set for client: Average loss: 0.0307, Accuracy: 6114/10000 (61%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 1.933402
# Train Epoch: 6 [19200/60000 (32%)]	Loss: 1.768458
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 1.800441
# Train Epoch: 6 [57600/60000 (96%)]	Loss: 1.755683
#
# Train set for client: Accuracy: 42925/60000 (72%)
#
#
# Test set for client: Average loss: 0.0266, Accuracy: 7874/10000 (79%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 1.707368
# Train Epoch: 7 [19200/60000 (32%)]	Loss: 1.609655
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 1.680034
# Train Epoch: 7 [57600/60000 (96%)]	Loss: 1.569157
#
# Train set for client: Accuracy: 50480/60000 (84%)
#
#
# Test set for client: Average loss: 0.0250, Accuracy: 8856/10000 (89%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 1.610402
# Train Epoch: 8 [19200/60000 (32%)]	Loss: 1.568645
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 1.602573
# Train Epoch: 8 [57600/60000 (96%)]	Loss: 1.530028
#
# Train set for client: Accuracy: 53595/60000 (89%)
#
#
# Test set for client: Average loss: 0.0244, Accuracy: 9172/10000 (92%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 1.584438
# Train Epoch: 9 [19200/60000 (32%)]	Loss: 1.557198
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 1.580391
# Train Epoch: 9 [57600/60000 (96%)]	Loss: 1.544871
#
# Train set for client: Accuracy: 54768/60000 (91%)
#
#
# Test set for client: Average loss: 0.0244, Accuracy: 9225/10000 (92%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 1.558926
# Train Epoch: 10 [19200/60000 (32%)]	Loss: 1.549872
# Train Epoch: 10 [38400/60000 (64%)]	Loss: 1.549947
# Train Epoch: 10 [57600/60000 (96%)]	Loss: 1.502291
#
# Train set for client: Accuracy: 55553/60000 (93%)
#
#
# Test set for client: Average loss: 0.0241, Accuracy: 9374/10000 (94%)
#
# Train Epoch: 11 [0/60000 (0%)]	Loss: 1.557762
# Train Epoch: 11 [19200/60000 (32%)]	Loss: 1.502334
# Train Epoch: 11 [38400/60000 (64%)]	Loss: 1.508218
# Train Epoch: 11 [57600/60000 (96%)]	Loss: 1.538612
#
# Train set for client: Accuracy: 56154/60000 (94%)
#
#
# Test set for client: Average loss: 0.0240, Accuracy: 9418/10000 (94%)
#
# Train Epoch: 12 [0/60000 (0%)]	Loss: 1.497772
# Train Epoch: 12 [19200/60000 (32%)]	Loss: 1.538018
# Train Epoch: 12 [38400/60000 (64%)]	Loss: 1.590205
# Train Epoch: 12 [57600/60000 (96%)]	Loss: 1.515097
#
# Train set for client: Accuracy: 56565/60000 (94%)
#
#
# Test set for client: Average loss: 0.0239, Accuracy: 9482/10000 (95%)
#
# Train Epoch: 13 [0/60000 (0%)]	Loss: 1.538064
# Train Epoch: 13 [19200/60000 (32%)]	Loss: 1.579808
# Train Epoch: 13 [38400/60000 (64%)]	Loss: 1.518907
# Train Epoch: 13 [57600/60000 (96%)]	Loss: 1.539411
#
# Train set for client: Accuracy: 56939/60000 (95%)
#
#
# Test set for client: Average loss: 0.0238, Accuracy: 9546/10000 (95%)
#
# Train Epoch: 14 [0/60000 (0%)]	Loss: 1.547242
# Train Epoch: 14 [19200/60000 (32%)]	Loss: 1.512728
# Train Epoch: 14 [38400/60000 (64%)]	Loss: 1.477364
# Train Epoch: 14 [57600/60000 (96%)]	Loss: 1.491819
#
# Train set for client: Accuracy: 57201/60000 (95%)
#
#
# Test set for client: Average loss: 0.0237, Accuracy: 9599/10000 (96%)
#
# Train Epoch: 15 [0/60000 (0%)]	Loss: 1.520089
# Train Epoch: 15 [19200/60000 (32%)]	Loss: 1.558312
# Train Epoch: 15 [38400/60000 (64%)]	Loss: 1.515396
# Train Epoch: 15 [57600/60000 (96%)]	Loss: 1.505076
#
# Train set for client: Accuracy: 57429/60000 (96%)
#
#
# Test set for client: Average loss: 0.0237, Accuracy: 9598/10000 (96%)
#
# Train Epoch: 16 [0/60000 (0%)]	Loss: 1.534951
# Train Epoch: 16 [19200/60000 (32%)]	Loss: 1.544489
# Train Epoch: 16 [38400/60000 (64%)]	Loss: 1.519049
# Train Epoch: 16 [57600/60000 (96%)]	Loss: 1.524560
#
# Train set for client: Accuracy: 57534/60000 (96%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9643/10000 (96%)
#
# Train Epoch: 17 [0/60000 (0%)]	Loss: 1.508103
# Train Epoch: 17 [19200/60000 (32%)]	Loss: 1.556419
# Train Epoch: 17 [38400/60000 (64%)]	Loss: 1.482958
# Train Epoch: 17 [57600/60000 (96%)]	Loss: 1.509461
#
# Train set for client: Accuracy: 57717/60000 (96%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9665/10000 (97%)
#
# Train Epoch: 18 [0/60000 (0%)]	Loss: 1.526002
# Train Epoch: 18 [19200/60000 (32%)]	Loss: 1.493460
# Train Epoch: 18 [38400/60000 (64%)]	Loss: 1.498788
# Train Epoch: 18 [57600/60000 (96%)]	Loss: 1.520198
#
# Train set for client: Accuracy: 57821/60000 (96%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9684/10000 (97%)
#
# Train Epoch: 19 [0/60000 (0%)]	Loss: 1.522103
# Train Epoch: 19 [19200/60000 (32%)]	Loss: 1.496193
# Train Epoch: 19 [38400/60000 (64%)]	Loss: 1.520946
# Train Epoch: 19 [57600/60000 (96%)]	Loss: 1.521083
#
# Train set for client: Accuracy: 57874/60000 (96%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9656/10000 (97%)
#
# Train Epoch: 20 [0/60000 (0%)]	Loss: 1.500230
# Train Epoch: 20 [19200/60000 (32%)]	Loss: 1.475961
# Train Epoch: 20 [38400/60000 (64%)]	Loss: 1.488347
# Train Epoch: 20 [57600/60000 (96%)]	Loss: 1.506812
#
# Train set for client: Accuracy: 57937/60000 (97%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9689/10000 (97%)
#
# Train Epoch: 21 [0/60000 (0%)]	Loss: 1.550718
# Train Epoch: 21 [19200/60000 (32%)]	Loss: 1.496805
# Train Epoch: 21 [38400/60000 (64%)]	Loss: 1.526331
# Train Epoch: 21 [57600/60000 (96%)]	Loss: 1.513092
#
# Train set for client: Accuracy: 58018/60000 (97%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9697/10000 (97%)
#
# Train Epoch: 22 [0/60000 (0%)]	Loss: 1.499589
# Train Epoch: 22 [19200/60000 (32%)]	Loss: 1.490268
# Train Epoch: 22 [38400/60000 (64%)]	Loss: 1.496393
# Train Epoch: 22 [57600/60000 (96%)]	Loss: 1.485158
#
# Train set for client: Accuracy: 58085/60000 (97%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9686/10000 (97%)
#
# Train Epoch: 23 [0/60000 (0%)]	Loss: 1.489294
# Train Epoch: 23 [19200/60000 (32%)]	Loss: 1.495363
# Train Epoch: 23 [38400/60000 (64%)]	Loss: 1.515328
# Train Epoch: 23 [57600/60000 (96%)]	Loss: 1.501573
#
# Train set for client: Accuracy: 58156/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9712/10000 (97%)
#
# Train Epoch: 24 [0/60000 (0%)]	Loss: 1.504098
# Train Epoch: 24 [19200/60000 (32%)]	Loss: 1.485164
# Train Epoch: 24 [38400/60000 (64%)]	Loss: 1.496874
# Train Epoch: 24 [57600/60000 (96%)]	Loss: 1.490129
#
# Train set for client: Accuracy: 58190/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9731/10000 (97%)
#
# Train Epoch: 25 [0/60000 (0%)]	Loss: 1.513459
# Train Epoch: 25 [19200/60000 (32%)]	Loss: 1.524763
# Train Epoch: 25 [38400/60000 (64%)]	Loss: 1.530875
# Train Epoch: 25 [57600/60000 (96%)]	Loss: 1.506790
#
# Train set for client: Accuracy: 58230/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9725/10000 (97%)
#
# Train Epoch: 26 [0/60000 (0%)]	Loss: 1.520235
# Train Epoch: 26 [19200/60000 (32%)]	Loss: 1.517654
# Train Epoch: 26 [38400/60000 (64%)]	Loss: 1.486298
# Train Epoch: 26 [57600/60000 (96%)]	Loss: 1.482423
#
# Train set for client: Accuracy: 58230/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9724/10000 (97%)
#
# Train Epoch: 27 [0/60000 (0%)]	Loss: 1.509217
# Train Epoch: 27 [19200/60000 (32%)]	Loss: 1.475748
# Train Epoch: 27 [38400/60000 (64%)]	Loss: 1.501378
# Train Epoch: 27 [57600/60000 (96%)]	Loss: 1.492979
#
# Train set for client: Accuracy: 58253/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9733/10000 (97%)
#
# Train Epoch: 28 [0/60000 (0%)]	Loss: 1.519460
# Train Epoch: 28 [19200/60000 (32%)]	Loss: 1.518104
# Train Epoch: 28 [38400/60000 (64%)]	Loss: 1.499560
# Train Epoch: 28 [57600/60000 (96%)]	Loss: 1.478180
#
# Train set for client: Accuracy: 58310/60000 (97%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9699/10000 (97%)
#
# Train Epoch: 29 [0/60000 (0%)]	Loss: 1.556813
# Train Epoch: 29 [19200/60000 (32%)]	Loss: 1.493964
# Train Epoch: 29 [38400/60000 (64%)]	Loss: 1.483006
# Train Epoch: 29 [57600/60000 (96%)]	Loss: 1.529005
#
# Train set for client: Accuracy: 58334/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9727/10000 (97%)
#
# Train Epoch: 30 [0/60000 (0%)]	Loss: 1.511571
# Train Epoch: 30 [19200/60000 (32%)]	Loss: 1.515541
# Train Epoch: 30 [38400/60000 (64%)]	Loss: 1.496980
# Train Epoch: 30 [57600/60000 (96%)]	Loss: 1.553371
#
# Train set for client: Accuracy: 58365/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9759/10000 (98%)
#
# Train Epoch: 31 [0/60000 (0%)]	Loss: 1.523098
# Train Epoch: 31 [19200/60000 (32%)]	Loss: 1.523122
# Train Epoch: 31 [38400/60000 (64%)]	Loss: 1.487109
# Train Epoch: 31 [57600/60000 (96%)]	Loss: 1.471873
#
# Train set for client: Accuracy: 58350/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9720/10000 (97%)
#
# Train Epoch: 32 [0/60000 (0%)]	Loss: 1.522748
# Train Epoch: 32 [19200/60000 (32%)]	Loss: 1.500057
# Train Epoch: 32 [38400/60000 (64%)]	Loss: 1.494280
# Train Epoch: 32 [57600/60000 (96%)]	Loss: 1.484326
#
# Train set for client: Accuracy: 58380/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9750/10000 (98%)
#
# Train Epoch: 33 [0/60000 (0%)]	Loss: 1.518333
# Train Epoch: 33 [19200/60000 (32%)]	Loss: 1.492862
# Train Epoch: 33 [38400/60000 (64%)]	Loss: 1.487165
# Train Epoch: 33 [57600/60000 (96%)]	Loss: 1.483251
#
# Train set for client: Accuracy: 58390/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9753/10000 (98%)
#
# Train Epoch: 34 [0/60000 (0%)]	Loss: 1.518180
# Train Epoch: 34 [19200/60000 (32%)]	Loss: 1.547708
# Train Epoch: 34 [38400/60000 (64%)]	Loss: 1.504846
# Train Epoch: 34 [57600/60000 (96%)]	Loss: 1.512404
#
# Train set for client: Accuracy: 58424/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9754/10000 (98%)
#
# Train Epoch: 35 [0/60000 (0%)]	Loss: 1.488748
# Train Epoch: 35 [19200/60000 (32%)]	Loss: 1.527003
# Train Epoch: 35 [38400/60000 (64%)]	Loss: 1.491564
# Train Epoch: 35 [57600/60000 (96%)]	Loss: 1.516822
#
# Train set for client: Accuracy: 58427/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9762/10000 (98%)
#
# Train Epoch: 36 [0/60000 (0%)]	Loss: 1.545552
# Train Epoch: 36 [19200/60000 (32%)]	Loss: 1.527943
# Train Epoch: 36 [38400/60000 (64%)]	Loss: 1.495275
# Train Epoch: 36 [57600/60000 (96%)]	Loss: 1.542714
#
# Train set for client: Accuracy: 58448/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9771/10000 (98%)
#
# Train Epoch: 37 [0/60000 (0%)]	Loss: 1.489518
# Train Epoch: 37 [19200/60000 (32%)]	Loss: 1.487870
# Train Epoch: 37 [38400/60000 (64%)]	Loss: 1.472561
# Train Epoch: 37 [57600/60000 (96%)]	Loss: 1.507819
#
# Train set for client: Accuracy: 58457/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9705/10000 (97%)
#
# Train Epoch: 38 [0/60000 (0%)]	Loss: 1.484972
# Train Epoch: 38 [19200/60000 (32%)]	Loss: 1.478833
# Train Epoch: 38 [38400/60000 (64%)]	Loss: 1.492687
# Train Epoch: 38 [57600/60000 (96%)]	Loss: 1.526857
#
# Train set for client: Accuracy: 58470/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9774/10000 (98%)
#
# Train Epoch: 39 [0/60000 (0%)]	Loss: 1.516359
# Train Epoch: 39 [19200/60000 (32%)]	Loss: 1.515844
# Train Epoch: 39 [38400/60000 (64%)]	Loss: 1.482564
# Train Epoch: 39 [57600/60000 (96%)]	Loss: 1.528528
#
# Train set for client: Accuracy: 58460/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9764/10000 (98%)
#
# Train Epoch: 40 [0/60000 (0%)]	Loss: 1.487550
# Train Epoch: 40 [19200/60000 (32%)]	Loss: 1.496165
# Train Epoch: 40 [38400/60000 (64%)]	Loss: 1.487000
# Train Epoch: 40 [57600/60000 (96%)]	Loss: 1.476940
#
# Train set for client: Accuracy: 58480/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9755/10000 (98%)
#
# Train Epoch: 41 [0/60000 (0%)]	Loss: 1.506424
# Train Epoch: 41 [19200/60000 (32%)]	Loss: 1.488894
# Train Epoch: 41 [38400/60000 (64%)]	Loss: 1.524735
# Train Epoch: 41 [57600/60000 (96%)]	Loss: 1.475591
#
# Train set for client: Accuracy: 58532/60000 (98%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9743/10000 (97%)
#
# Train Epoch: 42 [0/60000 (0%)]	Loss: 1.529280
# Train Epoch: 42 [19200/60000 (32%)]	Loss: 1.471172
# Train Epoch: 42 [38400/60000 (64%)]	Loss: 1.504858
# Train Epoch: 42 [57600/60000 (96%)]	Loss: 1.490458
#
# Train set for client: Accuracy: 58500/60000 (98%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9772/10000 (98%)
#
# Train Epoch: 43 [0/60000 (0%)]	Loss: 1.480517
# Train Epoch: 43 [19200/60000 (32%)]	Loss: 1.487809
# Train Epoch: 43 [38400/60000 (64%)]	Loss: 1.476084
# Train Epoch: 43 [57600/60000 (96%)]	Loss: 1.506782
#
# Train set for client: Accuracy: 58529/60000 (98%)
#
#
# Test set for client: Average loss: 0.0234, Accuracy: 9767/10000 (98%)
#
# Train Epoch: 44 [0/60000 (0%)]	Loss: 1.495102
# Train Epoch: 44 [19200/60000 (32%)]	Loss: 1.476436
# Train Epoch: 44 [38400/60000 (64%)]	Loss: 1.478002
# Train Epoch: 44 [57600/60000 (96%)]	Loss: 1.494500
#
# Train set for client: Accuracy: 58537/60000 (98%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9763/10000 (98%)
#
# Train Epoch: 45 [0/60000 (0%)]	Loss: 1.488297
# Train Epoch: 45 [19200/60000 (32%)]	Loss: 1.513284
# Train Epoch: 45 [38400/60000 (64%)]	Loss: 1.519648
# Train Epoch: 45 [57600/60000 (96%)]	Loss: 1.515051
#
# Train set for client: Accuracy: 58532/60000 (98%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9741/10000 (97%)
#
# Train Epoch: 46 [0/60000 (0%)]	Loss: 1.481705
# Train Epoch: 46 [19200/60000 (32%)]	Loss: 1.505128
# Train Epoch: 46 [38400/60000 (64%)]	Loss: 1.470152
# Train Epoch: 46 [57600/60000 (96%)]	Loss: 1.490293
#
# Train set for client: Accuracy: 58559/60000 (98%)
#
#
# Test set for client: Average loss: 0.0234, Accuracy: 9782/10000 (98%)
#
# Train Epoch: 47 [0/60000 (0%)]	Loss: 1.492066
# Train Epoch: 47 [19200/60000 (32%)]	Loss: 1.475003
# Train Epoch: 47 [38400/60000 (64%)]	Loss: 1.485784
# Train Epoch: 47 [57600/60000 (96%)]	Loss: 1.501848
#
# Train set for client: Accuracy: 58564/60000 (98%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9776/10000 (98%)
#
# Train Epoch: 48 [0/60000 (0%)]	Loss: 1.497225
# Train Epoch: 48 [19200/60000 (32%)]	Loss: 1.506609
# Train Epoch: 48 [38400/60000 (64%)]	Loss: 1.526255
# Train Epoch: 48 [57600/60000 (96%)]	Loss: 1.470162
#
# Train set for client: Accuracy: 58580/60000 (98%)
#
#
# Test set for client: Average loss: 0.0234, Accuracy: 9778/10000 (98%)
#
# Train Epoch: 49 [0/60000 (0%)]	Loss: 1.486015
# Train Epoch: 49 [19200/60000 (32%)]	Loss: 1.468833
# Train Epoch: 49 [38400/60000 (64%)]	Loss: 1.503621
# Train Epoch: 49 [57600/60000 (96%)]	Loss: 1.486257
#
# Train set for client: Accuracy: 58562/60000 (98%)
#
#
# Test set for client: Average loss: 0.0234, Accuracy: 9783/10000 (98%)

# %%
def train_model(clients,client_optimisers,server,server_optimiser,device,train_loader,epoch):
    for client in clients:
        client.train()
    server.train()
    criterion = nn.CrossEntropyLoss()
    correct = 0
    previous_client = None
    for batch_idx, (data, target) in enumerate(train_loader):        
        data, target = data.to(device), target.to(device)

        client = clients[batch_idx%5]
        client_optimiser = client_optimisers[batch_idx%5]
        server_optimiser.zero_grad()
        client_optimiser.zero_grad()

        if previous_client:
            client.load_state_dict(previous_client.state_dict())

        ### execute client - feed forward network
        intermediate = client(data)
        remote = intermediate.detach().requires_grad_()
        ### execute server - feed forward network
        output = server(remote)
        loss = criterion(output,target)
        loss.backward()
        ### execute client back propagation
        grad = remote.grad.clone()
        intermediate.backward(grad)
        ### optimiser step
        server_optimiser.step()
        client_optimiser.step()
        previous_client = client

        pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()
        ### printing logs
        if batch_idx % 300 == 0:
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
    
    print('\nTrain set for client: Accuracy: {}/{} ({:.0f}%)\n'.format(
        correct, len(train_loader.dataset),
        100. * correct / len(train_loader.dataset)))

def test_model(clients,server,device,test_loader):
    for client in clients:
        client.eval()
    server.eval()
    criterion = nn.CrossEntropyLoss()
    for client in clients:
        with torch.no_grad():
            test_loss = 0
            correct = 0
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                intermediate = client(data)
                output = server(intermediate)
                test_loss += criterion(output, target).item()  # sum up batch loss
                pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
                correct += pred.eq(target.view_as(pred)).sum().item()
            
            test_loss /= len(test_loader.dataset)
            print('\nTest set for client: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
                test_loss, correct, len(test_loader.dataset),
                100. * correct / len(test_loader.dataset)))

if __name__ == "__main__":
    random.seed(7)
    torch.manual_seed(7)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    if torch.cuda.is_available():  
        dev = "cuda:0" 
    else:  
        dev = "cpu"
    device = torch.device(dev)

    train_loader,test_loader = get_mnist_dataset(batch_size=64)

    clients=[]
    client_optimisers = []
    for i in range(5):
        client = lenet_client(input_channels=1).to(device)
        client_optim = optim.SGD(client.parameters(),lr=1e-2,weight_decay=5e-3)
        clients.append(client)
        client_optimisers.append(client_optim)

    server = lenet_server(input_channels=256,output_channels=10).to(device)
    server_optim = optim.SGD(server.parameters(),lr=1e-2,weight_decay=5e-3)

    print("\n\nModel Summary")
    print("\nClient:")
    summary(clients[0],(1,28,28))
    print("\n\nServer:")
    summary(server,(1,256))

    for i in range(1,50):
        train_model(clients,client_optimisers,server,server_optim,device,train_loader,i)
        test_model(clients,server,device,test_loader)
    
    torch.save({'server':server.state_dict(),
            'client1':clients[0].state_dict(),
            'client2':clients[1].state_dict(),
            'client3':clients[2].state_dict(),
            'client4':clients[3].state_dict(),
            'client5':clients[4].state_dict()},"split-model-multi-agent.pt")
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw
# Processing...
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# Done!
#
#
# Model Summary
#
# Client:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 24, 24]             156
#               ReLU-2            [-1, 6, 24, 24]               0
#          MaxPool2d-3            [-1, 6, 12, 12]               0
#             Conv2d-4             [-1, 16, 8, 8]           2,416
#               ReLU-5             [-1, 16, 8, 8]               0
#          MaxPool2d-6             [-1, 16, 4, 4]               0
#            Flatten-7                  [-1, 256]               0
# ================================================================
# Total params: 2,572
# Trainable params: 2,572
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.08
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.09
# ----------------------------------------------------------------
#
#
# Server:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1               [-1, 1, 120]          30,840
#               ReLU-2               [-1, 1, 120]               0
#             Linear-3                [-1, 1, 84]          10,164
#               ReLU-4                [-1, 1, 84]               0
#             Linear-5                [-1, 1, 10]             850
#            Softmax-6                [-1, 1, 10]               0
# ================================================================
# Total params: 41,854
# Trainable params: 41,854
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.16
# Estimated Total Size (MB): 0.16
# ----------------------------------------------------------------
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302571
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 2.302400
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 2.300459
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 2.301578
#
# Train set for client: Accuracy: 7088/60000 (12%)
#
#
# Test set for client: Average loss: 0.0361, Accuracy: 1510/10000 (15%)
#
# Test set for client: Average loss: 0.0361, Accuracy: 1510/10000 (15%)
#
# Test set for client: Average loss: 0.0361, Accuracy: 1513/10000 (15%)
#
# Test set for client: Average loss: 0.0361, Accuracy: 1509/10000 (15%)
#
# Test set for client: Average loss: 0.0361, Accuracy: 1510/10000 (15%)
# Train Epoch: 2 [0/60000 (0%)]	Loss: 2.300454
# Train Epoch: 2 [19200/60000 (32%)]	Loss: 2.299955
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 2.299955
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 2.297885
#
# Train set for client: Accuracy: 11472/60000 (19%)
#
#
# Test set for client: Average loss: 0.0361, Accuracy: 2097/10000 (21%)
#
# Test set for client: Average loss: 0.0361, Accuracy: 2097/10000 (21%)
#
# Test set for client: Average loss: 0.0361, Accuracy: 2097/10000 (21%)
#
# Test set for client: Average loss: 0.0361, Accuracy: 2097/10000 (21%)
#
# Test set for client: Average loss: 0.0361, Accuracy: 2097/10000 (21%)
# Train Epoch: 3 [0/60000 (0%)]	Loss: 2.299515
# Train Epoch: 3 [19200/60000 (32%)]	Loss: 2.298296
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 2.292071
# Train Epoch: 3 [57600/60000 (96%)]	Loss: 2.288026
#
# Train set for client: Accuracy: 12577/60000 (21%)
#
#
# Test set for client: Average loss: 0.0359, Accuracy: 2100/10000 (21%)
#
# Test set for client: Average loss: 0.0359, Accuracy: 2100/10000 (21%)
#
# Test set for client: Average loss: 0.0359, Accuracy: 2100/10000 (21%)
#
# Test set for client: Average loss: 0.0359, Accuracy: 2100/10000 (21%)
#
# Test set for client: Average loss: 0.0359, Accuracy: 2100/10000 (21%)
# Train Epoch: 4 [0/60000 (0%)]	Loss: 2.284422
# Train Epoch: 4 [19200/60000 (32%)]	Loss: 2.263950
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 2.166822
# Train Epoch: 4 [57600/60000 (96%)]	Loss: 2.045410
#
# Train set for client: Accuracy: 16828/60000 (28%)
#
#
# Test set for client: Average loss: 0.0315, Accuracy: 5150/10000 (52%)
#
# Test set for client: Average loss: 0.0315, Accuracy: 5150/10000 (52%)
#
# Test set for client: Average loss: 0.0315, Accuracy: 5149/10000 (51%)
#
# Test set for client: Average loss: 0.0315, Accuracy: 5148/10000 (51%)
#
# Test set for client: Average loss: 0.0315, Accuracy: 5150/10000 (52%)
# Train Epoch: 5 [0/60000 (0%)]	Loss: 2.014174
# Train Epoch: 5 [19200/60000 (32%)]	Loss: 1.881239
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 1.772046
# Train Epoch: 5 [57600/60000 (96%)]	Loss: 1.675284
#
# Train set for client: Accuracy: 40067/60000 (67%)
#
#
# Test set for client: Average loss: 0.0268, Accuracy: 7725/10000 (77%)
#
# Test set for client: Average loss: 0.0268, Accuracy: 7723/10000 (77%)
#
# Test set for client: Average loss: 0.0268, Accuracy: 7723/10000 (77%)
#
# Test set for client: Average loss: 0.0268, Accuracy: 7727/10000 (77%)
#
# Test set for client: Average loss: 0.0268, Accuracy: 7728/10000 (77%)
# Train Epoch: 6 [0/60000 (0%)]	Loss: 1.671482
# Train Epoch: 6 [19200/60000 (32%)]	Loss: 1.708432
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 1.685395
# Train Epoch: 6 [57600/60000 (96%)]	Loss: 1.748366
#
# Train set for client: Accuracy: 47502/60000 (79%)
#
#
# Test set for client: Average loss: 0.0261, Accuracy: 8103/10000 (81%)
#
# Test set for client: Average loss: 0.0261, Accuracy: 8100/10000 (81%)
#
# Test set for client: Average loss: 0.0261, Accuracy: 8101/10000 (81%)
#
# Test set for client: Average loss: 0.0261, Accuracy: 8100/10000 (81%)
#
# Test set for client: Average loss: 0.0261, Accuracy: 8101/10000 (81%)
# Train Epoch: 7 [0/60000 (0%)]	Loss: 1.694272
# Train Epoch: 7 [19200/60000 (32%)]	Loss: 1.618547
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 1.643396
# Train Epoch: 7 [57600/60000 (96%)]	Loss: 1.668659
#
# Train set for client: Accuracy: 48947/60000 (82%)
#
#
# Test set for client: Average loss: 0.0258, Accuracy: 8274/10000 (83%)
#
# Test set for client: Average loss: 0.0258, Accuracy: 8278/10000 (83%)
#
# Test set for client: Average loss: 0.0258, Accuracy: 8274/10000 (83%)
#
# Test set for client: Average loss: 0.0258, Accuracy: 8276/10000 (83%)
#
# Test set for client: Average loss: 0.0258, Accuracy: 8273/10000 (83%)
# Train Epoch: 8 [0/60000 (0%)]	Loss: 1.557731
# Train Epoch: 8 [19200/60000 (32%)]	Loss: 1.644464
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 1.656003
# Train Epoch: 8 [57600/60000 (96%)]	Loss: 1.622596
#
# Train set for client: Accuracy: 49780/60000 (83%)
#
#
# Test set for client: Average loss: 0.0255, Accuracy: 8442/10000 (84%)
#
# Test set for client: Average loss: 0.0255, Accuracy: 8446/10000 (84%)
#
# Test set for client: Average loss: 0.0255, Accuracy: 8446/10000 (84%)
#
# Test set for client: Average loss: 0.0255, Accuracy: 8449/10000 (84%)
#
# Test set for client: Average loss: 0.0255, Accuracy: 8448/10000 (84%)
# Train Epoch: 9 [0/60000 (0%)]	Loss: 1.627127
# Train Epoch: 9 [19200/60000 (32%)]	Loss: 1.635310
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 1.691382
# Train Epoch: 9 [57600/60000 (96%)]	Loss: 1.606833
#
# Train set for client: Accuracy: 50382/60000 (84%)
#
#
# Test set for client: Average loss: 0.0254, Accuracy: 8522/10000 (85%)
#
# Test set for client: Average loss: 0.0254, Accuracy: 8523/10000 (85%)
#
# Test set for client: Average loss: 0.0254, Accuracy: 8516/10000 (85%)
#
# Test set for client: Average loss: 0.0254, Accuracy: 8522/10000 (85%)
#
# Test set for client: Average loss: 0.0254, Accuracy: 8520/10000 (85%)
# Train Epoch: 10 [0/60000 (0%)]	Loss: 1.587705
# Train Epoch: 10 [19200/60000 (32%)]	Loss: 1.628268
# Train Epoch: 10 [38400/60000 (64%)]	Loss: 1.583982
# Train Epoch: 10 [57600/60000 (96%)]	Loss: 1.570482
#
# Train set for client: Accuracy: 50874/60000 (85%)
#
#
# Test set for client: Average loss: 0.0253, Accuracy: 8568/10000 (86%)
#
# Test set for client: Average loss: 0.0253, Accuracy: 8565/10000 (86%)
#
# Test set for client: Average loss: 0.0253, Accuracy: 8563/10000 (86%)
#
# Test set for client: Average loss: 0.0253, Accuracy: 8560/10000 (86%)
#
# Test set for client: Average loss: 0.0253, Accuracy: 8565/10000 (86%)
# Train Epoch: 11 [0/60000 (0%)]	Loss: 1.672743
# Train Epoch: 11 [19200/60000 (32%)]	Loss: 1.614979
# Train Epoch: 11 [38400/60000 (64%)]	Loss: 1.644986
# Train Epoch: 11 [57600/60000 (96%)]	Loss: 1.622648
#
# Train set for client: Accuracy: 51234/60000 (85%)
#
#
# Test set for client: Average loss: 0.0252, Accuracy: 8613/10000 (86%)
#
# Test set for client: Average loss: 0.0252, Accuracy: 8613/10000 (86%)
#
# Test set for client: Average loss: 0.0252, Accuracy: 8616/10000 (86%)
#
# Test set for client: Average loss: 0.0252, Accuracy: 8614/10000 (86%)
#
# Test set for client: Average loss: 0.0252, Accuracy: 8611/10000 (86%)
# Train Epoch: 12 [0/60000 (0%)]	Loss: 1.600659
# Train Epoch: 12 [19200/60000 (32%)]	Loss: 1.605252
# Train Epoch: 12 [38400/60000 (64%)]	Loss: 1.608939
# Train Epoch: 12 [57600/60000 (96%)]	Loss: 1.664057
#
# Train set for client: Accuracy: 51481/60000 (86%)
#
#
# Test set for client: Average loss: 0.0252, Accuracy: 8654/10000 (87%)
#
# Test set for client: Average loss: 0.0252, Accuracy: 8658/10000 (87%)
#
# Test set for client: Average loss: 0.0252, Accuracy: 8654/10000 (87%)
#
# Test set for client: Average loss: 0.0252, Accuracy: 8653/10000 (87%)
#
# Test set for client: Average loss: 0.0252, Accuracy: 8654/10000 (87%)
# Train Epoch: 13 [0/60000 (0%)]	Loss: 1.640006
# Train Epoch: 13 [19200/60000 (32%)]	Loss: 1.620743
# Train Epoch: 13 [38400/60000 (64%)]	Loss: 1.616131
# Train Epoch: 13 [57600/60000 (96%)]	Loss: 1.612852
#
# Train set for client: Accuracy: 51728/60000 (86%)
#
#
# Test set for client: Average loss: 0.0252, Accuracy: 8669/10000 (87%)
#
# Test set for client: Average loss: 0.0252, Accuracy: 8666/10000 (87%)
#
# Test set for client: Average loss: 0.0252, Accuracy: 8672/10000 (87%)
#
# Test set for client: Average loss: 0.0252, Accuracy: 8674/10000 (87%)
#
# Test set for client: Average loss: 0.0251, Accuracy: 8675/10000 (87%)
# Train Epoch: 14 [0/60000 (0%)]	Loss: 1.656017
# Train Epoch: 14 [19200/60000 (32%)]	Loss: 1.580285
# Train Epoch: 14 [38400/60000 (64%)]	Loss: 1.563916
# Train Epoch: 14 [57600/60000 (96%)]	Loss: 1.541407
#
# Train set for client: Accuracy: 52596/60000 (88%)
#
#
# Test set for client: Average loss: 0.0242, Accuracy: 9412/10000 (94%)
#
# Test set for client: Average loss: 0.0242, Accuracy: 9411/10000 (94%)
#
# Test set for client: Average loss: 0.0242, Accuracy: 9410/10000 (94%)
#
# Test set for client: Average loss: 0.0242, Accuracy: 9409/10000 (94%)
#
# Test set for client: Average loss: 0.0242, Accuracy: 9401/10000 (94%)
# Train Epoch: 15 [0/60000 (0%)]	Loss: 1.520835
# Train Epoch: 15 [19200/60000 (32%)]	Loss: 1.517866
# Train Epoch: 15 [38400/60000 (64%)]	Loss: 1.526183
# Train Epoch: 15 [57600/60000 (96%)]	Loss: 1.561785
#
# Train set for client: Accuracy: 56566/60000 (94%)
#
#
# Test set for client: Average loss: 0.0239, Accuracy: 9546/10000 (95%)
#
# Test set for client: Average loss: 0.0239, Accuracy: 9543/10000 (95%)
#
# Test set for client: Average loss: 0.0239, Accuracy: 9542/10000 (95%)
#
# Test set for client: Average loss: 0.0239, Accuracy: 9540/10000 (95%)
#
# Test set for client: Average loss: 0.0239, Accuracy: 9541/10000 (95%)
# Train Epoch: 16 [0/60000 (0%)]	Loss: 1.535190
# Train Epoch: 16 [19200/60000 (32%)]	Loss: 1.516478
# Train Epoch: 16 [38400/60000 (64%)]	Loss: 1.533306
# Train Epoch: 16 [57600/60000 (96%)]	Loss: 1.494789
#
# Train set for client: Accuracy: 57069/60000 (95%)
#
#
# Test set for client: Average loss: 0.0238, Accuracy: 9576/10000 (96%)
#
# Test set for client: Average loss: 0.0238, Accuracy: 9570/10000 (96%)
#
# Test set for client: Average loss: 0.0238, Accuracy: 9571/10000 (96%)
#
# Test set for client: Average loss: 0.0238, Accuracy: 9575/10000 (96%)
#
# Test set for client: Average loss: 0.0238, Accuracy: 9570/10000 (96%)
# Train Epoch: 17 [0/60000 (0%)]	Loss: 1.536693
# Train Epoch: 17 [19200/60000 (32%)]	Loss: 1.487202
# Train Epoch: 17 [38400/60000 (64%)]	Loss: 1.515217
# Train Epoch: 17 [57600/60000 (96%)]	Loss: 1.482324
#
# Train set for client: Accuracy: 57346/60000 (96%)
#
#
# Test set for client: Average loss: 0.0237, Accuracy: 9604/10000 (96%)
#
# Test set for client: Average loss: 0.0237, Accuracy: 9607/10000 (96%)
#
# Test set for client: Average loss: 0.0237, Accuracy: 9607/10000 (96%)
#
# Test set for client: Average loss: 0.0237, Accuracy: 9607/10000 (96%)
#
# Test set for client: Average loss: 0.0237, Accuracy: 9605/10000 (96%)
# Train Epoch: 18 [0/60000 (0%)]	Loss: 1.520265
# Train Epoch: 18 [19200/60000 (32%)]	Loss: 1.511786
# Train Epoch: 18 [38400/60000 (64%)]	Loss: 1.503402
# Train Epoch: 18 [57600/60000 (96%)]	Loss: 1.491353
#
# Train set for client: Accuracy: 57514/60000 (96%)
#
#
# Test set for client: Average loss: 0.0237, Accuracy: 9634/10000 (96%)
#
# Test set for client: Average loss: 0.0237, Accuracy: 9632/10000 (96%)
#
# Test set for client: Average loss: 0.0237, Accuracy: 9634/10000 (96%)
#
# Test set for client: Average loss: 0.0237, Accuracy: 9636/10000 (96%)
#
# Test set for client: Average loss: 0.0237, Accuracy: 9633/10000 (96%)
# Train Epoch: 19 [0/60000 (0%)]	Loss: 1.495613
# Train Epoch: 19 [19200/60000 (32%)]	Loss: 1.524583
# Train Epoch: 19 [38400/60000 (64%)]	Loss: 1.504628
# Train Epoch: 19 [57600/60000 (96%)]	Loss: 1.493308
#
# Train set for client: Accuracy: 57699/60000 (96%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9662/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9661/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9664/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9665/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9662/10000 (97%)
# Train Epoch: 20 [0/60000 (0%)]	Loss: 1.529244
# Train Epoch: 20 [19200/60000 (32%)]	Loss: 1.553919
# Train Epoch: 20 [38400/60000 (64%)]	Loss: 1.512975
# Train Epoch: 20 [57600/60000 (96%)]	Loss: 1.474991
#
# Train set for client: Accuracy: 57765/60000 (96%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9653/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9653/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9652/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9661/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9651/10000 (97%)
# Train Epoch: 21 [0/60000 (0%)]	Loss: 1.504156
# Train Epoch: 21 [19200/60000 (32%)]	Loss: 1.507844
# Train Epoch: 21 [38400/60000 (64%)]	Loss: 1.514647
# Train Epoch: 21 [57600/60000 (96%)]	Loss: 1.521239
#
# Train set for client: Accuracy: 57882/60000 (96%)
#
#
# Test set for client: Average loss: 0.0237, Accuracy: 9628/10000 (96%)
#
# Test set for client: Average loss: 0.0237, Accuracy: 9628/10000 (96%)
#
# Test set for client: Average loss: 0.0237, Accuracy: 9594/10000 (96%)
#
# Test set for client: Average loss: 0.0237, Accuracy: 9623/10000 (96%)
#
# Test set for client: Average loss: 0.0237, Accuracy: 9639/10000 (96%)
# Train Epoch: 22 [0/60000 (0%)]	Loss: 1.546438
# Train Epoch: 22 [19200/60000 (32%)]	Loss: 1.483715
# Train Epoch: 22 [38400/60000 (64%)]	Loss: 1.509788
# Train Epoch: 22 [57600/60000 (96%)]	Loss: 1.508480
#
# Train set for client: Accuracy: 57952/60000 (97%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9698/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9696/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9696/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9696/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9696/10000 (97%)
# Train Epoch: 23 [0/60000 (0%)]	Loss: 1.516004
# Train Epoch: 23 [19200/60000 (32%)]	Loss: 1.498142
# Train Epoch: 23 [38400/60000 (64%)]	Loss: 1.499217
# Train Epoch: 23 [57600/60000 (96%)]	Loss: 1.515300
#
# Train set for client: Accuracy: 57950/60000 (97%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9706/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9705/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9698/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9708/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9705/10000 (97%)
# Train Epoch: 24 [0/60000 (0%)]	Loss: 1.526248
# Train Epoch: 24 [19200/60000 (32%)]	Loss: 1.499169
# Train Epoch: 24 [38400/60000 (64%)]	Loss: 1.506980
# Train Epoch: 24 [57600/60000 (96%)]	Loss: 1.530442
#
# Train set for client: Accuracy: 58079/60000 (97%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9699/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9698/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9695/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9704/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9699/10000 (97%)
# Train Epoch: 25 [0/60000 (0%)]	Loss: 1.501726
# Train Epoch: 25 [19200/60000 (32%)]	Loss: 1.498834
# Train Epoch: 25 [38400/60000 (64%)]	Loss: 1.515802
# Train Epoch: 25 [57600/60000 (96%)]	Loss: 1.518860
#
# Train set for client: Accuracy: 58091/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9723/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9726/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9726/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9723/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9724/10000 (97%)
# Train Epoch: 26 [0/60000 (0%)]	Loss: 1.507097
# Train Epoch: 26 [19200/60000 (32%)]	Loss: 1.513055
# Train Epoch: 26 [38400/60000 (64%)]	Loss: 1.485913
# Train Epoch: 26 [57600/60000 (96%)]	Loss: 1.485067
#
# Train set for client: Accuracy: 58110/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9719/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9718/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9721/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9722/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9722/10000 (97%)
# Train Epoch: 27 [0/60000 (0%)]	Loss: 1.495172
# Train Epoch: 27 [19200/60000 (32%)]	Loss: 1.489771
# Train Epoch: 27 [38400/60000 (64%)]	Loss: 1.497139
# Train Epoch: 27 [57600/60000 (96%)]	Loss: 1.504619
#
# Train set for client: Accuracy: 58166/60000 (97%)
#
#
# Test set for client: Average loss: 0.0236, Accuracy: 9695/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9694/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9688/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9696/10000 (97%)
#
# Test set for client: Average loss: 0.0236, Accuracy: 9694/10000 (97%)
# Train Epoch: 28 [0/60000 (0%)]	Loss: 1.499914
# Train Epoch: 28 [19200/60000 (32%)]	Loss: 1.531079
# Train Epoch: 28 [38400/60000 (64%)]	Loss: 1.485768
# Train Epoch: 28 [57600/60000 (96%)]	Loss: 1.488753
#
# Train set for client: Accuracy: 58195/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9747/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9746/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9747/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9747/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9747/10000 (97%)
# Train Epoch: 29 [0/60000 (0%)]	Loss: 1.522813
# Train Epoch: 29 [19200/60000 (32%)]	Loss: 1.515085
# Train Epoch: 29 [38400/60000 (64%)]	Loss: 1.514477
# Train Epoch: 29 [57600/60000 (96%)]	Loss: 1.490928
#
# Train set for client: Accuracy: 58225/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9757/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9753/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9756/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9756/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9755/10000 (98%)
# Train Epoch: 30 [0/60000 (0%)]	Loss: 1.474604
# Train Epoch: 30 [19200/60000 (32%)]	Loss: 1.505742
# Train Epoch: 30 [38400/60000 (64%)]	Loss: 1.494044
# Train Epoch: 30 [57600/60000 (96%)]	Loss: 1.501312
#
# Train set for client: Accuracy: 58222/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9757/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9757/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9759/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9753/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9757/10000 (98%)
# Train Epoch: 31 [0/60000 (0%)]	Loss: 1.528211
# Train Epoch: 31 [19200/60000 (32%)]	Loss: 1.486930
# Train Epoch: 31 [38400/60000 (64%)]	Loss: 1.513594
# Train Epoch: 31 [57600/60000 (96%)]	Loss: 1.495608
#
# Train set for client: Accuracy: 58259/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9762/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9761/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9760/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9763/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9755/10000 (98%)
# Train Epoch: 32 [0/60000 (0%)]	Loss: 1.498235
# Train Epoch: 32 [19200/60000 (32%)]	Loss: 1.482073
# Train Epoch: 32 [38400/60000 (64%)]	Loss: 1.509356
# Train Epoch: 32 [57600/60000 (96%)]	Loss: 1.510725
#
# Train set for client: Accuracy: 58279/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9744/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9739/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9736/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9744/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9743/10000 (97%)
# Train Epoch: 33 [0/60000 (0%)]	Loss: 1.502014
# Train Epoch: 33 [19200/60000 (32%)]	Loss: 1.536329
# Train Epoch: 33 [38400/60000 (64%)]	Loss: 1.493944
# Train Epoch: 33 [57600/60000 (96%)]	Loss: 1.482924
#
# Train set for client: Accuracy: 58306/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9737/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9739/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9740/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9738/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9737/10000 (97%)
# Train Epoch: 34 [0/60000 (0%)]	Loss: 1.521630
# Train Epoch: 34 [19200/60000 (32%)]	Loss: 1.496517
# Train Epoch: 34 [38400/60000 (64%)]	Loss: 1.489825
# Train Epoch: 34 [57600/60000 (96%)]	Loss: 1.506982
#
# Train set for client: Accuracy: 58316/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9744/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9741/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9739/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9744/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9743/10000 (97%)
# Train Epoch: 35 [0/60000 (0%)]	Loss: 1.514003
# Train Epoch: 35 [19200/60000 (32%)]	Loss: 1.487559
# Train Epoch: 35 [38400/60000 (64%)]	Loss: 1.526945
# Train Epoch: 35 [57600/60000 (96%)]	Loss: 1.487843
#
# Train set for client: Accuracy: 58356/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9760/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9760/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9765/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9759/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9763/10000 (98%)
# Train Epoch: 36 [0/60000 (0%)]	Loss: 1.488492
# Train Epoch: 36 [19200/60000 (32%)]	Loss: 1.542812
# Train Epoch: 36 [38400/60000 (64%)]	Loss: 1.482452
# Train Epoch: 36 [57600/60000 (96%)]	Loss: 1.489593
#
# Train set for client: Accuracy: 58346/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9763/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9762/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9760/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9761/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9764/10000 (98%)
# Train Epoch: 37 [0/60000 (0%)]	Loss: 1.487162
# Train Epoch: 37 [19200/60000 (32%)]	Loss: 1.500610
# Train Epoch: 37 [38400/60000 (64%)]	Loss: 1.505411
# Train Epoch: 37 [57600/60000 (96%)]	Loss: 1.488978
#
# Train set for client: Accuracy: 58375/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9767/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9770/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9771/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9767/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9765/10000 (98%)
# Train Epoch: 38 [0/60000 (0%)]	Loss: 1.509760
# Train Epoch: 38 [19200/60000 (32%)]	Loss: 1.478527
# Train Epoch: 38 [38400/60000 (64%)]	Loss: 1.503127
# Train Epoch: 38 [57600/60000 (96%)]	Loss: 1.494862
#
# Train set for client: Accuracy: 58381/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9761/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9763/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9760/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9761/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9761/10000 (98%)
# Train Epoch: 39 [0/60000 (0%)]	Loss: 1.542391
# Train Epoch: 39 [19200/60000 (32%)]	Loss: 1.504799
# Train Epoch: 39 [38400/60000 (64%)]	Loss: 1.517912
# Train Epoch: 39 [57600/60000 (96%)]	Loss: 1.497825
#
# Train set for client: Accuracy: 58385/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9766/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9766/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9767/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9765/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9766/10000 (98%)
# Train Epoch: 40 [0/60000 (0%)]	Loss: 1.502853
# Train Epoch: 40 [19200/60000 (32%)]	Loss: 1.494644
# Train Epoch: 40 [38400/60000 (64%)]	Loss: 1.496269
# Train Epoch: 40 [57600/60000 (96%)]	Loss: 1.508133
#
# Train set for client: Accuracy: 58396/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9763/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9767/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9764/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9761/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9765/10000 (98%)
# Train Epoch: 41 [0/60000 (0%)]	Loss: 1.497046
# Train Epoch: 41 [19200/60000 (32%)]	Loss: 1.499719
# Train Epoch: 41 [38400/60000 (64%)]	Loss: 1.517289
# Train Epoch: 41 [57600/60000 (96%)]	Loss: 1.523587
#
# Train set for client: Accuracy: 58419/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9766/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9765/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9766/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9771/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9769/10000 (98%)
# Train Epoch: 42 [0/60000 (0%)]	Loss: 1.496865
# Train Epoch: 42 [19200/60000 (32%)]	Loss: 1.488709
# Train Epoch: 42 [38400/60000 (64%)]	Loss: 1.494174
# Train Epoch: 42 [57600/60000 (96%)]	Loss: 1.499612
#
# Train set for client: Accuracy: 58431/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9743/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9742/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9741/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9746/10000 (97%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9745/10000 (97%)
# Train Epoch: 43 [0/60000 (0%)]	Loss: 1.515422
# Train Epoch: 43 [19200/60000 (32%)]	Loss: 1.492748
# Train Epoch: 43 [38400/60000 (64%)]	Loss: 1.514378
# Train Epoch: 43 [57600/60000 (96%)]	Loss: 1.512275
#
# Train set for client: Accuracy: 58445/60000 (97%)
#
#
# Test set for client: Average loss: 0.0234, Accuracy: 9777/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9779/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9776/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9778/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9778/10000 (98%)
# Train Epoch: 44 [0/60000 (0%)]	Loss: 1.487600
# Train Epoch: 44 [19200/60000 (32%)]	Loss: 1.505452
# Train Epoch: 44 [38400/60000 (64%)]	Loss: 1.506084
# Train Epoch: 44 [57600/60000 (96%)]	Loss: 1.481678
#
# Train set for client: Accuracy: 58453/60000 (97%)
#
#
# Test set for client: Average loss: 0.0234, Accuracy: 9769/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9769/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9766/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9767/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9768/10000 (98%)
# Train Epoch: 45 [0/60000 (0%)]	Loss: 1.485989
# Train Epoch: 45 [19200/60000 (32%)]	Loss: 1.482733
# Train Epoch: 45 [38400/60000 (64%)]	Loss: 1.486096
# Train Epoch: 45 [57600/60000 (96%)]	Loss: 1.517580
#
# Train set for client: Accuracy: 58465/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9760/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9758/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9752/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9753/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9757/10000 (98%)
# Train Epoch: 46 [0/60000 (0%)]	Loss: 1.512345
# Train Epoch: 46 [19200/60000 (32%)]	Loss: 1.485456
# Train Epoch: 46 [38400/60000 (64%)]	Loss: 1.495193
# Train Epoch: 46 [57600/60000 (96%)]	Loss: 1.495481
#
# Train set for client: Accuracy: 58481/60000 (97%)
#
#
# Test set for client: Average loss: 0.0234, Accuracy: 9783/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9781/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9781/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9785/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9783/10000 (98%)
# Train Epoch: 47 [0/60000 (0%)]	Loss: 1.511001
# Train Epoch: 47 [19200/60000 (32%)]	Loss: 1.493042
# Train Epoch: 47 [38400/60000 (64%)]	Loss: 1.482016
# Train Epoch: 47 [57600/60000 (96%)]	Loss: 1.549641
#
# Train set for client: Accuracy: 58498/60000 (97%)
#
#
# Test set for client: Average loss: 0.0234, Accuracy: 9779/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9777/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9776/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9781/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9779/10000 (98%)
# Train Epoch: 48 [0/60000 (0%)]	Loss: 1.476224
# Train Epoch: 48 [19200/60000 (32%)]	Loss: 1.470725
# Train Epoch: 48 [38400/60000 (64%)]	Loss: 1.515397
# Train Epoch: 48 [57600/60000 (96%)]	Loss: 1.504235
#
# Train set for client: Accuracy: 58493/60000 (97%)
#
#
# Test set for client: Average loss: 0.0234, Accuracy: 9779/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9781/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9780/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9783/10000 (98%)
#
# Test set for client: Average loss: 0.0234, Accuracy: 9779/10000 (98%)
# Train Epoch: 49 [0/60000 (0%)]	Loss: 1.480624
# Train Epoch: 49 [19200/60000 (32%)]	Loss: 1.506853
# Train Epoch: 49 [38400/60000 (64%)]	Loss: 1.486792
# Train Epoch: 49 [57600/60000 (96%)]	Loss: 1.521778
#
# Train set for client: Accuracy: 58498/60000 (97%)
#
#
# Test set for client: Average loss: 0.0235, Accuracy: 9765/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9766/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9764/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9767/10000 (98%)
#
# Test set for client: Average loss: 0.0235, Accuracy: 9766/10000 (98%)
